# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df
# Out:
#        ResponseId                      MainBranch              Age  \
# 0               1  I am a developer by profession  25-34 years old
# 1               2  I am a developer by profession  25-34 years old
# 2               3  I am a developer by profession  35-44 years old
# 3               4  I am a developer by profession  35-44 years old
# 4               5  I am a developer by profession  35-44 years old
# ...           ...                             ...              ...
# 49118       49119  I am a developer by profession  25-34 years old
# 49119       49120  I am a developer by profession  35-44 years old
# 49120       49121  I am a developer by profession  25-34 years old
# 49121       49122  I am a developer by profession  25-34 years old
# 49122       49123  I am a developer by profession  25-34 years old
#
#                                                  EdLevel  \
# 0        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1                    Associate degree (A.A., A.S., etc.)
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                  ...
# 49118       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49119       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49120  Secondary school (e.g. American high school, G...
# 49121                Associate degree (A.A., A.S., etc.)
# 49122  Some college/university study without earning ...
#
#                                               Employment  \
# 0                                               Employed
# 1                                               Employed
# 2      Independent contractor, freelancer, or self-em...
# 3                                               Employed
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 49118                                           Employed
# 49119                                           Employed
# 49120                                           Employed
# 49121                                           Employed
# 49122                                           Employed
#
#                                           EmploymentAddl  WorkExp  \
# 0        Caring for dependents (children, elderly, etc.)      8.0
# 1                                                    NaN      2.0
# 2                                      None of the above     10.0
# 3                                      None of the above      4.0
# 4        Caring for dependents (children, elderly, etc.)     21.0
# ...                                                  ...      ...
# 49118                                                NaN      9.0
# 49119    Caring for dependents (children, elderly, etc.)     13.0
# 49120                                                NaN      2.0
# 49121  None of the above;Engaged in paid work (20-29 ...     10.0
# 49122                                  None of the above     10.0
#
#                                          LearnCodeChoose  \
# 0      Yes, I am not new to coding but am learning ne...
# 1      Yes, I am not new to coding but am learning ne...
# 2      Yes, I am not new to coding but am learning ne...
# 3      Yes, I am not new to coding but am learning ne...
# 4      No, I am not new to coding and did not learn n...
# ...                                                  ...
# 49118  Yes, I am not new to coding but am learning ne...
# 49119  No, I am not new to coding and did not learn n...
# 49120  Yes, I am not new to coding but am learning ne...
# 49121  No, I am not new to coding and did not learn n...
# 49122  No, I am not new to coding and did not learn n...
#
#                                                LearnCode  \
# 0      Online Courses or Certification (includes all ...
# 1      Online Courses or Certification (includes all ...
# 2      Online Courses or Certification (includes all ...
# 3      Other online resources (e.g. standard search, ...
# 4                                                    NaN
# ...                                                  ...
# 49118  Online Courses or Certification (includes all ...
# 49119                                                NaN
# 49120  Other online resources (e.g. standard search, ...
# 49121                                                NaN
# 49122                                                NaN
#
#                                              LearnCodeAI  ...  \
# 0      Yes, I learned how to use AI-enabled tools for...  ...
# 1      Yes, I learned how to use AI-enabled tools for...  ...
# 2      Yes, I learned how to use AI-enabled tools for...  ...
# 3      Yes, I learned how to use AI-enabled tools for...  ...
# 4      Yes, I learned how to use AI-enabled tools for...  ...
# ...                                                  ...  ...
# 49118  Yes, I learned how to use AI-enabled tools req...  ...
# 49119  Yes, I learned how to use AI-enabled tools req...  ...
# 49120  No, I didn't spend time learning in the past year  ...
# 49121  Yes, I learned how to use AI-enabled tools for...  ...
# 49122  No, I learned something that was not related t...  ...
#
#       AIAgentOrchestration  AIAgentOrchWrite AIAgentObserveSecure  \
# 0                Vertex AI               NaN                  NaN
# 1                      NaN               NaN                  NaN
# 2                      NaN               NaN                  NaN
# 3                      NaN               NaN                  NaN
# 4                      NaN               NaN                  NaN
# ...                    ...               ...                  ...
# 49118                  NaN               NaN                  NaN
# 49119                  NaN               NaN                  NaN
# 49120                  NaN               NaN                  NaN
# 49121                  NaN               NaN                  NaN
# 49122                  NaN               NaN                  NaN
#
#       AIAgentObsWrite                                   AIAgentExternal  \
# 0                 NaN                                           ChatGPT
# 1                 NaN                                               NaN
# 2                 NaN  ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 3                 NaN                               ChatGPT;Claude Code
# 4                 NaN                                               NaN
# ...               ...                                               ...
# 49118             NaN                                               NaN
# 49119             NaN                                               NaN
# 49120             NaN                                               NaN
# 49121             NaN                                               NaN
# 49122             NaN                                               NaN
#
#       AIAgentExtWrite                                            AIHuman  \
# 0                 NaN                    When I don’t trust AI’s answers
# 1                 NaN  When I don’t trust AI’s answers;When I want to...
# 2                 NaN  When I don’t trust AI’s answers;When I want to...
# 3                 NaN  When I don’t trust AI’s answers;When I want to...
# 4                 NaN                    When I don’t trust AI’s answers
# ...               ...                                                ...
# 49118             NaN                                                NaN
# 49119             NaN                                                NaN
# 49120             NaN                                                NaN
# 49121             NaN                                                NaN
# 49122             NaN                                                NaN
#
#                                                   AIOpen  ConvertedCompYearly  \
# 0                  Troubleshooting, profiling, debugging              61256.0
# 1                              All skills. AI is a flop.             104413.0
# 2      Understand how things actually work, problem s...              53061.0
# 3                                                    NaN              36197.0
# 4      critical thinking, the skill to define the tas...              60000.0
# ...                                                  ...                  ...
# 49118                                                NaN                  NaN
# 49119                                                NaN                  NaN
# 49120                                                NaN                  NaN
# 49121                                                NaN                  NaN
# 49122                                                NaN                  NaN
#
#        JobSat
# 0        10.0
# 1         9.0
# 2         8.0
# 3         6.0
# 4         7.0
# ...       ...
# 49118     8.0
# 49119     NaN
# 49120     NaN
# 49121     7.0
# 49122     8.0
#
# [49123 rows x 170 columns]

# %%
df.shape
# Out:
# (49123, 170)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49123 entries, 0 to 49122
# Columns: 170 entries, ResponseId to JobSat
# dtypes: float64(50), int64(1), object(119)
# memory usage: 63.7+ MB

# %%
pd.set_option('display.max_columns', 170)
pd.set_option('display.max_rows', 139)

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#         qid                 qname  \
# 0     QID18         TechEndorse_1
# 1     QID18         TechEndorse_2
# 2     QID18         TechEndorse_3
# 3     QID18         TechEndorse_4
# 4     QID18         TechEndorse_5
# 5     QID18         TechEndorse_6
# 6     QID18         TechEndorse_7
# 7     QID18         TechEndorse_8
# 8     QID18         TechEndorse_9
# 9     QID18        TechEndorse_13
# 10    QID18   TechEndorse_13_TEXT
# 11    QID19          TechOppose_1
# 12    QID19          TechOppose_2
# 13    QID19          TechOppose_3
# 14    QID19          TechOppose_5
# 15    QID19          TechOppose_7
# 16    QID19          TechOppose_9
# 17    QID19         TechOppose_11
# 18    QID19         TechOppose_13
# 19    QID19         TechOppose_16
# 20    QID19         TechOppose_15
# 21    QID19    TechOppose_15_TEXT
# 22    QID27        JobSatPoints_1
# 23    QID27        JobSatPoints_2
# 24    QID27       JobSatPoints_16
# 25    QID27        JobSatPoints_3
# 26    QID27        JobSatPoints_4
# 27    QID27        JobSatPoints_5
# 28    QID27        JobSatPoints_6
# 29    QID27        JobSatPoints_7
# 30    QID27        JobSatPoints_8
# 31    QID27        JobSatPoints_9
# 32    QID27       JobSatPoints_10
# 33    QID27       JobSatPoints_11
# 34    QID27       JobSatPoints_13
# 35    QID27       JobSatPoints_14
# 36    QID27       JobSatPoints_15
# 37    QID27  JobSatPoints_15_TEXT
# 38    QID76          SO_Actions_1
# 39    QID76         SO_Actions_16
# 40    QID76          SO_Actions_3
# 41    QID76          SO_Actions_4
# 42    QID76          SO_Actions_5
# 43    QID76          SO_Actions_6
# 44    QID76          SO_Actions_9
# 45    QID76          SO_Actions_7
# 46    QID76         SO_Actions_10
# 47    QID76         SO_Actions_15
# 48    QID76    SO_Actions_15_TEXT
# 49     QID3            MainBranch
# 50     QID4                   Age
# 51     QID9               EdLevel
# 52     QID7            Employment
# 53     QID8        EmploymentAddl
# 54    QID14               WorkExp
# 55    QID10       LearnCodeChoose
# 56    QID11             LearnCode
# 57    QID12           LearnCodeAI
# 58    QID32            AILearnHow
# 59    QID13             YearsCode
# 60    QID15               DevType
# 61    QID16               OrgSize
# 62    QID23                ICorPM
# 63    QID24            RemoteWork
# 64    QID17     PurchaseInfluence
# 65    QID33      TechEndorseIntro
# 66    QID25              Industry
# 67    QID26                JobSat
# 68    QID28              AIThreat
# 69    QID29               NewRole
# 70    QID30         ToolCountWork
# 71    QID31     ToolCountPersonal
# 72    QID20               Country
# 73    QID21              Currency
# 74    QID22             CompTotal
# 75    QID44        LanguageChoice
# 76    QID34              Language
# 77    QID51    LanguagesHaveEntry
# 78    QID52    LanguagesWantEntry
# 79    QID45        DatabaseChoice
# 80    QID35              Database
# 81    QID54     DatabaseHaveEntry
# 82    QID55     DatabaseWantEntry
# 83    QID46        PlatformChoice
# 84    QID36              Platform
# 85    QID56     PlatformHaveEntry
# 86    QID57     PlatformWantEntry
# 87    QID47        WebframeChoice
# 88    QID37              Webframe
# 89    QID58     WebframeHaveEntry
# 90    QID59     WebframeWantEntry
# 91    QID48         DevEnvsChoice
# 92    QID38               DevEnvs
# 93    QID60       DevEnvHaveEntry
# 94    QID61       DevEnvWantEntry
# 95    QID39                SOTags
# 96    QID62       SOTagsHaveEntry
# 97    QID63      SOTagsWant Entry
# 98    QID40                 OpSys
# 99    QID41      OfficeStackAsync
# 100   QID64  OfficeStackHaveEntry
# 101   QID65  OfficeStackWantEntry
# 102   QID42          CommPlatform
# 103   QID66  CommPlatformHaveEntr
# 104   QID67  CommPlatformWantEntr
# 105   QID50        AIModelsChoice
# 106   QID43              AIModels
# 107   QID68     AIModelsHaveEntry
# 108   QID69     AIModelsWantEntry
# 109   QID72             SOAccount
# 110   QID70           SOVisitFreq
# 111   QID71            SODuration
# 112   QID73            SOPartFreq
# 113   QID75        SO_Dev_Content
# 114   QID77                SOComm
# 115   QID97            SOFriction
# 116   QID78              AISelect
# 117   QID79                AISent
# 118   QID80                 AIAcc
# 119   QID81             AIComplex
# 120   QID82                AITool
# 121   QID99         AIFrustration
# 122   QID84             AIExplain
# 123   QID85              AIAgents
# 124   QID83         AIAgentChange
# 125   QID86          AIAgent_Uses
# 126  QID106      AgentUsesGeneral
# 127   QID87         AIAgentImpact
# 128   QID88     AIAgentChallenges
# 129   QID89      AIAgentKnowledge
# 130  QID107      AIAgentKnowWrite
# 131   QID90  AIAgentOrchestration
# 132  QID102      AIAgentOrchWrite
# 133   QID91  AIAgentObserveSecure
# 134  QID103       AIAgentObsWrite
# 135   QID92       AIAgentExternal
# 136  QID104       AIAgentExtWrite
# 137  QID100               AIHuman
# 138   QID93                AIOpen
#
#                                               question    type  \
# 0    What attracts you to a technology or causes yo...      RO
# 1    What attracts you to a technology or causes yo...      RO
# 2    What attracts you to a technology or causes yo...      RO
# 3    What attracts you to a technology or causes yo...      RO
# 4    What attracts you to a technology or causes yo...      RO
# 5    What attracts you to a technology or causes yo...      RO
# 6    What attracts you to a technology or causes yo...      RO
# 7    What attracts you to a technology or causes yo...      RO
# 8    What attracts you to a technology or causes yo...      RO
# 9    What attracts you to a technology or causes yo...      RO
# 10   What attracts you to a technology or causes yo...      RO
# 11   What would turn you off or cause you to reject...      RO
# 12   What would turn you off or cause you to reject...      RO
# 13   What would turn you off or cause you to reject...      RO
# 14   What would turn you off or cause you to reject...      RO
# 15   What would turn you off or cause you to reject...      RO
# 16   What would turn you off or cause you to reject...      RO
# 17   What would turn you off or cause you to reject...      RO
# 18   What would turn you off or cause you to reject...      RO
# 19   What would turn you off or cause you to reject...      RO
# 20   What would turn you off or cause you to reject...      RO
# 21   What would turn you off or cause you to reject...      RO
# 22   Rank the following attributes of your current ...      RO
# 23   Rank the following attributes of your current ...      RO
# 24   Rank the following attributes of your current ...      RO
# 25   Rank the following attributes of your current ...      RO
# 26   Rank the following attributes of your current ...      RO
# 27   Rank the following attributes of your current ...      RO
# 28   Rank the following attributes of your current ...      RO
# 29   Rank the following attributes of your current ...      RO
# 30   Rank the following attributes of your current ...      RO
# 31   Rank the following attributes of your current ...      RO
# 32   Rank the following attributes of your current ...      RO
# 33   Rank the following attributes of your current ...      RO
# 34   Rank the following attributes of your current ...      RO
# 35   Rank the following attributes of your current ...      RO
# 36   Rank the following attributes of your current ...      RO
# 37   Rank the following attributes of your current ...      RO
# 38   When visiting Stack Overflow, which following ...      RO
# 39   When visiting Stack Overflow, which following ...      RO
# 40   When visiting Stack Overflow, which following ...      RO
# 41   When visiting Stack Overflow, which following ...      RO
# 42   When visiting Stack Overflow, which following ...      RO
# 43   When visiting Stack Overflow, which following ...      RO
# 44   When visiting Stack Overflow, which following ...      RO
# 45   When visiting Stack Overflow, which following ...      RO
# 46   When visiting Stack Overflow, which following ...      RO
# 47   When visiting Stack Overflow, which following ...      RO
# 48   When visiting Stack Overflow, which following ...      RO
# 49   Are you someone who writes code? Please select...      MC
# 50                                   What is your age?      MC
# 51   Which of the following best describes the high...      MC
# 52   Which of the following best describes your cur...      MC
# 53   Which of the following <strong>additional</str...      MC
# 54   How many years of professional work experience...      TE
# 55   Did you begin learning to code or learn a new ...      MC
# 56   How did you learn to code in the past year? Se...      MC
# 57   Did you spend time in the last year learning A...      MC
# 58   How did you learn to code for AI in the past y...      MC
# 59   Including any education, how many years have y...      TE
# 60   Which of the following describes your current ...      MC
# 61   Approximately how many people are employed by ...      MC
# 62   Are you an individual contributor or people ma...      MC
# 63   Which best describes your current work situation?      MC
# 64   Have you <strong>influenced or endorsed</stron...      MC
# 65   When you&rsquo;re in a position to <strong>inf...      MC
# 66                   What industry do you work for in?      MC
# 67   How satisfied are you in your current professi...      MC
# 68   Do you believe AI is a threat to your current ...      MC
# 69   Have you considered a career change or transit...      MC
# 70   For your <b>primary work role</b> (student, de...      TE
# 71   <b></b>For your <b>side projects or other pers...      TE
# 72                                  Where do you live?      MC
# 73   Which currency do you use day-to-day? If your ...      MC
# 74   What is your current total <b>annual</b> compe...      TE
# 75   Did you work with programming, scripting and m...      MC
# 76   Which <b>programming, scripting, and markup la...  Matrix
# 77   Was the programming language you use not liste...      TE
# 78   Was the programming language you want to use n...      TE
# 79   Did you work with database environments in the...      MC
# 80   Which <b>database environments </b>have you do...  Matrix
# 81   Was the database environment you use not liste...      TE
# 82   Was the database environment you want to use n...      TE
# 83   Did you work with cloud platforms, containeriz...      MC
# 84   Which <b>cloud platforms, containerization/orc...  Matrix
# 85   Was the cloud platforms, containerization/orch...      TE
# 86   Was the cloud platforms, containerization/orch...      TE
# 87   Did you work with web frameworks and web techn...      MC
# 88   Which <b>web frameworks and web technologies</...  Matrix
# 89   Were the web frameworks and web technologies y...      TE
# 90   Were the web frameworks and web technologies y...      TE
# 91   Did you work with development environments or ...      MC
# 92   Which <strong>development environments and AI-...  Matrix
# 93   Was the developer environment or AI-enabled co...      TE
# 94   Was the developer environment or AI-enabled co...      TE
# 95   Which rising technology of the added as <b>new...  Matrix
# 96   Was the new tag on Stack Overflow (i.e. added ...      TE
# 97   Was the new tag on Stack Overflow (i.e. added ...      TE
# 98   What is the primary <b>operating system</b> in...  Matrix
# 99   Which <b>collaborative work management and/or ...  Matrix
# 100  Was the collaborative work management and/or c...      TE
# 101  Was the collaborative work management and/or c...      TE
# 102  Which <b>community platforms</b> have you util...  Matrix
# 103  Was the community platform you use not listed ...      TE
# 104  Was the community platform you want to use not...      TE
# 105  Did you utilize or integrate specific Large La...      MC
# 106  Which <b>LLM models for AI tools</b> have you ...  Matrix
# 107  Was the LLM model for AI tools you use not lis...      TE
# 108  Was the LLM model for AI tools you want to use...      TE
# 109              Do you have a Stack Overflow account?      MC
# 110  How frequently would you say you visit Stack O...      MC
# 111             How long have you used Stack Overflow?      MC
# 112  How frequently would you say you participate i...      MC
# 113  Whether it be to solve a problem, for career g...      MC
# 114  Do you consider yourself a member of the Stack...      MC
# 115  When you visit Stack Overflow, how often is it...      MC
# 116  Do you currently use AI tools in your developm...      MC
# 117  How favorable is your stance on using AI tools...      MC
# 118  How much do you trust the accuracy of the outp...      MC
# 119  How well do the AI tools you use in your devel...      MC
# 120  Which parts of your development workflow are y...  Matrix
# 121  When using AI tools, which of the following pr...      MC
# 122  In your own words, is &quot;vibe coding&quot; ...      TE
# 123  Are you using AI agents in your work (developm...      MC
# 124  Have AI tools or AI agents changed how you com...      MC
# 125  What industry purposes or specific tasks are y...      MC
# 126                                                         MC
# 127  To what extent do you agree with the following...  Matrix
# 128  To what extent do you agree with the following...  Matrix
# 129  You indicated you use or develop AI agents as ...      MC
# 130  Was the tool or tools for AI agent orchestrati...      TE
# 131  You indicated you use or develop AI agents as ...      MC
# 132  Was the tool or tools for AI agent orchestrati...      TE
# 133  You indicated you use or develop AI agents as ...      MC
# 134  Was the tool or tools for AI agent observabili...      TE
# 135  You indicated you use or develop AI agents as ...      MC
# 136  Was the out-of-the-box agents, copilots or ass...      TE
# 137  In the future, if AI can do most coding tasks,...      MC
# 138  Looking ahead 3–5 years, what skills do you be...      TE
#
#                                                    sub  sq_id
# 0              AI integration or AI Agent capabilities    1.0
# 1                                      Easy-to-use API    2.0
# 2                              Robust and complete API    3.0
# 3                 Customizable and manageable codebase    4.0
# 4                               Reputation for quality    5.0
# 5                  Connected to an open-source project    6.0
# 6                          Good brand and public image    7.0
# 7                          Reliability and low latency    8.0
# 8                                 Costs are manageable    9.0
# 9                              Other (please specify):   10.0
# 10                      Other (please specify): - Text   13.0
# 11                             Lack of AI or AI agents    1.0
# 12                                      Poor usability    2.0
# 13                              Lack of or sub-par API    3.0
# 14                          Inefficient or time-costly    4.0
# 15                                 Prohibitive pricing    5.0
# 16                        Security or privacy concerns    6.0
# 17                 Availability of better alternatives    7.0
# 18         Outdated or obsolete technology or features    8.0
# 19                                    Ethical concerns    9.0
# 20                             Other (please specify):   10.0
# 21                      Other (please specify): - Text   15.0
# 22       Control over the level of quality in projects    1.0
# 23         Autonomy and trust to manage your own tasks    2.0
# 24                               You like your manager    3.0
# 25               Collaboration and support from a team    4.0
# 26                                      Expert mentors    5.0
# 27   Opportunities to mentor and lead junior-level ...    6.0
# 28                    Developing specialized expertise    7.0
# 29                         Solving real-world problems    8.0
# 30   Job stability and career growth with a single ...    9.0
# 31   Innovation through solving challenging and com...   10.0
# 32             Working with new technologies and tools   11.0
# 33                        Competitive pay and benefits   12.0
# 34                Recognition from peers for your work   13.0
# 35           Recognition from leadership for your work   14.0
# 36                             Other (please specify):   15.0
# 37                      Other (please specify): - Text   15.0
# 38   Browse content related to Q&A posts I recently...    1.0
# 39   Read and/or vote on comments for a Question or...    2.0
# 40                     Bookmark posts to look at later    3.0
# 41   Directly open a Q&A post via search, documenta...    4.0
# 42                                      Ask a question    5.0
# 43                                   Answer a question    6.0
# 44                                Comment on Q&A posts    7.0
# 45                           Upvote/Downvote Q&A posts    8.0
# 46                      Use discussion or chat feature    9.0
# 47                                   Other (write in):   10.0
# 48                            Other (write in): - Text   15.0
# 49                                                 NaN    NaN
# 50                                                 NaN    NaN
# 51                                                 NaN    NaN
# 52                                                 NaN    NaN
# 53                                                 NaN    NaN
# 54                                                 NaN    NaN
# 55                                                 NaN    NaN
# 56                                                 NaN    NaN
# 57                                                 NaN    NaN
# 58                                                 NaN    NaN
# 59                                                 NaN    NaN
# 60                                                 NaN    NaN
# 61                                                 NaN    NaN
# 62                                                 NaN    NaN
# 63                                                 NaN    NaN
# 64                                                 NaN    NaN
# 65                                                 NaN    NaN
# 66                                                 NaN    NaN
# 67                                                 NaN    NaN
# 68                                                 NaN    NaN
# 69                                                 NaN    NaN
# 70                                                 NaN    NaN
# 71                                                 NaN    NaN
# 72                                                 NaN    NaN
# 73                                                 NaN    NaN
# 74                                                 NaN    NaN
# 75                                                 NaN    NaN
# 76                                                 NaN    NaN
# 77                                                 NaN    NaN
# 78                                                 NaN    NaN
# 79                                                 NaN    NaN
# 80                                                 NaN    NaN
# 81                                                 NaN    NaN
# 82                                                 NaN    NaN
# 83                                                 NaN    NaN
# 84                                                 NaN    NaN
# 85                                                 NaN    NaN
# 86                                                 NaN    NaN
# 87                                                 NaN    NaN
# 88                                                 NaN    NaN
# 89                                                 NaN    NaN
# 90                                                 NaN    NaN
# 91                                                 NaN    NaN
# 92                                                 NaN    NaN
# 93                                                 NaN    NaN
# 94                                                 NaN    NaN
# 95                                                 NaN    NaN
# 96                                                 NaN    NaN
# 97                                                 NaN    NaN
# 98                                                 NaN    NaN
# 99                                                 NaN    NaN
# 100                                                NaN    NaN
# 101                                                NaN    NaN
# 102                                                NaN    NaN
# 103                                                NaN    NaN
# 104                                                NaN    NaN
# 105                                                NaN    NaN
# 106                                                NaN    NaN
# 107                                                NaN    NaN
# 108                                                NaN    NaN
# 109                                                NaN    NaN
# 110                                                NaN    NaN
# 111                                                NaN    NaN
# 112                                                NaN    NaN
# 113                                                NaN    NaN
# 114                                                NaN    NaN
# 115                                                NaN    NaN
# 116                                                NaN    NaN
# 117                                                NaN    NaN
# 118                                                NaN    NaN
# 119                                                NaN    NaN
# 120                                                NaN    NaN
# 121                                                NaN    NaN
# 122                                                NaN    NaN
# 123                                                NaN    NaN
# 124                                                NaN    NaN
# 125                                                NaN    NaN
# 126                                                NaN    NaN
# 127                                                NaN    NaN
# 128                                                NaN    NaN
# 129                                                NaN    NaN
# 130                                                NaN    NaN
# 131                                                NaN    NaN
# 132                                                NaN    NaN
# 133                                                NaN    NaN
# 134                                                NaN    NaN
# 135                                                NaN    NaN
# 136                                                NaN    NaN
# 137                                                NaN    NaN
# 138                                                NaN    NaN

# %%
schema_df.head()
# Out:
#      qid          qname                                           question  \
# 0  QID18  TechEndorse_1  What attracts you to a technology or causes yo...
# 1  QID18  TechEndorse_2  What attracts you to a technology or causes yo...
# 2  QID18  TechEndorse_3  What attracts you to a technology or causes yo...
# 3  QID18  TechEndorse_4  What attracts you to a technology or causes yo...
# 4  QID18  TechEndorse_5  What attracts you to a technology or causes yo...
#
#   type                                      sub  sq_id
# 0   RO  AI integration or AI Agent capabilities    1.0
# 1   RO                          Easy-to-use API    2.0
# 2   RO                  Robust and complete API    3.0
# 3   RO     Customizable and manageable codebase    4.0
# 4   RO                   Reputation for quality    5.0

# %%
schema_df.tail()
# Out:
#         qid            qname  \
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  sub  sq_id
# 134  Was the tool or tools for AI agent observabili...   TE  NaN    NaN
# 135  You indicated you use or develop AI agents as ...   MC  NaN    NaN
# 136  Was the out-of-the-box agents, copilots or ass...   TE  NaN    NaN
# 137  In the future, if AI can do most coding tasks,...   MC  NaN    NaN
# 138  Looking ahead 3–5 years, what skills do you be...   TE  NaN    NaN

# %%
df.shape
# Out:
# (49123, 170)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=170)

# %%
df["Age"]
# Out:
# 0        25-34 years old
# 1        25-34 years old
# 2        35-44 years old
# 3        35-44 years old
# 4        35-44 years old
#               ...
# 49118    25-34 years old
# 49119    35-44 years old
# 49120    25-34 years old
# 49121    25-34 years old
# 49122    25-34 years old
# Name: Age, Length: 49123, dtype: object

# %%
df["Age"].value_counts()
# Out:
# Age
# 25-34 years old      16485
# 35-44 years old      13232
# 18-24 years old       9195
# 45-54 years old       6265
# 55-64 years old       2626
# 65 years or older      942
# Prefer not to say      378
# Name: count, dtype: int64

# %%
df.loc[0]
# Out:
# ResponseId                                                           1
# MainBranch                              I am a developer by profession
# Age                                                    25-34 years old
# EdLevel                Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                    Employed
#                                             ...
# AIAgentExtWrite                                                    NaN
# AIHuman                                When I don’t trust AI’s answers
# AIOpen                           Troubleshooting, profiling, debugging
# ConvertedCompYearly                                            61256.0
# JobSat                                                            10.0
# Name: 0, Length: 170, dtype: object

# %%
df.loc[0, "Age"]
# Out:
# '25-34 years old'

# %%
df.loc[[0, 1, 2], "Age"]
# Out:
# 0    25-34 years old
# 1    25-34 years old
# 2    35-44 years old
# Name: Age, dtype: object

# %%
df.loc[0:2, "Age"]
# Out:
# 0    25-34 years old
# 1    25-34 years old
# 2    35-44 years old
# Name: Age, dtype: object

# %%
df.loc[0:2, "Age":"WorkExp"]
# Out:
#                Age                                          EdLevel  \
# 0  25-34 years old  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1  25-34 years old              Associate degree (A.A., A.S., etc.)
# 2  35-44 years old     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
#
#                                     EmploymentAddl  WorkExp
# 0  Caring for dependents (children, elderly, etc.)      8.0
# 1                                              NaN      2.0
# 2                                None of the above     10.0

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col="ResponseId")

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# 3           Independent contractor, freelancer, or self-em...
# 4                                                    Employed
# 5           Independent contractor, freelancer, or self-em...
#
#                                              EmploymentAddl  WorkExp  \
# ResponseId
# 1           Caring for dependents (children, elderly, etc.)      8.0
# 2                                                       NaN      2.0
# 3                                         None of the above     10.0
# 4                                         None of the above      4.0
# 5           Caring for dependents (children, elderly, etc.)     21.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
# 2           Yes, I am not new to coding but am learning ne...
# 3           Yes, I am not new to coding but am learning ne...
# 4           Yes, I am not new to coding but am learning ne...
# 5           No, I am not new to coding and did not learn n...
#
#                                                     LearnCode  \
# ResponseId
# 1           Online Courses or Certification (includes all ...
# 2           Online Courses or Certification (includes all ...
# 3           Online Courses or Certification (includes all ...
# 4           Other online resources (e.g. standard search, ...
# 5                                                         NaN
#
#                                                   LearnCodeAI  \
# ResponseId
# 1           Yes, I learned how to use AI-enabled tools for...
# 2           Yes, I learned how to use AI-enabled tools for...
# 3           Yes, I learned how to use AI-enabled tools for...
# 4           Yes, I learned how to use AI-enabled tools for...
# 5           Yes, I learned how to use AI-enabled tools for...
#
#                                                    AILearnHow  YearsCode  \
# ResponseId
# 1                         AI CodeGen tools or AI-enabled apps       14.0
# 2                         AI CodeGen tools or AI-enabled apps       10.0
# 3           AI CodeGen tools or AI-enabled apps;Technical ...       12.0
# 4           AI CodeGen tools or AI-enabled apps;Videos (no...        5.0
# 5           Technical documentation (is generated for/by t...       22.0
#
#                          DevType                   OrgSize  \
# ResponseId
# 1              Developer, mobile        20 to 99 employees
# 2            Developer, back-end      500 to 999 employees
# 3           Developer, front-end                       NaN
# 4            Developer, back-end  10,000 or more employees
# 5            Engineering manager                       NaN
#
#                             ICorPM  \
# ResponseId
# 1                   People manager
# 2           Individual contributor
# 3                              NaN
# 4           Individual contributor
# 5                              NaN
#
#                                                    RemoteWork  \
# ResponseId
# 1                                                      Remote
# 2           Hybrid (some in-person, leans heavy to flexibi...
# 3                                                         NaN
# 4                                                      Remote
# 5                                                         NaN
#
#                                             PurchaseInfluence  \
# ResponseId
# 1           Yes, I influenced the purchase of a substantia...
# 2                                                          No
# 3                                                          No
# 4                                                          No
# 5           Yes, I endorsed a tool that was open-source an...
#
#             TechEndorseIntro  TechEndorse_1  TechEndorse_2  TechEndorse_3  \
# ResponseId
# 1                       Work           10.0            7.0            9.0
# 2           Personal Project           13.0            1.0            2.0
# 3                       Work           12.0            2.0            3.0
# 4           Personal Project            2.0           12.0            6.0
# 5                       Work            6.0            3.0            1.0
#
#             TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  \
# ResponseId
# 1                     6.0            3.0           11.0           12.0
# 2                     9.0            4.0            3.0           12.0
# 3                     7.0            5.0           10.0           13.0
# 4                     5.0           13.0            3.0            8.0
# 5                     9.0           10.0            8.0            7.0
#
#             TechEndorse_8  TechEndorse_9  TechEndorse_13 TechEndorse_13_TEXT  \
# ResponseId
# 1                     1.0            8.0            14.0                 NaN
# 2                     5.0            7.0            14.0                 NaN
# 3                     1.0            4.0            14.0                 NaN
# 4                    11.0            7.0            14.0                 NaN
# 5                     4.0            2.0            14.0                 NaN
#
#             TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# ResponseId
# 1                   15.0           7.0           8.0          12.0
# 2                   14.0           1.0          13.0          10.0
# 3                    8.0           1.0           2.0          12.0
# 4                   10.0           5.0           8.0           4.0
# 5                    7.0          13.0           3.0           9.0
#
#             TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  \
# ResponseId
# 1                   11.0           1.0            6.0           13.0
# 2                    9.0           3.0            4.0            2.0
# 3                   13.0           3.0            9.0            4.0
# 4                   13.0          12.0            2.0            7.0
# 5                   12.0           6.0            1.0            8.0
#
#             TechOppose_16  TechOppose_15 TechOppose_15_TEXT  \
# ResponseId
# 1                     3.0           16.0                NaN
# 2                     5.0           15.0                NaN
# 3                    11.0           15.0                NaN
# 4                     1.0           15.0                NaN
# 5                    14.0           15.0                NaN
#
#                                 Industry  JobSatPoints_1  JobSatPoints_4  \
# ResponseId
# 1                                Fintech             3.0             9.0
# 2           Retail and Consumer Services            10.0             9.0
# 3                   Software Development             9.0            11.0
# 4           Retail and Consumer Services             1.0             5.0
# 5                   Software Development             9.0            13.0
#
#             JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# ResponseId
# 1                      5.0            10.0            12.0            11.0
# 2                     12.0             1.0             6.0             2.0
# 3                      8.0            12.0             1.0             5.0
# 4                      6.0             7.0             8.0             9.0
# 5                     14.0             8.0             6.0             5.0
#
#             JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  JobSatPoints_13  \
# ResponseId
# 1                      2.0              6.0              7.0             13.0
# 2                     11.0              4.0              7.0             13.0
# 3                      2.0              4.0              3.0             13.0
# 4                     10.0             11.0             12.0             13.0
# 5                      7.0              2.0              1.0             12.0
#
#             JobSatPoints_14  JobSatPoints_15  JobSatPoints_16  \
# ResponseId
# 1                      14.0             15.0              8.0
# 2                      14.0             15.0              5.0
# 3                      14.0             15.0             10.0
# 4                      14.0             15.0              3.0
# 5                      10.0             15.0              3.0
#
#            JobSatPoints_15_TEXT      AIThreat  \
# ResponseId
# 1                           NaN  I'm not sure
# 2                           NaN  I'm not sure
# 3                           NaN            No
# 4                           NaN            No
# 5                           NaN            No
#
#                                                       NewRole  ToolCountWork  \
# ResponseId
# 1           I have neither consider or transitioned into a...            7.0
# 2           I have transitioned into a new career and/or i...            6.0
# 3           I have transitioned into a new career and/or i...            3.0
# 4           I have neither consider or transitioned into a...            NaN
# 5           I have neither consider or transitioned into a...            4.0
#
#             ToolCountPersonal      Country                  Currency  \
# ResponseId
# 1                         3.0      Ukraine         EUR European Euro
# 2                         5.0  Netherlands         EUR European Euro
# 3                         3.0      Ukraine     UAH Ukrainian hryvnia
# 4                         NaN      Ukraine         EUR European Euro
# 5                         3.0      Ukraine  USD United States dollar
#
#             CompTotal LanguageChoice  \
# ResponseId
# 1             52800.0            Yes
# 2             90000.0            Yes
# 3           2214000.0            Yes
# 4             31200.0            Yes
# 5             60000.0            Yes
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 1                            Bash/Shell (all shells);Dart;SQL
# 2                                                        Java
# 3                         Dart;HTML/CSS;JavaScript;TypeScript
# 4                                             Java;Kotlin;SQL
# 5           C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
#
#                               LanguageWantToWorkWith  \
# ResponseId
# 1                                               Dart
# 2                                  Java;Python;Swift
# 3                Dart;HTML/CSS;JavaScript;TypeScript
# 4                                        Java;Kotlin
# 5           C#;Java;JavaScript;Python;SQL;TypeScript
#
#                                      LanguageAdmired LanguagesHaveEntry  \
# ResponseId
# 1                                               Dart                NaN
# 2                                               Java                NaN
# 3                Dart;HTML/CSS;JavaScript;TypeScript                NaN
# 4                                        Java;Kotlin                NaN
# 5           C#;Java;JavaScript;Python;SQL;TypeScript                NaN
#
#            LanguagesWantEntry DatabaseChoice  \
# ResponseId
# 1                         NaN            Yes
# 2                         NaN            Yes
# 3                         NaN            Yes
# 4                         NaN             No
# 5                         NaN            Yes
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 1                                  Cloud Firestore;PostgreSQL
# 2                                            Dynamodb;MongoDB
# 3                                    MongoDB;MySQL;PostgreSQL
# 4                                                         NaN
# 5           Elasticsearch;Microsoft SQL Server;MySQL;Oracl...
#
#                         DatabaseWantToWorkWith  \
# ResponseId
# 1                                          NaN
# 2                             Dynamodb;MongoDB
# 3           Firebase Realtime Database;MongoDB
# 4                                          NaN
# 5              Elasticsearch;Oracle;PostgreSQL
#
#                             DatabaseAdmired DatabaseHaveEntry  \
# ResponseId
# 1                                       NaN               NaN
# 2                          Dynamodb;MongoDB               NaN
# 3                                   MongoDB               NaN
# 4                                       NaN               NaN
# 5           Elasticsearch;Oracle;PostgreSQL               NaN
#
#            DatabaseWantEntry PlatformChoice  \
# ResponseId
# 1                        NaN            Yes
# 2                        NaN            Yes
# 3                        NaN            Yes
# 4                        NaN            Yes
# 5                        NaN            Yes
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 1           Amazon Web Services (AWS);Cloudflare;Firebase;...
# 2           Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 3                                   Datadog;Firebase;npm;pnpm
# 4                      Amazon Web Services (AWS);Google Cloud
# 5           Amazon Web Services (AWS);APT;Docker;Make;Mave...
#
#                                        PlatformWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 3            Amazon Web Services (AWS);Firebase;npm;pnpm;Vite
# 4                      Amazon Web Services (AWS);Google Cloud
# 5           Amazon Web Services (AWS);APT;Docker;Maven (bu...
#
#                                               PlatformAdmired  \
# ResponseId
# 1                                                         NaN
# 2           Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 3                                           Firebase;npm;pnpm
# 4                      Amazon Web Services (AWS);Google Cloud
# 5           Amazon Web Services (AWS);APT;Docker;Maven (bu...
#
#            PlatformHaveEntry PlatformWantEntry WebframeChoice  \
# ResponseId
# 1                        NaN               NaN             No
# 2                        NaN               NaN            Yes
# 3                        NaN               NaN            Yes
# 4                        NaN               NaN            Yes
# 5                        NaN               NaN            Yes
#
#                                WebframeHaveWorkedWith  \
# ResponseId
# 1                                                 NaN
# 2                                         Spring Boot
# 3                               Next.js;Node.js;React
# 4                                         Spring Boot
# 5           Angular;ASP.NET;ASP.NET Core;Flask;jQuery
#
#                 WebframeWantToWorkWith             WebframeAdmired  \
# ResponseId
# 1                                  NaN                         NaN
# 2                          Spring Boot                 Spring Boot
# 3                Next.js;Node.js;React       Next.js;Node.js;React
# 4                          Spring Boot                 Spring Boot
# 5           Angular;ASP.NET Core;Flask  Angular;ASP.NET Core;Flask
#
#            WebframeHaveEntry WebframeWantEntry DevEnvsChoice  \
# ResponseId
# 1                        NaN               NaN           Yes
# 2                        NaN               NaN           Yes
# 3                        NaN          Solid.js           Yes
# 4                        NaN               NaN            No
# 5                        NaN               NaN           Yes
#
#                                         DevEnvsHaveWorkedWith  \
# ResponseId
# 1           Android Studio;Notepad++;Visual Studio;Visual ...
# 2              IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode
# 3                                          Visual Studio Code
# 4                                                         NaN
# 5           Eclipse;IntelliJ IDEA;Jupyter Notebook/Jupyter...
#
#                                         DevEnvsWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2              IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode
# 3                                 Visual Studio Code;Windsurf
# 4                                                         NaN
# 5           IntelliJ IDEA;Jupyter Notebook/JupyterLab;Note...
#
#                                                DevEnvsAdmired DevEnvHaveEntry  \
# ResponseId
# 1                                                         NaN             NaN
# 2              IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode             NaN
# 3                                          Visual Studio Code             NaN
# 4                                                         NaN             NaN
# 5           IntelliJ IDEA;Jupyter Notebook/JupyterLab;Note...             NaN
#
#            DevEnvWantEntry                SOTagsHaveWorkedWith  \
# ResponseId
# 1                      NaN                                 NaN
# 2                      NaN                                 NaN
# 3                      NaN                       Google Gemini
# 4                      NaN                      Amazon Bedrock
# 5                      NaN  Large Language Model;Google Gemini
#
#                SOTagsWantToWorkWith         SOTagsAdmired SOTagsHaveEntry  \
# ResponseId
# 1                               NaN                   NaN             NaN
# 2                               NaN                   NaN             NaN
# 3           Google Gemini;Shadcn/ui         Google Gemini             NaN
# 4                               NaN                   NaN             NaN
# 5              Large Language Model  Large Language Model             NaN
#
#            SOTagsWant Entry         OpSysPersonal use  \
# ResponseId
# 1                       NaN     Windows;MacOS;Android
# 2                       NaN  Windows;MacOS;iOS;iPadOS
# 3                       NaN             MacOS;Android
# 4                       NaN                   Windows
# 5                       NaN               Windows;iOS
#
#                        OpSysProfessional use  \
# ResponseId
# 1           Windows;MacOS;Android;iOS;iPadOS
# 2                                      MacOS
# 3                                      MacOS
# 4                             Windows;Ubuntu
# 5                      Windows;Ubuntu;Debian
#
#                          OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 1           Confluence;GitHub;GitLab;Jira;Markdown File
# 2                                Confluence;GitHub;Jira
# 3                                    GitHub;GitLab;Jira
# 4                                      GitLab;Jira;Miro
# 5                              Azure Devops;GitHub;Jira
#
#            OfficeStackAsyncWantToWorkWith   OfficeStackAsyncAdmired  \
# ResponseId
# 1                           Markdown File             Markdown File
# 2                  Confluence;GitHub;Jira    Confluence;GitHub;Jira
# 3                      GitHub;GitLab;Jira        GitHub;GitLab;Jira
# 4                             GitLab;Jira               GitLab;Jira
# 5                Azure Devops;GitHub;Jira  Azure Devops;GitHub;Jira
#
#            OfficeStackHaveEntry OfficeStackWantEntry  \
# ResponseId
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# 4                           NaN                  NaN
# 5                           NaN                  NaN
#
#                                    CommPlatformHaveWorkedWith  \
# ResponseId
# 1           Stack Overflow;Reddit;GitHub (public projects,...
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4                      Stack Overflow;Reddit;YouTube;LinkedIn
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
#
#                                    CommPlatformWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4           Stack Overflow;Reddit;GitHub (public projects,...
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
#
#                                           CommPlatformAdmired  \
# ResponseId
# 1                                                         NaN
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4                      Stack Overflow;Reddit;YouTube;LinkedIn
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
#
#            CommPlatformHaveEntr CommPlatformWantEntr AIModelsChoice  \
# ResponseId
# 1                           NaN                  NaN            Yes
# 2                           NaN                  NaN            Yes
# 3                           NaN                  NaN            Yes
# 4                           NaN                  NaN             No
# 5                           NaN                  NaN            Yes
#
#                                        AIModelsHaveWorkedWith  \
# ResponseId
# 1           openAI GPT (chatbot models);openAI Image gener...
# 2                                 openAI GPT (chatbot models)
# 3           Gemini (Flash general purpose models);openAI G...
# 4                                                         NaN
# 5                                 openAI GPT (chatbot models)
#
#                                        AIModelsWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                 openAI GPT (chatbot models)
# 3           Gemini (Flash general purpose models);Gemini (...
# 4                                                         NaN
# 5                                 openAI GPT (chatbot models)
#
#                                               AIModelsAdmired  \
# ResponseId
# 1                                                         NaN
# 2                                 openAI GPT (chatbot models)
# 3           Gemini (Flash general purpose models);openAI G...
# 4                                                         NaN
# 5                                 openAI GPT (chatbot models)
#
#            AIModelsHaveEntry AIModelsWantEntry                SOAccount  \
# ResponseId
# 1                        NaN               NaN                      Yes
# 2                        NaN               NaN  Not sure/can't remember
# 3                        NaN               NaN  Not sure/can't remember
# 4                        NaN               NaN                      Yes
# 5                        NaN               NaN                       No
#
#                                 SOVisitFreq               SODuration  \
# ResponseId
# 1                      A few times per week   Between 5 and 10 years
# 2                    Multiple times per day  Between 10 and 15 years
# 3                      A few times per week   Between 5 and 10 years
# 4           A few times per month or weekly    Between 3 and 5 years
# 5           A few times per month or weekly   Between 5 and 10 years
#
#                                                    SOPartFreq  \
# ResponseId
# 1           I have never participated in Q&A on Stack Over...
# 2                       Infrequently, less than once per year
# 3                       Infrequently, less than once per year
# 4           I have never participated in Q&A on Stack Over...
# 5                       Infrequently, less than once per year
#
#                                                SO_Dev_Content  SO_Actions_1  \
# ResponseId
# 1                                                         NaN           1.0
# 2           Chat (people);Message Boards;Long-form article...           6.0
# 3           Chat (people);Videos;Lists of recommendations ...           3.0
# 4                                        Videos;Chat (bot/AI)           1.0
# 5                                          Long-form articles           1.0
#
#             SO_Actions_16  SO_Actions_3  SO_Actions_4  SO_Actions_5  \
# ResponseId
# 1                     NaN           6.0           2.0           3.0
# 2                     NaN           5.0           8.0           2.0
# 3                     NaN           4.0           5.0           1.0
# 4                     NaN           4.0           5.0           6.0
# 5                     NaN           7.0           4.0           2.0
#
#             SO_Actions_6  SO_Actions_9  SO_Actions_7  SO_Actions_10  \
# ResponseId
# 1                    7.0           8.0           9.0           11.0
# 2                    4.0           9.0          10.0           11.0
# 3                    2.0           7.0           9.0           11.0
# 4                    7.0           8.0           9.0           11.0
# 5                    5.0          10.0           6.0           12.0
#
#             SO_Actions_15 SO_Actions_15_TEXT          SOComm  \
# ResponseId
# 1                    15.0                NaN         Neutral
# 2                    15.0                NaN   Yes, somewhat
# 3                    15.0                NaN         Neutral
# 4                    15.0                NaN         Neutral
# 5                    15.0                NaN  No, not really
#
#                         SOFriction  \
# ResponseId
# 1             Rarely, almost never
# 2           About half of the time
# 3           About half of the time
# 4             Rarely, almost never
# 5             Rarely, almost never
#
#                                                AISelect       AISent  \
# ResponseId
# 1           Yes, I use AI tools monthly or infrequently  Indifferent
# 2                            Yes, I use AI tools weekly  Indifferent
# 3                             Yes, I use AI tools daily    Favorable
# 4                            Yes, I use AI tools weekly    Favorable
# 5                            Yes, I use AI tools weekly    Favorable
#
#                                  AIAcc  \
# ResponseId
# 1           Neither trust nor distrust
# 2           Neither trust nor distrust
# 3                       Somewhat trust
# 4                       Somewhat trust
# 5           Neither trust nor distrust
#
#                                                 AIComplex  \
# ResponseId
# 1                           Bad at handling complex tasks
# 2                           Bad at handling complex tasks
# 3           Neither good or bad at handling complex tasks
# 4                           Bad at handling complex tasks
# 5           Good, but not great at handling complex tasks
#
#                                  AIToolCurrently partially AI  \
# ResponseId
# 1           Learning about a codebase;Writing code;Search ...
# 2                       Learning new concepts or technologies
# 3           Documenting code;Debugging or fixing code;Test...
# 4                                                         NaN
# 5           Learning about a codebase;Writing code;Debuggi...
#
#                      AIToolDon't plan to use AI for this task  \
# ResponseId
# 1           Project planning;Deployment and monitoring;Lea...
# 2           Learning about a codebase;Project planning;Com...
# 3                                                         NaN
# 4           Project planning;Documenting code;Testing code...
# 5           Project planning;Documenting code;Testing code...
#
#                                AIToolPlan to partially use AI  \
# ResponseId
# 1           Documenting code;Debugging or fixing code;Test...
# 2           Writing code;Documenting code;Debugging or fix...
# 3           Project planning;Committing and reviewing code...
# 4           Learning about a codebase;Writing code;Debuggi...
# 5                        Generating content or synthetic data
#
#                                   AIToolPlan to mostly use AI  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           Learning about a codebase;Writing code;Generat...
# 4           Search for answers;Generating content or synth...
# 5                                                         NaN
#
#            AIToolCurrently mostly AI  \
# ResponseId
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
#
#                                                 AIFrustration AIExplain  \
# ResponseId
# 1           AI solutions that are almost right, but not quite        No
# 2           AI solutions that are almost right, but not qu...        No
# 3           AI solutions that are almost right, but not qu...        No
# 4           AI solutions that are almost right, but not qu...        NO
# 5           AI solutions that are almost right, but not quite    partly
#
#                                                      AIAgents  \
# ResponseId
# 1           Yes, I use AI agents at work monthly or infreq...
# 2                                     No, and I don't plan to
# 3                         Yes, I use AI agents at work weekly
# 4           Yes, I use AI agents at work monthly or infreq...
# 5                                     No, and I don't plan to
#
#                       AIAgentChange          AIAgent_Uses  \
# ResponseId
# 1           Not at all or minimally  Software engineering
# 2           Not at all or minimally                   NaN
# 3                     Yes, somewhat  Software engineering
# 4           Not at all or minimally  Software engineering
# 5            Yes, to a great extent                   NaN
#
#                             AgentUsesGeneral  \
# ResponseId
# 1                                        NaN
# 2                                        NaN
# 3           Multi-platform search enablement
# 4                        Language processing
# 5                                        NaN
#
#                                   AIAgentImpactSomewhat agree  \
# ResponseId
# 1           AI agents have increased my productivity.;AI a...
# 2                                                         NaN
# 3           AI agents have increased my productivity.;AI a...
# 4           AI agents have accelerated my learning about n...
# 5                                                         NaN
#
#                                          AIAgentImpactNeutral  \
# ResponseId
# 1           AI agents have helped me automate repetitive t...
# 2                                                         NaN
# 3           AI agents have improved the quality of my code...
# 4           AI agents have increased my productivity.;AI a...
# 5                                                         NaN
#
#                                AIAgentImpactSomewhat disagree  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           AI agents have improved collaboration within m...
# 4           AI agents have helped me automate repetitive t...
# 5                                                         NaN
#
#            AIAgentImpactStrongly agree AIAgentImpactStrongly disagree  \
# ResponseId
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# 5                                  NaN                            NaN
#
#                                      AIAgentChallengesNeutral  \
# ResponseId
# 1           I am concerned about the accuracy of the infor...
# 2           It takes significant time and effort to learn ...
# 3           It takes significant time and effort to learn ...
# 4           It takes significant time and effort to learn ...
# 5           Integrating AI agents with my existing tools a...
#
#                            AIAgentChallengesSomewhat disagree  \
# ResponseId
# 1           Integrating AI agents with my existing tools a...
# 2                                                         NaN
# 3           My company's IT and/or InfoSec teams have stri...
# 4                                                         NaN
# 5                                                         NaN
#
#                               AIAgentChallengesStrongly agree  \
# ResponseId
# 1           The cost of using certain AI agent platforms i...
# 2           I am concerned about the accuracy of the infor...
# 3                                                         NaN
# 4           I am concerned about the accuracy of the infor...
# 5           I am concerned about the accuracy of the infor...
#
#                               AIAgentChallengesSomewhat agree  \
# ResponseId
# 1                                                         NaN
# 2           Integrating AI agents with my existing tools a...
# 3           I am concerned about the accuracy of the infor...
# 4           Integrating AI agents with my existing tools a...
# 5           It takes significant time and effort to learn ...
#
#            AIAgentChallengesStrongly disagree AIAgentKnowledge  \
# ResponseId
# 1                                         NaN              NaN
# 2                                         NaN              NaN
# 3                                         NaN            Redis
# 4                                         NaN              NaN
# 5                                         NaN              NaN
#
#            AIAgentKnowWrite AIAgentOrchestration AIAgentOrchWrite  \
# ResponseId
# 1                       NaN            Vertex AI              NaN
# 2                       NaN                  NaN              NaN
# 3                       NaN                  NaN              NaN
# 4                       NaN                  NaN              NaN
# 5                       NaN                  NaN              NaN
#
#            AIAgentObserveSecure AIAgentObsWrite  \
# ResponseId
# 1                           NaN             NaN
# 2                           NaN             NaN
# 3                           NaN             NaN
# 4                           NaN             NaN
# 5                           NaN             NaN
#
#                                              AIAgentExternal AIAgentExtWrite  \
# ResponseId
# 1                                                    ChatGPT             NaN
# 2                                                        NaN             NaN
# 3           ChatGPT;Claude Code;GitHub Copilot;Google Gemini             NaN
# 4                                        ChatGPT;Claude Code             NaN
# 5                                                        NaN             NaN
#
#                                                       AIHuman  \
# ResponseId
# 1                             When I don’t trust AI’s answers
# 2           When I don’t trust AI’s answers;When I want to...
# 3           When I don’t trust AI’s answers;When I want to...
# 4           When I don’t trust AI’s answers;When I want to...
# 5                             When I don’t trust AI’s answers
#
#                                                        AIOpen  \
# ResponseId
# 1                       Troubleshooting, profiling, debugging
# 2                                   All skills. AI is a flop.
# 3           Understand how things actually work, problem s...
# 4                                                         NaN
# 5           critical thinking, the skill to define the tas...
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 1                       61256.0    10.0
# 2                      104413.0     9.0
# 3                       53061.0     8.0
# 4                       36197.0     6.0
# 5                       60000.0     7.0

# %%
df.loc[1]
# Out:
# MainBranch                              I am a developer by profession
# Age                                                    25-34 years old
# EdLevel                Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                    Employed
# EmploymentAddl         Caring for dependents (children, elderly, etc.)
#                                             ...
# AIAgentExtWrite                                                    NaN
# AIHuman                                When I don’t trust AI’s answers
# AIOpen                           Troubleshooting, profiling, debugging
# ConvertedCompYearly                                            61256.0
# JobSat                                                            10.0
# Name: 1, Length: 169, dtype: object

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col="qname")

# %%
schema_df
# Out:
#                          qid  \
# qname
# TechEndorse_1          QID18
# TechEndorse_2          QID18
# TechEndorse_3          QID18
# TechEndorse_4          QID18
# TechEndorse_5          QID18
# TechEndorse_6          QID18
# TechEndorse_7          QID18
# TechEndorse_8          QID18
# TechEndorse_9          QID18
# TechEndorse_13         QID18
# TechEndorse_13_TEXT    QID18
# TechOppose_1           QID19
# TechOppose_2           QID19
# TechOppose_3           QID19
# TechOppose_5           QID19
# TechOppose_7           QID19
# TechOppose_9           QID19
# TechOppose_11          QID19
# TechOppose_13          QID19
# TechOppose_16          QID19
# TechOppose_15          QID19
# TechOppose_15_TEXT     QID19
# JobSatPoints_1         QID27
# JobSatPoints_2         QID27
# JobSatPoints_16        QID27
# JobSatPoints_3         QID27
# JobSatPoints_4         QID27
# JobSatPoints_5         QID27
# JobSatPoints_6         QID27
# JobSatPoints_7         QID27
# JobSatPoints_8         QID27
# JobSatPoints_9         QID27
# JobSatPoints_10        QID27
# JobSatPoints_11        QID27
# JobSatPoints_13        QID27
# JobSatPoints_14        QID27
# JobSatPoints_15        QID27
# JobSatPoints_15_TEXT   QID27
# SO_Actions_1           QID76
# SO_Actions_16          QID76
# SO_Actions_3           QID76
# SO_Actions_4           QID76
# SO_Actions_5           QID76
# SO_Actions_6           QID76
# SO_Actions_9           QID76
# SO_Actions_7           QID76
# SO_Actions_10          QID76
# SO_Actions_15          QID76
# SO_Actions_15_TEXT     QID76
# MainBranch              QID3
# Age                     QID4
# EdLevel                 QID9
# Employment              QID7
# EmploymentAddl          QID8
# WorkExp                QID14
# LearnCodeChoose        QID10
# LearnCode              QID11
# LearnCodeAI            QID12
# AILearnHow             QID32
# YearsCode              QID13
# DevType                QID15
# OrgSize                QID16
# ICorPM                 QID23
# RemoteWork             QID24
# PurchaseInfluence      QID17
# TechEndorseIntro       QID33
# Industry               QID25
# JobSat                 QID26
# AIThreat               QID28
# NewRole                QID29
# ToolCountWork          QID30
# ToolCountPersonal      QID31
# Country                QID20
# Currency               QID21
# CompTotal              QID22
# LanguageChoice         QID44
# Language               QID34
# LanguagesHaveEntry     QID51
# LanguagesWantEntry     QID52
# DatabaseChoice         QID45
# Database               QID35
# DatabaseHaveEntry      QID54
# DatabaseWantEntry      QID55
# PlatformChoice         QID46
# Platform               QID36
# PlatformHaveEntry      QID56
# PlatformWantEntry      QID57
# WebframeChoice         QID47
# Webframe               QID37
# WebframeHaveEntry      QID58
# WebframeWantEntry      QID59
# DevEnvsChoice          QID48
# DevEnvs                QID38
# DevEnvHaveEntry        QID60
# DevEnvWantEntry        QID61
# SOTags                 QID39
# SOTagsHaveEntry        QID62
# SOTagsWant Entry       QID63
# OpSys                  QID40
# OfficeStackAsync       QID41
# OfficeStackHaveEntry   QID64
# OfficeStackWantEntry   QID65
# CommPlatform           QID42
# CommPlatformHaveEntr   QID66
# CommPlatformWantEntr   QID67
# AIModelsChoice         QID50
# AIModels               QID43
# AIModelsHaveEntry      QID68
# AIModelsWantEntry      QID69
# SOAccount              QID72
# SOVisitFreq            QID70
# SODuration             QID71
# SOPartFreq             QID73
# SO_Dev_Content         QID75
# SOComm                 QID77
# SOFriction             QID97
# AISelect               QID78
# AISent                 QID79
# AIAcc                  QID80
# AIComplex              QID81
# AITool                 QID82
# AIFrustration          QID99
# AIExplain              QID84
# AIAgents               QID85
# AIAgentChange          QID83
# AIAgent_Uses           QID86
# AgentUsesGeneral      QID106
# AIAgentImpact          QID87
# AIAgentChallenges      QID88
# AIAgentKnowledge       QID89
# AIAgentKnowWrite      QID107
# AIAgentOrchestration   QID90
# AIAgentOrchWrite      QID102
# AIAgentObserveSecure   QID91
# AIAgentObsWrite       QID103
# AIAgentExternal        QID92
# AIAgentExtWrite       QID104
# AIHuman               QID100
# AIOpen                 QID93
#
#                                                                question  \
# qname
# TechEndorse_1         What attracts you to a technology or causes yo...
# TechEndorse_2         What attracts you to a technology or causes yo...
# TechEndorse_3         What attracts you to a technology or causes yo...
# TechEndorse_4         What attracts you to a technology or causes yo...
# TechEndorse_5         What attracts you to a technology or causes yo...
# TechEndorse_6         What attracts you to a technology or causes yo...
# TechEndorse_7         What attracts you to a technology or causes yo...
# TechEndorse_8         What attracts you to a technology or causes yo...
# TechEndorse_9         What attracts you to a technology or causes yo...
# TechEndorse_13        What attracts you to a technology or causes yo...
# TechEndorse_13_TEXT   What attracts you to a technology or causes yo...
# TechOppose_1          What would turn you off or cause you to reject...
# TechOppose_2          What would turn you off or cause you to reject...
# TechOppose_3          What would turn you off or cause you to reject...
# TechOppose_5          What would turn you off or cause you to reject...
# TechOppose_7          What would turn you off or cause you to reject...
# TechOppose_9          What would turn you off or cause you to reject...
# TechOppose_11         What would turn you off or cause you to reject...
# TechOppose_13         What would turn you off or cause you to reject...
# TechOppose_16         What would turn you off or cause you to reject...
# TechOppose_15         What would turn you off or cause you to reject...
# TechOppose_15_TEXT    What would turn you off or cause you to reject...
# JobSatPoints_1        Rank the following attributes of your current ...
# JobSatPoints_2        Rank the following attributes of your current ...
# JobSatPoints_16       Rank the following attributes of your current ...
# JobSatPoints_3        Rank the following attributes of your current ...
# JobSatPoints_4        Rank the following attributes of your current ...
# JobSatPoints_5        Rank the following attributes of your current ...
# JobSatPoints_6        Rank the following attributes of your current ...
# JobSatPoints_7        Rank the following attributes of your current ...
# JobSatPoints_8        Rank the following attributes of your current ...
# JobSatPoints_9        Rank the following attributes of your current ...
# JobSatPoints_10       Rank the following attributes of your current ...
# JobSatPoints_11       Rank the following attributes of your current ...
# JobSatPoints_13       Rank the following attributes of your current ...
# JobSatPoints_14       Rank the following attributes of your current ...
# JobSatPoints_15       Rank the following attributes of your current ...
# JobSatPoints_15_TEXT  Rank the following attributes of your current ...
# SO_Actions_1          When visiting Stack Overflow, which following ...
# SO_Actions_16         When visiting Stack Overflow, which following ...
# SO_Actions_3          When visiting Stack Overflow, which following ...
# SO_Actions_4          When visiting Stack Overflow, which following ...
# SO_Actions_5          When visiting Stack Overflow, which following ...
# SO_Actions_6          When visiting Stack Overflow, which following ...
# SO_Actions_9          When visiting Stack Overflow, which following ...
# SO_Actions_7          When visiting Stack Overflow, which following ...
# SO_Actions_10         When visiting Stack Overflow, which following ...
# SO_Actions_15         When visiting Stack Overflow, which following ...
# SO_Actions_15_TEXT    When visiting Stack Overflow, which following ...
# MainBranch            Are you someone who writes code? Please select...
# Age                                                   What is your age?
# EdLevel               Which of the following best describes the high...
# Employment            Which of the following best describes your cur...
# EmploymentAddl        Which of the following <strong>additional</str...
# WorkExp               How many years of professional work experience...
# LearnCodeChoose       Did you begin learning to code or learn a new ...
# LearnCode             How did you learn to code in the past year? Se...
# LearnCodeAI           Did you spend time in the last year learning A...
# AILearnHow            How did you learn to code for AI in the past y...
# YearsCode             Including any education, how many years have y...
# DevType               Which of the following describes your current ...
# OrgSize               Approximately how many people are employed by ...
# ICorPM                Are you an individual contributor or people ma...
# RemoteWork            Which best describes your current work situation?
# PurchaseInfluence     Have you <strong>influenced or endorsed</stron...
# TechEndorseIntro      When you&rsquo;re in a position to <strong>inf...
# Industry                              What industry do you work for in?
# JobSat                How satisfied are you in your current professi...
# AIThreat              Do you believe AI is a threat to your current ...
# NewRole               Have you considered a career change or transit...
# ToolCountWork         For your <b>primary work role</b> (student, de...
# ToolCountPersonal     <b></b>For your <b>side projects or other pers...
# Country                                              Where do you live?
# Currency              Which currency do you use day-to-day? If your ...
# CompTotal             What is your current total <b>annual</b> compe...
# LanguageChoice        Did you work with programming, scripting and m...
# Language              Which <b>programming, scripting, and markup la...
# LanguagesHaveEntry    Was the programming language you use not liste...
# LanguagesWantEntry    Was the programming language you want to use n...
# DatabaseChoice        Did you work with database environments in the...
# Database              Which <b>database environments </b>have you do...
# DatabaseHaveEntry     Was the database environment you use not liste...
# DatabaseWantEntry     Was the database environment you want to use n...
# PlatformChoice        Did you work with cloud platforms, containeriz...
# Platform              Which <b>cloud platforms, containerization/orc...
# PlatformHaveEntry     Was the cloud platforms, containerization/orch...
# PlatformWantEntry     Was the cloud platforms, containerization/orch...
# WebframeChoice        Did you work with web frameworks and web techn...
# Webframe              Which <b>web frameworks and web technologies</...
# WebframeHaveEntry     Were the web frameworks and web technologies y...
# WebframeWantEntry     Were the web frameworks and web technologies y...
# DevEnvsChoice         Did you work with development environments or ...
# DevEnvs               Which <strong>development environments and AI-...
# DevEnvHaveEntry       Was the developer environment or AI-enabled co...
# DevEnvWantEntry       Was the developer environment or AI-enabled co...
# SOTags                Which rising technology of the added as <b>new...
# SOTagsHaveEntry       Was the new tag on Stack Overflow (i.e. added ...
# SOTagsWant Entry      Was the new tag on Stack Overflow (i.e. added ...
# OpSys                 What is the primary <b>operating system</b> in...
# OfficeStackAsync      Which <b>collaborative work management and/or ...
# OfficeStackHaveEntry  Was the collaborative work management and/or c...
# OfficeStackWantEntry  Was the collaborative work management and/or c...
# CommPlatform          Which <b>community platforms</b> have you util...
# CommPlatformHaveEntr  Was the community platform you use not listed ...
# CommPlatformWantEntr  Was the community platform you want to use not...
# AIModelsChoice        Did you utilize or integrate specific Large La...
# AIModels              Which <b>LLM models for AI tools</b> have you ...
# AIModelsHaveEntry     Was the LLM model for AI tools you use not lis...
# AIModelsWantEntry     Was the LLM model for AI tools you want to use...
# SOAccount                         Do you have a Stack Overflow account?
# SOVisitFreq           How frequently would you say you visit Stack O...
# SODuration                       How long have you used Stack Overflow?
# SOPartFreq            How frequently would you say you participate i...
# SO_Dev_Content        Whether it be to solve a problem, for career g...
# SOComm                Do you consider yourself a member of the Stack...
# SOFriction            When you visit Stack Overflow, how often is it...
# AISelect              Do you currently use AI tools in your developm...
# AISent                How favorable is your stance on using AI tools...
# AIAcc                 How much do you trust the accuracy of the outp...
# AIComplex             How well do the AI tools you use in your devel...
# AITool                Which parts of your development workflow are y...
# AIFrustration         When using AI tools, which of the following pr...
# AIExplain             In your own words, is &quot;vibe coding&quot; ...
# AIAgents              Are you using AI agents in your work (developm...
# AIAgentChange         Have AI tools or AI agents changed how you com...
# AIAgent_Uses          What industry purposes or specific tasks are y...
# AgentUsesGeneral
# AIAgentImpact         To what extent do you agree with the following...
# AIAgentChallenges     To what extent do you agree with the following...
# AIAgentKnowledge      You indicated you use or develop AI agents as ...
# AIAgentKnowWrite      Was the tool or tools for AI agent orchestrati...
# AIAgentOrchestration  You indicated you use or develop AI agents as ...
# AIAgentOrchWrite      Was the tool or tools for AI agent orchestrati...
# AIAgentObserveSecure  You indicated you use or develop AI agents as ...
# AIAgentObsWrite       Was the tool or tools for AI agent observabili...
# AIAgentExternal       You indicated you use or develop AI agents as ...
# AIAgentExtWrite       Was the out-of-the-box agents, copilots or ass...
# AIHuman               In the future, if AI can do most coding tasks,...
# AIOpen                Looking ahead 3–5 years, what skills do you be...
#
#                         type  \
# qname
# TechEndorse_1             RO
# TechEndorse_2             RO
# TechEndorse_3             RO
# TechEndorse_4             RO
# TechEndorse_5             RO
# TechEndorse_6             RO
# TechEndorse_7             RO
# TechEndorse_8             RO
# TechEndorse_9             RO
# TechEndorse_13            RO
# TechEndorse_13_TEXT       RO
# TechOppose_1              RO
# TechOppose_2              RO
# TechOppose_3              RO
# TechOppose_5              RO
# TechOppose_7              RO
# TechOppose_9              RO
# TechOppose_11             RO
# TechOppose_13             RO
# TechOppose_16             RO
# TechOppose_15             RO
# TechOppose_15_TEXT        RO
# JobSatPoints_1            RO
# JobSatPoints_2            RO
# JobSatPoints_16           RO
# JobSatPoints_3            RO
# JobSatPoints_4            RO
# JobSatPoints_5            RO
# JobSatPoints_6            RO
# JobSatPoints_7            RO
# JobSatPoints_8            RO
# JobSatPoints_9            RO
# JobSatPoints_10           RO
# JobSatPoints_11           RO
# JobSatPoints_13           RO
# JobSatPoints_14           RO
# JobSatPoints_15           RO
# JobSatPoints_15_TEXT      RO
# SO_Actions_1              RO
# SO_Actions_16             RO
# SO_Actions_3              RO
# SO_Actions_4              RO
# SO_Actions_5              RO
# SO_Actions_6              RO
# SO_Actions_9              RO
# SO_Actions_7              RO
# SO_Actions_10             RO
# SO_Actions_15             RO
# SO_Actions_15_TEXT        RO
# MainBranch                MC
# Age                       MC
# EdLevel                   MC
# Employment                MC
# EmploymentAddl            MC
# WorkExp                   TE
# LearnCodeChoose           MC
# LearnCode                 MC
# LearnCodeAI               MC
# AILearnHow                MC
# YearsCode                 TE
# DevType                   MC
# OrgSize                   MC
# ICorPM                    MC
# RemoteWork                MC
# PurchaseInfluence         MC
# TechEndorseIntro          MC
# Industry                  MC
# JobSat                    MC
# AIThreat                  MC
# NewRole                   MC
# ToolCountWork             TE
# ToolCountPersonal         TE
# Country                   MC
# Currency                  MC
# CompTotal                 TE
# LanguageChoice            MC
# Language              Matrix
# LanguagesHaveEntry        TE
# LanguagesWantEntry        TE
# DatabaseChoice            MC
# Database              Matrix
# DatabaseHaveEntry         TE
# DatabaseWantEntry         TE
# PlatformChoice            MC
# Platform              Matrix
# PlatformHaveEntry         TE
# PlatformWantEntry         TE
# WebframeChoice            MC
# Webframe              Matrix
# WebframeHaveEntry         TE
# WebframeWantEntry         TE
# DevEnvsChoice             MC
# DevEnvs               Matrix
# DevEnvHaveEntry           TE
# DevEnvWantEntry           TE
# SOTags                Matrix
# SOTagsHaveEntry           TE
# SOTagsWant Entry          TE
# OpSys                 Matrix
# OfficeStackAsync      Matrix
# OfficeStackHaveEntry      TE
# OfficeStackWantEntry      TE
# CommPlatform          Matrix
# CommPlatformHaveEntr      TE
# CommPlatformWantEntr      TE
# AIModelsChoice            MC
# AIModels              Matrix
# AIModelsHaveEntry         TE
# AIModelsWantEntry         TE
# SOAccount                 MC
# SOVisitFreq               MC
# SODuration                MC
# SOPartFreq                MC
# SO_Dev_Content            MC
# SOComm                    MC
# SOFriction                MC
# AISelect                  MC
# AISent                    MC
# AIAcc                     MC
# AIComplex                 MC
# AITool                Matrix
# AIFrustration             MC
# AIExplain                 TE
# AIAgents                  MC
# AIAgentChange             MC
# AIAgent_Uses              MC
# AgentUsesGeneral          MC
# AIAgentImpact         Matrix
# AIAgentChallenges     Matrix
# AIAgentKnowledge          MC
# AIAgentKnowWrite          TE
# AIAgentOrchestration      MC
# AIAgentOrchWrite          TE
# AIAgentObserveSecure      MC
# AIAgentObsWrite           TE
# AIAgentExternal           MC
# AIAgentExtWrite           TE
# AIHuman                   MC
# AIOpen                    TE
#
#                                                                     sub  sq_id
# qname
# TechEndorse_1                   AI integration or AI Agent capabilities    1.0
# TechEndorse_2                                           Easy-to-use API    2.0
# TechEndorse_3                                   Robust and complete API    3.0
# TechEndorse_4                      Customizable and manageable codebase    4.0
# TechEndorse_5                                    Reputation for quality    5.0
# TechEndorse_6                       Connected to an open-source project    6.0
# TechEndorse_7                               Good brand and public image    7.0
# TechEndorse_8                               Reliability and low latency    8.0
# TechEndorse_9                                      Costs are manageable    9.0
# TechEndorse_13                                  Other (please specify):   10.0
# TechEndorse_13_TEXT                      Other (please specify): - Text   13.0
# TechOppose_1                                    Lack of AI or AI agents    1.0
# TechOppose_2                                             Poor usability    2.0
# TechOppose_3                                     Lack of or sub-par API    3.0
# TechOppose_5                                 Inefficient or time-costly    4.0
# TechOppose_7                                        Prohibitive pricing    5.0
# TechOppose_9                               Security or privacy concerns    6.0
# TechOppose_11                       Availability of better alternatives    7.0
# TechOppose_13               Outdated or obsolete technology or features    8.0
# TechOppose_16                                          Ethical concerns    9.0
# TechOppose_15                                   Other (please specify):   10.0
# TechOppose_15_TEXT                       Other (please specify): - Text   15.0
# JobSatPoints_1            Control over the level of quality in projects    1.0
# JobSatPoints_2              Autonomy and trust to manage your own tasks    2.0
# JobSatPoints_16                                   You like your manager    3.0
# JobSatPoints_3                    Collaboration and support from a team    4.0
# JobSatPoints_4                                           Expert mentors    5.0
# JobSatPoints_5        Opportunities to mentor and lead junior-level ...    6.0
# JobSatPoints_6                         Developing specialized expertise    7.0
# JobSatPoints_7                              Solving real-world problems    8.0
# JobSatPoints_8        Job stability and career growth with a single ...    9.0
# JobSatPoints_9        Innovation through solving challenging and com...   10.0
# JobSatPoints_10                 Working with new technologies and tools   11.0
# JobSatPoints_11                            Competitive pay and benefits   12.0
# JobSatPoints_13                    Recognition from peers for your work   13.0
# JobSatPoints_14               Recognition from leadership for your work   14.0
# JobSatPoints_15                                 Other (please specify):   15.0
# JobSatPoints_15_TEXT                     Other (please specify): - Text   15.0
# SO_Actions_1          Browse content related to Q&A posts I recently...    1.0
# SO_Actions_16         Read and/or vote on comments for a Question or...    2.0
# SO_Actions_3                            Bookmark posts to look at later    3.0
# SO_Actions_4          Directly open a Q&A post via search, documenta...    4.0
# SO_Actions_5                                             Ask a question    5.0
# SO_Actions_6                                          Answer a question    6.0
# SO_Actions_9                                       Comment on Q&A posts    7.0
# SO_Actions_7                                  Upvote/Downvote Q&A posts    8.0
# SO_Actions_10                            Use discussion or chat feature    9.0
# SO_Actions_15                                         Other (write in):   10.0
# SO_Actions_15_TEXT                             Other (write in): - Text   15.0
# MainBranch                                                          NaN    NaN
# Age                                                                 NaN    NaN
# EdLevel                                                             NaN    NaN
# Employment                                                          NaN    NaN
# EmploymentAddl                                                      NaN    NaN
# WorkExp                                                             NaN    NaN
# LearnCodeChoose                                                     NaN    NaN
# LearnCode                                                           NaN    NaN
# LearnCodeAI                                                         NaN    NaN
# AILearnHow                                                          NaN    NaN
# YearsCode                                                           NaN    NaN
# DevType                                                             NaN    NaN
# OrgSize                                                             NaN    NaN
# ICorPM                                                              NaN    NaN
# RemoteWork                                                          NaN    NaN
# PurchaseInfluence                                                   NaN    NaN
# TechEndorseIntro                                                    NaN    NaN
# Industry                                                            NaN    NaN
# JobSat                                                              NaN    NaN
# AIThreat                                                            NaN    NaN
# NewRole                                                             NaN    NaN
# ToolCountWork                                                       NaN    NaN
# ToolCountPersonal                                                   NaN    NaN
# Country                                                             NaN    NaN
# Currency                                                            NaN    NaN
# CompTotal                                                           NaN    NaN
# LanguageChoice                                                      NaN    NaN
# Language                                                            NaN    NaN
# LanguagesHaveEntry                                                  NaN    NaN
# LanguagesWantEntry                                                  NaN    NaN
# DatabaseChoice                                                      NaN    NaN
# Database                                                            NaN    NaN
# DatabaseHaveEntry                                                   NaN    NaN
# DatabaseWantEntry                                                   NaN    NaN
# PlatformChoice                                                      NaN    NaN
# Platform                                                            NaN    NaN
# PlatformHaveEntry                                                   NaN    NaN
# PlatformWantEntry                                                   NaN    NaN
# WebframeChoice                                                      NaN    NaN
# Webframe                                                            NaN    NaN
# WebframeHaveEntry                                                   NaN    NaN
# WebframeWantEntry                                                   NaN    NaN
# DevEnvsChoice                                                       NaN    NaN
# DevEnvs                                                             NaN    NaN
# DevEnvHaveEntry                                                     NaN    NaN
# DevEnvWantEntry                                                     NaN    NaN
# SOTags                                                              NaN    NaN
# SOTagsHaveEntry                                                     NaN    NaN
# SOTagsWant Entry                                                    NaN    NaN
# OpSys                                                               NaN    NaN
# OfficeStackAsync                                                    NaN    NaN
# OfficeStackHaveEntry                                                NaN    NaN
# OfficeStackWantEntry                                                NaN    NaN
# CommPlatform                                                        NaN    NaN
# CommPlatformHaveEntr                                                NaN    NaN
# CommPlatformWantEntr                                                NaN    NaN
# AIModelsChoice                                                      NaN    NaN
# AIModels                                                            NaN    NaN
# AIModelsHaveEntry                                                   NaN    NaN
# AIModelsWantEntry                                                   NaN    NaN
# SOAccount                                                           NaN    NaN
# SOVisitFreq                                                         NaN    NaN
# SODuration                                                          NaN    NaN
# SOPartFreq                                                          NaN    NaN
# SO_Dev_Content                                                      NaN    NaN
# SOComm                                                              NaN    NaN
# SOFriction                                                          NaN    NaN
# AISelect                                                            NaN    NaN
# AISent                                                              NaN    NaN
# AIAcc                                                               NaN    NaN
# AIComplex                                                           NaN    NaN
# AITool                                                              NaN    NaN
# AIFrustration                                                       NaN    NaN
# AIExplain                                                           NaN    NaN
# AIAgents                                                            NaN    NaN
# AIAgentChange                                                       NaN    NaN
# AIAgent_Uses                                                        NaN    NaN
# AgentUsesGeneral                                                    NaN    NaN
# AIAgentImpact                                                       NaN    NaN
# AIAgentChallenges                                                   NaN    NaN
# AIAgentKnowledge                                                    NaN    NaN
# AIAgentKnowWrite                                                    NaN    NaN
# AIAgentOrchestration                                                NaN    NaN
# AIAgentOrchWrite                                                    NaN    NaN
# AIAgentObserveSecure                                                NaN    NaN
# AIAgentObsWrite                                                     NaN    NaN
# AIAgentExternal                                                     NaN    NaN
# AIAgentExtWrite                                                     NaN    NaN
# AIHuman                                                             NaN    NaN
# AIOpen                                                              NaN    NaN

# %%
schema_df.loc["Employment"]
# Out:
# qid                                                      QID7
# question    Which of the following best describes your cur...
# type                                                       MC
# sub                                                       NaN
# sq_id                                                     NaN
# Name: Employment, dtype: object

# %%
schema_df.loc["Employment", "question"]
# Out:
# 'Which of the following best describes your current employment status?<br>'

# %%
schema_df.sort_index()
# Out:
#                          qid  \
# qname
# AIAcc                  QID80
# AIAgentChallenges      QID88
# AIAgentChange          QID83
# AIAgentExtWrite       QID104
# AIAgentExternal        QID92
# AIAgentImpact          QID87
# AIAgentKnowWrite      QID107
# AIAgentKnowledge       QID89
# AIAgentObsWrite       QID103
# AIAgentObserveSecure   QID91
# AIAgentOrchWrite      QID102
# AIAgentOrchestration   QID90
# AIAgent_Uses           QID86
# AIAgents               QID85
# AIComplex              QID81
# AIExplain              QID84
# AIFrustration          QID99
# AIHuman               QID100
# AILearnHow             QID32
# AIModels               QID43
# AIModelsChoice         QID50
# AIModelsHaveEntry      QID68
# AIModelsWantEntry      QID69
# AIOpen                 QID93
# AISelect               QID78
# AISent                 QID79
# AIThreat               QID28
# AITool                 QID82
# Age                     QID4
# AgentUsesGeneral      QID106
# CommPlatform           QID42
# CommPlatformHaveEntr   QID66
# CommPlatformWantEntr   QID67
# CompTotal              QID22
# Country                QID20
# Currency               QID21
# Database               QID35
# DatabaseChoice         QID45
# DatabaseHaveEntry      QID54
# DatabaseWantEntry      QID55
# DevEnvHaveEntry        QID60
# DevEnvWantEntry        QID61
# DevEnvs                QID38
# DevEnvsChoice          QID48
# DevType                QID15
# EdLevel                 QID9
# Employment              QID7
# EmploymentAddl          QID8
# ICorPM                 QID23
# Industry               QID25
# JobSat                 QID26
# JobSatPoints_1         QID27
# JobSatPoints_10        QID27
# JobSatPoints_11        QID27
# JobSatPoints_13        QID27
# JobSatPoints_14        QID27
# JobSatPoints_15        QID27
# JobSatPoints_15_TEXT   QID27
# JobSatPoints_16        QID27
# JobSatPoints_2         QID27
# JobSatPoints_3         QID27
# JobSatPoints_4         QID27
# JobSatPoints_5         QID27
# JobSatPoints_6         QID27
# JobSatPoints_7         QID27
# JobSatPoints_8         QID27
# JobSatPoints_9         QID27
# Language               QID34
# LanguageChoice         QID44
# LanguagesHaveEntry     QID51
# LanguagesWantEntry     QID52
# LearnCode              QID11
# LearnCodeAI            QID12
# LearnCodeChoose        QID10
# MainBranch              QID3
# NewRole                QID29
# OfficeStackAsync       QID41
# OfficeStackHaveEntry   QID64
# OfficeStackWantEntry   QID65
# OpSys                  QID40
# OrgSize                QID16
# Platform               QID36
# PlatformChoice         QID46
# PlatformHaveEntry      QID56
# PlatformWantEntry      QID57
# PurchaseInfluence      QID17
# RemoteWork             QID24
# SOAccount              QID72
# SOComm                 QID77
# SODuration             QID71
# SOFriction             QID97
# SOPartFreq             QID73
# SOTags                 QID39
# SOTagsHaveEntry        QID62
# SOTagsWant Entry       QID63
# SOVisitFreq            QID70
# SO_Actions_1           QID76
# SO_Actions_10          QID76
# SO_Actions_15          QID76
# SO_Actions_15_TEXT     QID76
# SO_Actions_16          QID76
# SO_Actions_3           QID76
# SO_Actions_4           QID76
# SO_Actions_5           QID76
# SO_Actions_6           QID76
# SO_Actions_7           QID76
# SO_Actions_9           QID76
# SO_Dev_Content         QID75
# TechEndorseIntro       QID33
# TechEndorse_1          QID18
# TechEndorse_13         QID18
# TechEndorse_13_TEXT    QID18
# TechEndorse_2          QID18
# TechEndorse_3          QID18
# TechEndorse_4          QID18
# TechEndorse_5          QID18
# TechEndorse_6          QID18
# TechEndorse_7          QID18
# TechEndorse_8          QID18
# TechEndorse_9          QID18
# TechOppose_1           QID19
# TechOppose_11          QID19
# TechOppose_13          QID19
# TechOppose_15          QID19
# TechOppose_15_TEXT     QID19
# TechOppose_16          QID19
# TechOppose_2           QID19
# TechOppose_3           QID19
# TechOppose_5           QID19
# TechOppose_7           QID19
# TechOppose_9           QID19
# ToolCountPersonal      QID31
# ToolCountWork          QID30
# Webframe               QID37
# WebframeChoice         QID47
# WebframeHaveEntry      QID58
# WebframeWantEntry      QID59
# WorkExp                QID14
# YearsCode              QID13
#
#                                                                question  \
# qname
# AIAcc                 How much do you trust the accuracy of the outp...
# AIAgentChallenges     To what extent do you agree with the following...
# AIAgentChange         Have AI tools or AI agents changed how you com...
# AIAgentExtWrite       Was the out-of-the-box agents, copilots or ass...
# AIAgentExternal       You indicated you use or develop AI agents as ...
# AIAgentImpact         To what extent do you agree with the following...
# AIAgentKnowWrite      Was the tool or tools for AI agent orchestrati...
# AIAgentKnowledge      You indicated you use or develop AI agents as ...
# AIAgentObsWrite       Was the tool or tools for AI agent observabili...
# AIAgentObserveSecure  You indicated you use or develop AI agents as ...
# AIAgentOrchWrite      Was the tool or tools for AI agent orchestrati...
# AIAgentOrchestration  You indicated you use or develop AI agents as ...
# AIAgent_Uses          What industry purposes or specific tasks are y...
# AIAgents              Are you using AI agents in your work (developm...
# AIComplex             How well do the AI tools you use in your devel...
# AIExplain             In your own words, is &quot;vibe coding&quot; ...
# AIFrustration         When using AI tools, which of the following pr...
# AIHuman               In the future, if AI can do most coding tasks,...
# AILearnHow            How did you learn to code for AI in the past y...
# AIModels              Which <b>LLM models for AI tools</b> have you ...
# AIModelsChoice        Did you utilize or integrate specific Large La...
# AIModelsHaveEntry     Was the LLM model for AI tools you use not lis...
# AIModelsWantEntry     Was the LLM model for AI tools you want to use...
# AIOpen                Looking ahead 3–5 years, what skills do you be...
# AISelect              Do you currently use AI tools in your developm...
# AISent                How favorable is your stance on using AI tools...
# AIThreat              Do you believe AI is a threat to your current ...
# AITool                Which parts of your development workflow are y...
# Age                                                   What is your age?
# AgentUsesGeneral
# CommPlatform          Which <b>community platforms</b> have you util...
# CommPlatformHaveEntr  Was the community platform you use not listed ...
# CommPlatformWantEntr  Was the community platform you want to use not...
# CompTotal             What is your current total <b>annual</b> compe...
# Country                                              Where do you live?
# Currency              Which currency do you use day-to-day? If your ...
# Database              Which <b>database environments </b>have you do...
# DatabaseChoice        Did you work with database environments in the...
# DatabaseHaveEntry     Was the database environment you use not liste...
# DatabaseWantEntry     Was the database environment you want to use n...
# DevEnvHaveEntry       Was the developer environment or AI-enabled co...
# DevEnvWantEntry       Was the developer environment or AI-enabled co...
# DevEnvs               Which <strong>development environments and AI-...
# DevEnvsChoice         Did you work with development environments or ...
# DevType               Which of the following describes your current ...
# EdLevel               Which of the following best describes the high...
# Employment            Which of the following best describes your cur...
# EmploymentAddl        Which of the following <strong>additional</str...
# ICorPM                Are you an individual contributor or people ma...
# Industry                              What industry do you work for in?
# JobSat                How satisfied are you in your current professi...
# JobSatPoints_1        Rank the following attributes of your current ...
# JobSatPoints_10       Rank the following attributes of your current ...
# JobSatPoints_11       Rank the following attributes of your current ...
# JobSatPoints_13       Rank the following attributes of your current ...
# JobSatPoints_14       Rank the following attributes of your current ...
# JobSatPoints_15       Rank the following attributes of your current ...
# JobSatPoints_15_TEXT  Rank the following attributes of your current ...
# JobSatPoints_16       Rank the following attributes of your current ...
# JobSatPoints_2        Rank the following attributes of your current ...
# JobSatPoints_3        Rank the following attributes of your current ...
# JobSatPoints_4        Rank the following attributes of your current ...
# JobSatPoints_5        Rank the following attributes of your current ...
# JobSatPoints_6        Rank the following attributes of your current ...
# JobSatPoints_7        Rank the following attributes of your current ...
# JobSatPoints_8        Rank the following attributes of your current ...
# JobSatPoints_9        Rank the following attributes of your current ...
# Language              Which <b>programming, scripting, and markup la...
# LanguageChoice        Did you work with programming, scripting and m...
# LanguagesHaveEntry    Was the programming language you use not liste...
# LanguagesWantEntry    Was the programming language you want to use n...
# LearnCode             How did you learn to code in the past year? Se...
# LearnCodeAI           Did you spend time in the last year learning A...
# LearnCodeChoose       Did you begin learning to code or learn a new ...
# MainBranch            Are you someone who writes code? Please select...
# NewRole               Have you considered a career change or transit...
# OfficeStackAsync      Which <b>collaborative work management and/or ...
# OfficeStackHaveEntry  Was the collaborative work management and/or c...
# OfficeStackWantEntry  Was the collaborative work management and/or c...
# OpSys                 What is the primary <b>operating system</b> in...
# OrgSize               Approximately how many people are employed by ...
# Platform              Which <b>cloud platforms, containerization/orc...
# PlatformChoice        Did you work with cloud platforms, containeriz...
# PlatformHaveEntry     Was the cloud platforms, containerization/orch...
# PlatformWantEntry     Was the cloud platforms, containerization/orch...
# PurchaseInfluence     Have you <strong>influenced or endorsed</stron...
# RemoteWork            Which best describes your current work situation?
# SOAccount                         Do you have a Stack Overflow account?
# SOComm                Do you consider yourself a member of the Stack...
# SODuration                       How long have you used Stack Overflow?
# SOFriction            When you visit Stack Overflow, how often is it...
# SOPartFreq            How frequently would you say you participate i...
# SOTags                Which rising technology of the added as <b>new...
# SOTagsHaveEntry       Was the new tag on Stack Overflow (i.e. added ...
# SOTagsWant Entry      Was the new tag on Stack Overflow (i.e. added ...
# SOVisitFreq           How frequently would you say you visit Stack O...
# SO_Actions_1          When visiting Stack Overflow, which following ...
# SO_Actions_10         When visiting Stack Overflow, which following ...
# SO_Actions_15         When visiting Stack Overflow, which following ...
# SO_Actions_15_TEXT    When visiting Stack Overflow, which following ...
# SO_Actions_16         When visiting Stack Overflow, which following ...
# SO_Actions_3          When visiting Stack Overflow, which following ...
# SO_Actions_4          When visiting Stack Overflow, which following ...
# SO_Actions_5          When visiting Stack Overflow, which following ...
# SO_Actions_6          When visiting Stack Overflow, which following ...
# SO_Actions_7          When visiting Stack Overflow, which following ...
# SO_Actions_9          When visiting Stack Overflow, which following ...
# SO_Dev_Content        Whether it be to solve a problem, for career g...
# TechEndorseIntro      When you&rsquo;re in a position to <strong>inf...
# TechEndorse_1         What attracts you to a technology or causes yo...
# TechEndorse_13        What attracts you to a technology or causes yo...
# TechEndorse_13_TEXT   What attracts you to a technology or causes yo...
# TechEndorse_2         What attracts you to a technology or causes yo...
# TechEndorse_3         What attracts you to a technology or causes yo...
# TechEndorse_4         What attracts you to a technology or causes yo...
# TechEndorse_5         What attracts you to a technology or causes yo...
# TechEndorse_6         What attracts you to a technology or causes yo...
# TechEndorse_7         What attracts you to a technology or causes yo...
# TechEndorse_8         What attracts you to a technology or causes yo...
# TechEndorse_9         What attracts you to a technology or causes yo...
# TechOppose_1          What would turn you off or cause you to reject...
# TechOppose_11         What would turn you off or cause you to reject...
# TechOppose_13         What would turn you off or cause you to reject...
# TechOppose_15         What would turn you off or cause you to reject...
# TechOppose_15_TEXT    What would turn you off or cause you to reject...
# TechOppose_16         What would turn you off or cause you to reject...
# TechOppose_2          What would turn you off or cause you to reject...
# TechOppose_3          What would turn you off or cause you to reject...
# TechOppose_5          What would turn you off or cause you to reject...
# TechOppose_7          What would turn you off or cause you to reject...
# TechOppose_9          What would turn you off or cause you to reject...
# ToolCountPersonal     <b></b>For your <b>side projects or other pers...
# ToolCountWork         For your <b>primary work role</b> (student, de...
# Webframe              Which <b>web frameworks and web technologies</...
# WebframeChoice        Did you work with web frameworks and web techn...
# WebframeHaveEntry     Were the web frameworks and web technologies y...
# WebframeWantEntry     Were the web frameworks and web technologies y...
# WorkExp               How many years of professional work experience...
# YearsCode             Including any education, how many years have y...
#
#                         type  \
# qname
# AIAcc                     MC
# AIAgentChallenges     Matrix
# AIAgentChange             MC
# AIAgentExtWrite           TE
# AIAgentExternal           MC
# AIAgentImpact         Matrix
# AIAgentKnowWrite          TE
# AIAgentKnowledge          MC
# AIAgentObsWrite           TE
# AIAgentObserveSecure      MC
# AIAgentOrchWrite          TE
# AIAgentOrchestration      MC
# AIAgent_Uses              MC
# AIAgents                  MC
# AIComplex                 MC
# AIExplain                 TE
# AIFrustration             MC
# AIHuman                   MC
# AILearnHow                MC
# AIModels              Matrix
# AIModelsChoice            MC
# AIModelsHaveEntry         TE
# AIModelsWantEntry         TE
# AIOpen                    TE
# AISelect                  MC
# AISent                    MC
# AIThreat                  MC
# AITool                Matrix
# Age                       MC
# AgentUsesGeneral          MC
# CommPlatform          Matrix
# CommPlatformHaveEntr      TE
# CommPlatformWantEntr      TE
# CompTotal                 TE
# Country                   MC
# Currency                  MC
# Database              Matrix
# DatabaseChoice            MC
# DatabaseHaveEntry         TE
# DatabaseWantEntry         TE
# DevEnvHaveEntry           TE
# DevEnvWantEntry           TE
# DevEnvs               Matrix
# DevEnvsChoice             MC
# DevType                   MC
# EdLevel                   MC
# Employment                MC
# EmploymentAddl            MC
# ICorPM                    MC
# Industry                  MC
# JobSat                    MC
# JobSatPoints_1            RO
# JobSatPoints_10           RO
# JobSatPoints_11           RO
# JobSatPoints_13           RO
# JobSatPoints_14           RO
# JobSatPoints_15           RO
# JobSatPoints_15_TEXT      RO
# JobSatPoints_16           RO
# JobSatPoints_2            RO
# JobSatPoints_3            RO
# JobSatPoints_4            RO
# JobSatPoints_5            RO
# JobSatPoints_6            RO
# JobSatPoints_7            RO
# JobSatPoints_8            RO
# JobSatPoints_9            RO
# Language              Matrix
# LanguageChoice            MC
# LanguagesHaveEntry        TE
# LanguagesWantEntry        TE
# LearnCode                 MC
# LearnCodeAI               MC
# LearnCodeChoose           MC
# MainBranch                MC
# NewRole                   MC
# OfficeStackAsync      Matrix
# OfficeStackHaveEntry      TE
# OfficeStackWantEntry      TE
# OpSys                 Matrix
# OrgSize                   MC
# Platform              Matrix
# PlatformChoice            MC
# PlatformHaveEntry         TE
# PlatformWantEntry         TE
# PurchaseInfluence         MC
# RemoteWork                MC
# SOAccount                 MC
# SOComm                    MC
# SODuration                MC
# SOFriction                MC
# SOPartFreq                MC
# SOTags                Matrix
# SOTagsHaveEntry           TE
# SOTagsWant Entry          TE
# SOVisitFreq               MC
# SO_Actions_1              RO
# SO_Actions_10             RO
# SO_Actions_15             RO
# SO_Actions_15_TEXT        RO
# SO_Actions_16             RO
# SO_Actions_3              RO
# SO_Actions_4              RO
# SO_Actions_5              RO
# SO_Actions_6              RO
# SO_Actions_7              RO
# SO_Actions_9              RO
# SO_Dev_Content            MC
# TechEndorseIntro          MC
# TechEndorse_1             RO
# TechEndorse_13            RO
# TechEndorse_13_TEXT       RO
# TechEndorse_2             RO
# TechEndorse_3             RO
# TechEndorse_4             RO
# TechEndorse_5             RO
# TechEndorse_6             RO
# TechEndorse_7             RO
# TechEndorse_8             RO
# TechEndorse_9             RO
# TechOppose_1              RO
# TechOppose_11             RO
# TechOppose_13             RO
# TechOppose_15             RO
# TechOppose_15_TEXT        RO
# TechOppose_16             RO
# TechOppose_2              RO
# TechOppose_3              RO
# TechOppose_5              RO
# TechOppose_7              RO
# TechOppose_9              RO
# ToolCountPersonal         TE
# ToolCountWork             TE
# Webframe              Matrix
# WebframeChoice            MC
# WebframeHaveEntry         TE
# WebframeWantEntry         TE
# WorkExp                   TE
# YearsCode                 TE
#
#                                                                     sub  sq_id
# qname
# AIAcc                                                               NaN    NaN
# AIAgentChallenges                                                   NaN    NaN
# AIAgentChange                                                       NaN    NaN
# AIAgentExtWrite                                                     NaN    NaN
# AIAgentExternal                                                     NaN    NaN
# AIAgentImpact                                                       NaN    NaN
# AIAgentKnowWrite                                                    NaN    NaN
# AIAgentKnowledge                                                    NaN    NaN
# AIAgentObsWrite                                                     NaN    NaN
# AIAgentObserveSecure                                                NaN    NaN
# AIAgentOrchWrite                                                    NaN    NaN
# AIAgentOrchestration                                                NaN    NaN
# AIAgent_Uses                                                        NaN    NaN
# AIAgents                                                            NaN    NaN
# AIComplex                                                           NaN    NaN
# AIExplain                                                           NaN    NaN
# AIFrustration                                                       NaN    NaN
# AIHuman                                                             NaN    NaN
# AILearnHow                                                          NaN    NaN
# AIModels                                                            NaN    NaN
# AIModelsChoice                                                      NaN    NaN
# AIModelsHaveEntry                                                   NaN    NaN
# AIModelsWantEntry                                                   NaN    NaN
# AIOpen                                                              NaN    NaN
# AISelect                                                            NaN    NaN
# AISent                                                              NaN    NaN
# AIThreat                                                            NaN    NaN
# AITool                                                              NaN    NaN
# Age                                                                 NaN    NaN
# AgentUsesGeneral                                                    NaN    NaN
# CommPlatform                                                        NaN    NaN
# CommPlatformHaveEntr                                                NaN    NaN
# CommPlatformWantEntr                                                NaN    NaN
# CompTotal                                                           NaN    NaN
# Country                                                             NaN    NaN
# Currency                                                            NaN    NaN
# Database                                                            NaN    NaN
# DatabaseChoice                                                      NaN    NaN
# DatabaseHaveEntry                                                   NaN    NaN
# DatabaseWantEntry                                                   NaN    NaN
# DevEnvHaveEntry                                                     NaN    NaN
# DevEnvWantEntry                                                     NaN    NaN
# DevEnvs                                                             NaN    NaN
# DevEnvsChoice                                                       NaN    NaN
# DevType                                                             NaN    NaN
# EdLevel                                                             NaN    NaN
# Employment                                                          NaN    NaN
# EmploymentAddl                                                      NaN    NaN
# ICorPM                                                              NaN    NaN
# Industry                                                            NaN    NaN
# JobSat                                                              NaN    NaN
# JobSatPoints_1            Control over the level of quality in projects    1.0
# JobSatPoints_10                 Working with new technologies and tools   11.0
# JobSatPoints_11                            Competitive pay and benefits   12.0
# JobSatPoints_13                    Recognition from peers for your work   13.0
# JobSatPoints_14               Recognition from leadership for your work   14.0
# JobSatPoints_15                                 Other (please specify):   15.0
# JobSatPoints_15_TEXT                     Other (please specify): - Text   15.0
# JobSatPoints_16                                   You like your manager    3.0
# JobSatPoints_2              Autonomy and trust to manage your own tasks    2.0
# JobSatPoints_3                    Collaboration and support from a team    4.0
# JobSatPoints_4                                           Expert mentors    5.0
# JobSatPoints_5        Opportunities to mentor and lead junior-level ...    6.0
# JobSatPoints_6                         Developing specialized expertise    7.0
# JobSatPoints_7                              Solving real-world problems    8.0
# JobSatPoints_8        Job stability and career growth with a single ...    9.0
# JobSatPoints_9        Innovation through solving challenging and com...   10.0
# Language                                                            NaN    NaN
# LanguageChoice                                                      NaN    NaN
# LanguagesHaveEntry                                                  NaN    NaN
# LanguagesWantEntry                                                  NaN    NaN
# LearnCode                                                           NaN    NaN
# LearnCodeAI                                                         NaN    NaN
# LearnCodeChoose                                                     NaN    NaN
# MainBranch                                                          NaN    NaN
# NewRole                                                             NaN    NaN
# OfficeStackAsync                                                    NaN    NaN
# OfficeStackHaveEntry                                                NaN    NaN
# OfficeStackWantEntry                                                NaN    NaN
# OpSys                                                               NaN    NaN
# OrgSize                                                             NaN    NaN
# Platform                                                            NaN    NaN
# PlatformChoice                                                      NaN    NaN
# PlatformHaveEntry                                                   NaN    NaN
# PlatformWantEntry                                                   NaN    NaN
# PurchaseInfluence                                                   NaN    NaN
# RemoteWork                                                          NaN    NaN
# SOAccount                                                           NaN    NaN
# SOComm                                                              NaN    NaN
# SODuration                                                          NaN    NaN
# SOFriction                                                          NaN    NaN
# SOPartFreq                                                          NaN    NaN
# SOTags                                                              NaN    NaN
# SOTagsHaveEntry                                                     NaN    NaN
# SOTagsWant Entry                                                    NaN    NaN
# SOVisitFreq                                                         NaN    NaN
# SO_Actions_1          Browse content related to Q&A posts I recently...    1.0
# SO_Actions_10                            Use discussion or chat feature    9.0
# SO_Actions_15                                         Other (write in):   10.0
# SO_Actions_15_TEXT                             Other (write in): - Text   15.0
# SO_Actions_16         Read and/or vote on comments for a Question or...    2.0
# SO_Actions_3                            Bookmark posts to look at later    3.0
# SO_Actions_4          Directly open a Q&A post via search, documenta...    4.0
# SO_Actions_5                                             Ask a question    5.0
# SO_Actions_6                                          Answer a question    6.0
# SO_Actions_7                                  Upvote/Downvote Q&A posts    8.0
# SO_Actions_9                                       Comment on Q&A posts    7.0
# SO_Dev_Content                                                      NaN    NaN
# TechEndorseIntro                                                    NaN    NaN
# TechEndorse_1                   AI integration or AI Agent capabilities    1.0
# TechEndorse_13                                  Other (please specify):   10.0
# TechEndorse_13_TEXT                      Other (please specify): - Text   13.0
# TechEndorse_2                                           Easy-to-use API    2.0
# TechEndorse_3                                   Robust and complete API    3.0
# TechEndorse_4                      Customizable and manageable codebase    4.0
# TechEndorse_5                                    Reputation for quality    5.0
# TechEndorse_6                       Connected to an open-source project    6.0
# TechEndorse_7                               Good brand and public image    7.0
# TechEndorse_8                               Reliability and low latency    8.0
# TechEndorse_9                                      Costs are manageable    9.0
# TechOppose_1                                    Lack of AI or AI agents    1.0
# TechOppose_11                       Availability of better alternatives    7.0
# TechOppose_13               Outdated or obsolete technology or features    8.0
# TechOppose_15                                   Other (please specify):   10.0
# TechOppose_15_TEXT                       Other (please specify): - Text   15.0
# TechOppose_16                                          Ethical concerns    9.0
# TechOppose_2                                             Poor usability    2.0
# TechOppose_3                                     Lack of or sub-par API    3.0
# TechOppose_5                                 Inefficient or time-costly    4.0
# TechOppose_7                                        Prohibitive pricing    5.0
# TechOppose_9                               Security or privacy concerns    6.0
# ToolCountPersonal                                                   NaN    NaN
# ToolCountWork                                                       NaN    NaN
# Webframe                                                            NaN    NaN
# WebframeChoice                                                      NaN    NaN
# WebframeHaveEntry                                                   NaN    NaN
# WebframeWantEntry                                                   NaN    NaN
# WorkExp                                                             NaN    NaN
# YearsCode                                                           NaN    NaN

# %%
code_experience = df["YearsCode"] > 50

# %%
df.loc[code_experience]
# Out:
#                                                    MainBranch  \
# ResponseId
# 176         I used to be a developer by profession, but no...
# 259                               I code primarily as a hobby
# 426                            I am a developer by profession
# 937         I work with developers or my work supports dev...
# 954                               I code primarily as a hobby
# ...                                                       ...
# 47602       I am not primarily a developer, but I write co...
# 47981                             I code primarily as a hobby
# 48177       I am not primarily a developer, but I write co...
# 48209                          I am a developer by profession
# 48300                          I am a developer by profession
#
#                           Age  \
# ResponseId
# 176         65 years or older
# 259         65 years or older
# 426         65 years or older
# 937         65 years or older
# 954           55-64 years old
# ...                       ...
# 47602         25-34 years old
# 47981       65 years or older
# 48177       65 years or older
# 48209       65 years or older
# 48300         18-24 years old
#
#                                                       EdLevel  \
# ResponseId
# 176              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 259           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 426              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 937              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 954              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 47602         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 47981          Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 48177         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 48209                                 Other (please specify):
# 48300       Secondary school (e.g. American high school, G...
#
#                                                    Employment  \
# ResponseId
# 176                                                   Retired
# 259                                                   Retired
# 426                                                  Employed
# 937                                                  Employed
# 954                                                   Retired
# ...                                                       ...
# 47602                                                 Student
# 47981       Independent contractor, freelancer, or self-em...
# 48177                                                 Retired
# 48209                                                 Retired
# 48300                                                 Student
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 176         Transitioning to retirement (gradually reducin...     54.0
# 259                                         None of the above     39.0
# 426                                  Volunteering (regularly)     46.0
# 937                                         None of the above     51.0
# 954                                         None of the above     34.0
# ...                                                       ...      ...
# 47602             Engaged in paid work (10-19 hours per week)    100.0
# 47981       Volunteering (regularly);Transitioning to reti...     55.0
# 48177       Volunteering (regularly);Attending school (ful...     38.0
# 48209       Caring for dependents (children, elderly, etc....     69.0
# 48300       Caring for dependents (children, elderly, etc....      1.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 176         No, I am not new to coding and did not learn n...
# 259         Yes, I am not new to coding but am learning ne...
# 426         Yes, I am not new to coding but am learning ne...
# 937         Yes, I am not new to coding but am learning ne...
# 954         No, I am not new to coding and did not learn n...
# ...                                                       ...
# 47602          Yes, I am new to coding or currently a student
# 47981       Yes, I am not new to coding but am learning ne...
# 48177       Yes, I am not new to coding but am learning ne...
# 48209       No, I am not new to coding and did not learn n...
# 48300          Yes, I am new to coding or currently a student
#
#                                                     LearnCode  \
# ResponseId
# 176                                                       NaN
# 259         Other online resources (e.g. standard search, ...
# 426         Online Courses or Certification (includes all ...
# 937         Online Courses or Certification (includes all ...
# 954                                                       NaN
# ...                                                       ...
# 47602                        Colleague or on-the-job training
# 47981       Other online resources (e.g. standard search, ...
# 48177       Online Courses or Certification (includes all ...
# 48209                                                     NaN
# 48300       Online Courses or Certification (includes all ...
#
#                                                   LearnCodeAI  \
# ResponseId
# 176         No, I learned something that was not related t...
# 259         Yes, I learned how to use AI-enabled tools for...
# 426         Yes, I learned how to use AI-enabled tools for...
# 937         No, I learned something that was not related t...
# 954         No, I didn't spend time learning in the past year
# ...                                                       ...
# 47602       Yes, I learned how to use AI-enabled tools req...
# 47981       No, I didn't spend time learning in the past year
# 48177       Yes, I learned how to use AI-enabled tools for...
# 48209       No, I learned something that was not related t...
# 48300       Yes, I learned how to use AI-enabled tools for...
#
#                                                    AILearnHow  YearsCode  \
# ResponseId
# 176                                                       NaN       53.0
# 259         AI CodeGen tools or AI-enabled apps;Technical ...       53.0
# 426                                   Other (please specify):       52.0
# 937                                                       NaN       53.0
# 954                                                       NaN       51.0
# ...                                                       ...        ...
# 47602                              Games or coding challenges      100.0
# 47981                                                     NaN       55.0
# 48177       Other online resources (e.g. standard search, ...       51.0
# 48209                                                     NaN      100.0
# 48300       AI CodeGen tools or AI-enabled apps;Technical ...      100.0
#
#                                      DevType  \
# ResponseId
# 176                     Developer, front-end
# 259                                  Retired
# 426         Architect, software or solutions
# 937          DevOps engineer or professional
# 954                                  Retired
# ...                                      ...
# 47602          Cloud infrastructure engineer
# 47981                Other (please specify):
# 48177                                Retired
# 48209                Other (please specify):
# 48300       Architect, software or solutions
#
#                                                       OrgSize  \
# ResponseId
# 176         Just me - I am a freelancer, sole proprietor, ...
# 259                                                       NaN
# 426                                      100 to 499 employees
# 937                                  10,000 or more employees
# 954                                                       NaN
# ...                                                       ...
# 47602                                10,000 or more employees
# 47981       Just me - I am a freelancer, sole proprietor, ...
# 48177       Just me - I am a freelancer, sole proprietor, ...
# 48209                                                     NaN
# 48300       Just me - I am a freelancer, sole proprietor, ...
#
#                             ICorPM  \
# ResponseId
# 176         Individual contributor
# 259                            NaN
# 426         Individual contributor
# 937         Individual contributor
# 954                            NaN
# ...                            ...
# 47602       Individual contributor
# 47981       Individual contributor
# 48177       Individual contributor
# 48209                          NaN
# 48300                          NaN
#
#                                                    RemoteWork  \
# ResponseId
# 176         Hybrid (some in-person, leans heavy to flexibi...
# 259                                                       NaN
# 426         Hybrid (some in-person, leans heavy to flexibi...
# 937                                                    Remote
# 954                                                       NaN
# ...                                                       ...
# 47602                                               In-person
# 47981                                                  Remote
# 48177                                                  Remote
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                             PurchaseInfluence  \
# ResponseId
# 176         Yes, I influenced the purchase of a substantia...
# 259                                                       NaN
# 426                                                        No
# 937                                                        No
# 954                                                       NaN
# ...                                                       ...
# 47602       Yes, I endorsed a tool that was ultimately not...
# 47981                                                      No
# 48177       Yes, I endorsed a tool that was open-source an...
# 48209                                                     NaN
# 48300       Yes, I influenced the purchase of a tool that ...
#
#             TechEndorseIntro  TechEndorse_1  TechEndorse_2  TechEndorse_3  \
# ResponseId
# 176                     Work           13.0            1.0            2.0
# 259                     Work            8.0            5.0            6.0
# 426                     Work           12.0            8.0            5.0
# 937         Personal Project           13.0            3.0            1.0
# 954         Personal Project           13.0            6.0            1.0
# ...                      ...            ...            ...            ...
# 47602                   Work            7.0            2.0            9.0
# 47981       Personal Project            NaN            NaN            NaN
# 48177       Personal Project            9.0            8.0            7.0
# 48209                    NaN            NaN            NaN            NaN
# 48300                   Work            9.0            2.0            7.0
#
#             TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  \
# ResponseId
# 176                  11.0            3.0            9.0           12.0
# 259                  13.0            2.0            7.0           11.0
# 426                   6.0            2.0           11.0            1.0
# 937                   9.0            5.0           10.0           11.0
# 954                  10.0            2.0            9.0            5.0
# ...                   ...            ...            ...            ...
# 47602                 4.0            3.0            8.0            1.0
# 47981                 NaN            NaN            NaN            NaN
# 48177                 2.0            6.0            1.0            4.0
# 48209                 NaN            NaN            NaN            NaN
# 48300                 5.0            4.0            1.0            6.0
#
#             TechEndorse_8  TechEndorse_9  TechEndorse_13 TechEndorse_13_TEXT  \
# ResponseId
# 176                  10.0            5.0            14.0                 NaN
# 259                   1.0            3.0            14.0                 NaN
# 426                   9.0            4.0            14.0                 NaN
# 937                   2.0            8.0            14.0                 NaN
# 954                   3.0            4.0            14.0                 NaN
# ...                   ...            ...             ...                 ...
# 47602                 6.0            5.0            10.0                 NaN
# 47981                 NaN            NaN             NaN                 NaN
# 48177                 3.0            5.0            10.0                 NaN
# 48209                 NaN            NaN             NaN                 NaN
# 48300                 8.0            3.0            10.0                 NaN
#
#             TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# ResponseId
# 176                 14.0           4.0           8.0          13.0
# 259                  9.0           2.0           6.0           4.0
# 426                  7.0           2.0          10.0           6.0
# 937                 14.0           4.0           9.0           3.0
# 954                 14.0           6.0           8.0           5.0
# ...                  ...           ...           ...           ...
# 47602                8.0           4.0           6.0           5.0
# 47981                NaN           NaN           NaN           NaN
# 48177                5.0           1.0           7.0           3.0
# 48209                NaN           NaN           NaN           NaN
# 48300                NaN           NaN           NaN           NaN
#
#             TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  \
# ResponseId
# 176                  6.0           1.0            2.0            7.0
# 259                  1.0          14.0            3.0            7.0
# 426                  3.0          14.0            1.0           11.0
# 937                  1.0           7.0            2.0           11.0
# 954                  2.0           3.0            1.0            7.0
# ...                  ...           ...            ...            ...
# 47602                1.0           7.0            3.0            9.0
# 47981                NaN           NaN            NaN            NaN
# 48177                6.0           9.0            4.0            2.0
# 48209                NaN           NaN            NaN            NaN
# 48300                NaN           NaN            NaN            NaN
#
#             TechOppose_16  TechOppose_15 TechOppose_15_TEXT  \
# ResponseId
# 176                   9.0           15.0                NaN
# 259                  13.0           15.0                NaN
# 426                  12.0           15.0                NaN
# 937                  13.0           15.0                NaN
# 954                  10.0           15.0                NaN
# ...                   ...            ...                ...
# 47602                 2.0           10.0                NaN
# 47981                 NaN            NaN                NaN
# 48177                 8.0           10.0                NaN
# 48209                 NaN            NaN                NaN
# 48300                 NaN            NaN                NaN
#
#                                               Industry  JobSatPoints_1  \
# ResponseId
# 176                                            Fintech             NaN
# 259                                                NaN             NaN
# 426                               Software Development             1.0
# 937                         Banking/Financial Services             NaN
# 954                                                NaN             NaN
# ...                                                ...             ...
# 47602                                           Other:             NaN
# 47981                                           Other:             NaN
# 48177                             Software Development             NaN
# 48209                                              NaN             NaN
# 48300       Internet, Telecomm or Information Services             7.0
#
#             JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# ResponseId
# 176                    NaN             NaN             NaN             NaN
# 259                    NaN             NaN             NaN             NaN
# 426                   14.0             6.0            10.0             8.0
# 937                    NaN             NaN             NaN             NaN
# 954                    NaN             NaN             NaN             NaN
# ...                    ...             ...             ...             ...
# 47602                  NaN             NaN             NaN             NaN
# 47981                  NaN             NaN             NaN             NaN
# 48177                  NaN             NaN             NaN             NaN
# 48209                  NaN             NaN             NaN             NaN
# 48300                 14.0             6.0             1.0             2.0
#
#             JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# ResponseId
# 176                    NaN             NaN              NaN              NaN
# 259                    NaN             NaN              NaN              NaN
# 426                    7.0            12.0             13.0              4.0
# 937                    NaN             NaN              NaN              NaN
# 954                    NaN             NaN              NaN              NaN
# ...                    ...             ...              ...              ...
# 47602                  NaN             NaN              NaN              NaN
# 47981                  NaN             NaN              NaN              NaN
# 48177                  NaN             NaN              NaN              NaN
# 48209                  NaN             NaN              NaN              NaN
# 48300                  5.0            11.0              9.0             12.0
#
#             JobSatPoints_13  JobSatPoints_14  JobSatPoints_15  \
# ResponseId
# 176                     NaN              NaN              NaN
# 259                     NaN              NaN              NaN
# 426                     9.0             11.0             15.0
# 937                     NaN              NaN              NaN
# 954                     NaN              NaN              NaN
# ...                     ...              ...              ...
# 47602                   NaN              NaN              NaN
# 47981                   NaN              NaN              NaN
# 48177                   NaN              NaN              NaN
# 48209                   NaN              NaN              NaN
# 48300                   3.0             10.0             15.0
#
#             JobSatPoints_16 JobSatPoints_15_TEXT AIThreat  \
# ResponseId
# 176                     NaN                  NaN      NaN
# 259                     NaN                  NaN      NaN
# 426                     5.0                  NaN       No
# 937                     NaN                  NaN       No
# 954                     NaN                  NaN      NaN
# ...                     ...                  ...      ...
# 47602                   NaN                  NaN      Yes
# 47981                   NaN                  NaN       No
# 48177                   NaN                  NaN      NaN
# 48209                   NaN                  NaN      NaN
# 48300                   4.0                  NaN      Yes
#
#                                                       NewRole  ToolCountWork  \
# ResponseId
# 176                                                       NaN            NaN
# 259                                                       NaN            NaN
# 426         I have neither consider or transitioned into a...            6.0
# 937         I have strongly considered changing my career ...            8.0
# 954                                                       NaN            NaN
# ...                                                       ...            ...
# 47602       I have strongly considered changing my career ...          100.0
# 47981                                                     NaN            NaN
# 48177                                                     NaN            NaN
# 48209                                                     NaN            NaN
# 48300       I have strongly considered changing my career ...            NaN
#
#             ToolCountPersonal                   Country  \
# ResponseId
# 176                       3.0                   Germany
# 259                       5.0  United States of America
# 426                       3.0  United States of America
# 937                       4.0  United States of America
# 954                       1.0               Switzerland
# ...                       ...                       ...
# 47602                   100.0                  Viet Nam
# 47981                     NaN                       NaN
# 48177                     5.0  United States of America
# 48209                     NaN                       NaN
# 48300                     NaN                       NaN
#
#                             Currency  CompTotal LanguageChoice  \
# ResponseId
# 176                EUR European Euro    36000.0            NaN
# 259         USD United States dollar        NaN            Yes
# 426         USD United States dollar   195000.0            Yes
# 937         USD United States dollar   144700.0            Yes
# 954                 CHF\tSwiss franc     2000.0            Yes
# ...                              ...        ...            ...
# 47602           VND\tVietnamese dong      100.0            Yes
# 47981                            NaN        NaN            NaN
# 48177       USD United States dollar        NaN            NaN
# 48209                            NaN        NaN            NaN
# 48300                            NaN        NaN            NaN
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 176         Bash/Shell (all shells);Delphi;MATLAB;PHP;SQL;VBA
# 259         Bash/Shell (all shells);HTML/CSS;PHP;PowerShel...
# 426         Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 937               Bash/Shell (all shells);Java;PowerShell;SQL
# 954                                                     Swift
# ...                                                       ...
# 47602       Ada;Assembly;Bash/Shell (all shells);C;C#;C++;...
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 176                                        Delphi;PHP;SQL;VBA
# 259         Bash/Shell (all shells);HTML/CSS;PowerShell;Py...
# 426         Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 937                                            Lua;PowerShell
# 954                                                     Swift
# ...                                                       ...
# 47602                                             MATLAB;Perl
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                               LanguageAdmired  \
# ResponseId
# 176                                        Delphi;PHP;SQL;VBA
# 259         Bash/Shell (all shells);HTML/CSS;PowerShell;Py...
# 426         Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 937                                                PowerShell
# 954                                                     Swift
# ...                                                       ...
# 47602                                             MATLAB;Perl
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                            LanguagesHaveEntry  \
# ResponseId
# 176                                                       NaN
# 259                                                       NaN
# 426         Salesforce Apex, Salesforce VisualForce, Sales...
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                           LanguagesWantEntry DatabaseChoice  \
# ResponseId
# 176                                      NaN            Yes
# 259                                      NaN            Yes
# 426         Salesforce Apex,  Salesforce LWC            Yes
# 937                                      NaN            Yes
# 954                                      NaN             No
# ...                                      ...            ...
# 47602                                    NaN            Yes
# 47981                                    NaN            NaN
# 48177                                    NaN            NaN
# 48209                                    NaN            NaN
# 48300                                    NaN            NaN
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 176         MariaDB;Microsoft Access;Microsoft SQL Server;...
# 259                                            MariaDB;SQLite
# 426                                      Microsoft SQL Server
# 937                                   Microsoft Access;Oracle
# 954                                                       NaN
# ...                                                       ...
# 47602       BigQuery;Cassandra;Dynamodb;Elasticsearch;Micr...
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                        DatabaseWantToWorkWith  \
# ResponseId
# 176                                   Microsoft Access;SQLite
# 259                                            MariaDB;SQLite
# 426                                      Microsoft SQL Server
# 937                                          Microsoft Access
# 954                                                       NaN
# ...                                                       ...
# 47602       Cassandra;Dynamodb;Elasticsearch;Microsoft Access
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                               DatabaseAdmired  \
# ResponseId
# 176                                   Microsoft Access;SQLite
# 259                                            MariaDB;SQLite
# 426                                      Microsoft SQL Server
# 937                                          Microsoft Access
# 954                                                       NaN
# ...                                                       ...
# 47602       Cassandra;Dynamodb;Elasticsearch;Microsoft Access
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#            DatabaseHaveEntry DatabaseWantEntry PlatformChoice  \
# ResponseId
# 176                      NaN               NaN             No
# 259                      NaN               NaN            Yes
# 426                      NaN               NaN            Yes
# 937                      NaN               NaN            Yes
# 954                      NaN               NaN             No
# ...                      ...               ...            ...
# 47602                    NaN               NaN            Yes
# 47981                    NaN               NaN            NaN
# 48177                    NaN               NaN            NaN
# 48209                    NaN               NaN            NaN
# 48300                    NaN               NaN            NaN
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 176                                                       NaN
# 259         Ansible;APT;Chocolatey;Cloudflare;Docker;Googl...
# 426         Docker;Gradle;Make;Maven (build tool);Microsof...
# 937          Amazon Web Services (AWS);Microsoft Azure;Splunk
# 954                                                       NaN
# ...                                                       ...
# 47602                   Amazon Web Services (AWS);Ansible;APT
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                        PlatformWantToWorkWith  \
# ResponseId
# 176                                                       NaN
# 259         Ansible;APT;Chocolatey;Cloudflare;Docker;Googl...
# 426         Docker;Gradle;Make;Maven (build tool);Microsof...
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602                   Amazon Web Services (AWS);Ansible;APT
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                               PlatformAdmired  \
# ResponseId
# 176                                                       NaN
# 259         Ansible;APT;Chocolatey;Cloudflare;Docker;Googl...
# 426         Docker;Gradle;Make;Maven (build tool);Microsof...
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602                   Amazon Web Services (AWS);Ansible;APT
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#            PlatformHaveEntry PlatformWantEntry WebframeChoice  \
# ResponseId
# 176                      NaN               NaN            Yes
# 259                      NaN               NaN            Yes
# 426                      NaN               NaN            Yes
# 937                     Okta               NaN            NaN
# 954                      NaN               NaN             No
# ...                      ...               ...            ...
# 47602                    NaN               NaN            NaN
# 47981                    NaN               NaN            NaN
# 48177                    NaN               NaN            NaN
# 48209                    NaN               NaN            NaN
# 48300                    NaN               NaN            NaN
#
#                                        WebframeHaveWorkedWith  \
# ResponseId
# 176                                                       NaN
# 259                                                     Flask
# 426                                                    jQuery
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602       Angular;ASP.NET;ASP.NET Core;Astro;Blazor;Deno...
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 176                                                       NaN
# 259                                                     Flask
# 426                                                    jQuery
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602       AngularJS;ASP.NET Core;Blazor;Deno;Django;Lara...
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                               WebframeAdmired  \
# ResponseId
# 176                                                       NaN
# 259                                                     Flask
# 426                                                    jQuery
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602       ASP.NET Core;Blazor;Deno;Django;Laravel;Phoeni...
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                     WebframeHaveEntry  \
# ResponseId
# 176                                               NaN
# 259                                               NaN
# 426         Salesforce LWC (Lightning Web COmponents)
# 937                                               NaN
# 954                                               NaN
# ...                                               ...
# 47602                                             100
# 47981                                             NaN
# 48177                                             NaN
# 48209                                             NaN
# 48300                                             NaN
#
#                                     WebframeWantEntry DevEnvsChoice  \
# ResponseId
# 176                                               NaN            No
# 259                                               NaN           Yes
# 426         Salesforce LWC (Lightning Web COmponents)           Yes
# 937                                               NaN           Yes
# 954                                               NaN            No
# ...                                               ...           ...
# 47602                                             100           NaN
# 47981                                             NaN           NaN
# 48177                                             NaN           NaN
# 48209                                             NaN           NaN
# 48300                                             NaN           NaN
#
#                                         DevEnvsHaveWorkedWith  \
# ResponseId
# 176                                                       NaN
# 259         Cline and/or Roo;Cursor;Nano;Notepad++;PyCharm...
# 426                                        Visual Studio Code
# 937                Notepad++;Visual Studio;Visual Studio Code
# 954                                                       NaN
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                         DevEnvsWantToWorkWith  \
# ResponseId
# 176                                                       NaN
# 259         Cline and/or Roo;Nano;Notepad++;Visual Studio ...
# 426                                        Visual Studio Code
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                                DevEnvsAdmired DevEnvHaveEntry  \
# ResponseId
# 176                                                       NaN             NaN
# 259         Cline and/or Roo;Nano;Notepad++;Visual Studio ...             NaN
# 426                                        Visual Studio Code             NaN
# 937                                                       NaN             NaN
# 954                                                       NaN             NaN
# ...                                                       ...             ...
# 47602                                                     NaN             NaN
# 47981                                                     NaN             NaN
# 48177                                                     NaN             NaN
# 48209                                                     NaN             NaN
# 48300                                                     NaN             NaN
#
#            DevEnvWantEntry                               SOTagsHaveWorkedWith  \
# ResponseId
# 176                    NaN                                  Delphi 12+ Athens
# 259                    NaN                                                NaN
# 426                    NaN                                                NaN
# 937                    NaN                                                NaN
# 954                    NaN                                                NaN
# ...                    ...                                                ...
# 47602                  NaN  Tailwind CSS 4;SwiftData;Amazon Bedrock;Micros...
# 47981                  NaN                                                NaN
# 48177                  NaN                                                NaN
# 48209                  NaN                                                NaN
# 48300                  NaN                                                NaN
#
#                                          SOTagsWantToWorkWith  \
# ResponseId
# 176                                         Delphi 12+ Athens
# 259                                                       NaN
# 426                                                       NaN
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602       Tailwind CSS 4;SwiftData;Microsoft Fabric;Goog...
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                                 SOTagsAdmired SOTagsHaveEntry  \
# ResponseId
# 176                                         Delphi 12+ Athens             NaN
# 259                                                       NaN             NaN
# 426                                                       NaN             NaN
# 937                                                       NaN             NaN
# 954                                                       NaN             NaN
# ...                                                       ...             ...
# 47602       Tailwind CSS 4;SwiftData;Microsoft Fabric;Goog...               3
# 47981                                                     NaN             NaN
# 48177                                                     NaN             NaN
# 48209                                                     NaN             NaN
# 48300                                                     NaN             NaN
#
#            SOTagsWant Entry  \
# ResponseId
# 176                     NaN
# 259                     NaN
# 426                     NaN
# 937                     NaN
# 954                     NaN
# ...                     ...
# 47602                     3
# 47981                   NaN
# 48177                   NaN
# 48209                   NaN
# 48300                   NaN
#
#                                             OpSysPersonal use  \
# ResponseId
# 176                                           Windows;Android
# 259                             Ubuntu;Debian;Linux (non-WSL)
# 426                                             MacOS;Android
# 937                                           Windows;Android
# 954                                                 MacOS;iOS
# ...                                                       ...
# 47602       Windows;MacOS;Android;Windows Subsystem for Li...
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                         OpSysProfessional use  \
# ResponseId
# 176                                           Windows;Android
# 259                                                       NaN
# 426                                                     MacOS
# 937                                           Windows;Red Hat
# 954                                                       NaN
# ...                                                       ...
# 47602       Windows;MacOS;Android;Windows Subsystem for Li...
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 176                                                       NaN
# 259              GitHub;GitLab;Google Workspace;Markdown File
# 426                                    Confluence;GitHub;Jira
# 937                                        GitHub;GitLab;Jira
# 954                                                       NaN
# ...                                                       ...
# 47602       Airtable;Asana;Azure Devops;Doxygen;GitHub;Git...
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                OfficeStackAsyncWantToWorkWith  \
# ...
# 47981                                                     NaN
# 48177                                  Yes but with oversight
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                                      AIAgents  \
# ResponseId
# 176                                   No, and I don't plan to
# 259                        Yes, I use AI agents at work daily
# 426                                   No, and I don't plan to
# 937                                   No, and I don't plan to
# 954                                   No, and I don't plan to
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177       No, I use AI exclusively in copilot/autocomple...
# 48209                                                     NaN
# 48300                                                     NaN
#
#                       AIAgentChange  \
# ResponseId
# 176         Not at all or minimally
# 259          Yes, to a great extent
# 426                   Yes, somewhat
# 937         Not at all or minimally
# 954         Not at all or minimally
# ...                             ...
# 47602                           NaN
# 47981                           NaN
# 48177       Not at all or minimally
# 48209                           NaN
# 48300                           NaN
#
#                                                  AIAgent_Uses  \
# ResponseId
# 176                                                       NaN
# 259         Software engineering;Business process automati...
# 426                                                       NaN
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177                                    Software engineering
# 48209                                                     NaN
# 48300                                                     NaN
#
#            AgentUsesGeneral  \
# ResponseId
# 176                     NaN
# 259                     NaN
# 426                     NaN
# 937                     NaN
# 954                     NaN
# ...                     ...
# 47602                   NaN
# 47981                   NaN
# 48177           MCP servers
# 48209                   NaN
# 48300                   NaN
#
#                                   AIAgentImpactSomewhat agree  \
# ResponseId
# 176                                                       NaN
# 259                                                       NaN
# 426                                                       NaN
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177       AI agents have increased my productivity.;AI a...
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                          AIAgentImpactNeutral  \
# ResponseId
# 176                                                       NaN
# 259         AI agents have improved collaboration within m...
# 426                                                       NaN
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177       AI agents have helped me automate repetitive t...
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                AIAgentImpactSomewhat disagree  \
# ResponseId
# 176                                                       NaN
# 259                                                       NaN
# 426                                                       NaN
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177       AI agents have improved collaboration within m...
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                   AIAgentImpactStrongly agree  \
# ResponseId
# 176                                                       NaN
# 259         AI agents have increased my productivity.;AI a...
# 426                                                       NaN
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#            AIAgentImpactStrongly disagree  \
# ResponseId
# 176                                   NaN
# 259                                   NaN
# 426                                   NaN
# 937                                   NaN
# 954                                   NaN
# ...                                   ...
# 47602                                 NaN
# 47981                                 NaN
# 48177                                 NaN
# 48209                                 NaN
# 48300                                 NaN
#
#                                      AIAgentChallengesNeutral  \
# ResponseId
# 176                                                       NaN
# 259         The cost of using certain AI agent platforms i...
# 426         The cost of using certain AI agent platforms i...
# 937                                                       NaN
# 954         The cost of using certain AI agent platforms i...
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                            AIAgentChallengesSomewhat disagree  \
# ResponseId
# 176                                                       NaN
# 259                                                       NaN
# 426         My company's IT and/or InfoSec teams have stri...
# 937                                                       NaN
# 954                                                       NaN
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                               AIAgentChallengesStrongly agree  \
# ResponseId
# 176         I have concerns about the security and privacy...
# 259                                                       NaN
# 426         I am concerned about the accuracy of the infor...
# 937         I am concerned about the accuracy of the infor...
# 954         I am concerned about the accuracy of the infor...
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                               AIAgentChallengesSomewhat agree  \
# ResponseId
# 176         I am concerned about the accuracy of the infor...
# 259         I am concerned about the accuracy of the infor...
# 426         Integrating AI agents with my existing tools a...
# 937         The cost of using certain AI agent platforms i...
# 954         It takes significant time and effort to learn ...
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#            AIAgentChallengesStrongly disagree AIAgentKnowledge  \
# ResponseId
# 176                                       NaN              NaN
# 259                                       NaN              NaN
# 426                                       NaN              NaN
# 937                                       NaN              NaN
# 954                                       NaN              NaN
# ...                                       ...              ...
# 47602                                     NaN              NaN
# 47981                                     NaN              NaN
# 48177                                     NaN              NaN
# 48209                                     NaN              NaN
# 48300                                     NaN              NaN
#
#            AIAgentKnowWrite AIAgentOrchestration AIAgentOrchWrite  \
# ResponseId
# 176                     NaN                  NaN              NaN
# 259                     NaN                  NaN              NaN
# 426                     NaN                  NaN              NaN
# 937                     NaN                  NaN              NaN
# 954                     NaN                  NaN              NaN
# ...                     ...                  ...              ...
# 47602                   NaN                  NaN              NaN
# 47981                   NaN                  NaN              NaN
# 48177                   NaN                  NaN              NaN
# 48209                   NaN                  NaN              NaN
# 48300                   NaN                  NaN              NaN
#
#            AIAgentObserveSecure AIAgentObsWrite  \
# ResponseId
# 176                         NaN             NaN
# 259                         NaN             NaN
# 426                         NaN             NaN
# 937                         NaN             NaN
# 954                         NaN             NaN
# ...                         ...             ...
# 47602                       NaN             NaN
# 47981                       NaN             NaN
# 48177                       NaN             NaN
# 48209                       NaN             NaN
# 48300                       NaN             NaN
#
#                                               AIAgentExternal AIAgentExtWrite  \
# ResponseId
# 176                                                       NaN             NaN
# 259         ChatGPT;GitHub Copilot;Google Gemini;Roo code ...             NaN
# 426                                                       NaN             NaN
# 937                                                       NaN             NaN
# 954                                                       NaN             NaN
# ...                                                       ...             ...
# 47602                                                     NaN             NaN
# 47981                                                     NaN             NaN
# 48177                                                     NaN             NaN
# 48209                                                     NaN             NaN
# 48300                                                     NaN             NaN
#
#                                                       AIHuman  \
# ResponseId
# 176         When I don’t trust AI’s answers;When I want to...
# 259         When I don’t trust AI’s answers;When I want to...
# 426         When I don’t trust AI’s answers;When I want to...
# 937         When I don’t trust AI’s answers;When I want to...
# 954         When I don’t trust AI’s answers;When I want to...
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#                                                        AIOpen  \
# ResponseId
# 176                                                       NaN
# 259         Problem definition and solving a long with gui...
# 426         You still need to know what you are trying to ...
# 937         understanding the how to deal with bad data an...
# 954                                           Problem solving
# ...                                                       ...
# 47602                                                     NaN
# 47981                                                     NaN
# 48177                                                     NaN
# 48209                                                     NaN
# 48300                                                     NaN
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 176                     41765.0     NaN
# 259                         NaN     NaN
# 426                    195000.0     8.0
# 937                    144700.0     NaN
# 954                      2480.0     NaN
# ...                         ...     ...
# 47602                       NaN     NaN
# 47981                       NaN     NaN
# 48177                       NaN     NaN
# 48209                       NaN     NaN
# 48300                       NaN    10.0
#
# [248 rows x 169 columns]

# %%
df.loc[code_experience, ["Age", "Employment", "RemoteWork"]]
# Out:
#                           Age  \
# ResponseId
# 176         65 years or older
# 259         65 years or older
# 426         65 years or older
# 937         65 years or older
# 954           55-64 years old
# ...                       ...
# 47602         25-34 years old
# 47981       65 years or older
# 48177       65 years or older
# 48209       65 years or older
# 48300         18-24 years old
#
#                                                    Employment  \
# ResponseId
# 176                                                   Retired
# 259                                                   Retired
# 426                                                  Employed
# 937                                                  Employed
# 954                                                   Retired
# ...                                                       ...
# 47602                                                 Student
# 47981       Independent contractor, freelancer, or self-em...
# 48177                                                 Retired
# 48209                                                 Retired
# 48300                                                 Student
#
#                                                    RemoteWork
# ResponseId
# 176         Hybrid (some in-person, leans heavy to flexibi...
# 259                                                       NaN
# 426         Hybrid (some in-person, leans heavy to flexibi...
# 937                                                    Remote
# 954                                                       NaN
# ...                                                       ...
# 47602                                               In-person
# 47981                                                  Remote
# 48177                                                  Remote
# 48209                                                     NaN
# 48300                                                     NaN
#
# [248 rows x 3 columns]

# %%
countries = ["Spain", "Italy", "Sweden"]

# %%
filt = df["Country"].isin(countries)

# %%
df.loc[filt, "Country"]
# Out:
# ResponseId
# 28       Sweden
# 37        Italy
# 61        Spain
# 68       Sweden
# 86        Italy
#           ...
# 48910     Italy
# 48938    Sweden
# 48955     Italy
# 49027     Spain
# 49123     Italy
# Name: Country, Length: 2167, dtype: object

# %%
df["LanguageHaveWorkedWith"]
# Out:
# ResponseId
# 1                         Bash/Shell (all shells);Dart;SQL
# 2                                                     Java
# 3                      Dart;HTML/CSS;JavaScript;TypeScript
# 4                                          Java;Kotlin;SQL
# 5        C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
#                                ...
# 49119                                                  NaN
# 49120                                                  NaN
# 49121                                                  NaN
# 49122                                               C#;SQL
# 49123                                                  NaN
# Name: LanguageHaveWorkedWith, Length: 49123, dtype: object

# %%
filt = df["LanguageHaveWorkedWith"].str.contains("Python", na=False)

# %%
df.loc[filt, "LanguageHaveWorkedWith"]
# Out:
# ResponseId
# 5        C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
# 8        Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 9                                        Java;Python;Scala
# 16       Ada;Assembly;C;C#;C++;COBOL;Dart;Delphi;Elixir...
# 18                          HTML/CSS;JavaScript;Python;SQL
#                                ...
# 49062    C;Go;HTML/CSS;JavaScript;MATLAB;MicroPython;Py...
# 49089                                           Python;SQL
# 49090    C;C#;C++;HTML/CSS;Java;JavaScript;PHP;PowerShe...
# 49106    C++;Dart;GDScript;HTML/CSS;JavaScript;PHP;Powe...
# 49107    Bash/Shell (all shells);Delphi;PowerShell;Pyth...
# Name: LanguageHaveWorkedWith, Length: 18444, dtype: object

# %%
df.rename(columns={"Age": "CurrentAge"}) # Temporary change
# Out:
#                                 MainBranch       CurrentAge  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
# ...                                    ...              ...
# 49119       I am a developer by profession  25-34 years old
# 49120       I am a developer by profession  35-44 years old
# 49121       I am a developer by profession  25-34 years old
# 49122       I am a developer by profession  25-34 years old
# 49123       I am a developer by profession  25-34 years old
#
#                                                       EdLevel  \
# ResponseId
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                         Associate degree (A.A., A.S., etc.)
# 3                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                       ...
# 49119            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49120            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49121       Secondary school (e.g. American high school, G...
# 49122                     Associate degree (A.A., A.S., etc.)
# 49123       Some college/university study without earning ...
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# 3           Independent contractor, freelancer, or self-em...
# 4                                                    Employed
# 5           Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 49119                                                Employed
# 49120                                                Employed
# 49121                                                Employed
# 49122                                                Employed
# 49123                                                Employed
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 1             Caring for dependents (children, elderly, etc.)      8.0
# 2                                                         NaN      2.0
# 3                                           None of the above     10.0
# 4                                           None of the above      4.0
# 5             Caring for dependents (children, elderly, etc.)     21.0
# ...                                                       ...      ...
# 49119                                                     NaN      9.0
# 49120         Caring for dependents (children, elderly, etc.)     13.0
# 49121                                                     NaN      2.0
# 49122       None of the above;Engaged in paid work (20-29 ...     10.0
# 49123                                       None of the above     10.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
# 2           Yes, I am not new to coding but am learning ne...
# 3           Yes, I am not new to coding but am learning ne...
# 4           Yes, I am not new to coding but am learning ne...
# 5           No, I am not new to coding and did not learn n...
# ...                                                       ...
# 49119       Yes, I am not new to coding but am learning ne...
# 49120       No, I am not new to coding and did not learn n...
# 49121       Yes, I am not new to coding but am learning ne...
# 49122       No, I am not new to coding and did not learn n...
# 49123       No, I am not new to coding and did not learn n...
#
#                                                     LearnCode  \
# ResponseId
# 1           Online Courses or Certification (includes all ...
# 2           Online Courses or Certification (includes all ...
# 3           Online Courses or Certification (includes all ...
# 4           Other online resources (e.g. standard search, ...
# 5                                                         NaN
# ...                                                       ...
# 49119       Online Courses or Certification (includes all ...
# 49120                                                     NaN
# 49121       Other online resources (e.g. standard search, ...
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                                   LearnCodeAI  \
# ResponseId
# 1           Yes, I learned how to use AI-enabled tools for...
# 2           Yes, I learned how to use AI-enabled tools for...
# 3           Yes, I learned how to use AI-enabled tools for...
# 4           Yes, I learned how to use AI-enabled tools for...
# 5           Yes, I learned how to use AI-enabled tools for...
# ...                                                       ...
# 49119       Yes, I learned how to use AI-enabled tools req...
# 49120       Yes, I learned how to use AI-enabled tools req...
# 49121       No, I didn't spend time learning in the past year
# 49122       Yes, I learned how to use AI-enabled tools for...
# 49123       No, I learned something that was not related t...
#
#                                                    AILearnHow  YearsCode  \
# ResponseId
# 1                         AI CodeGen tools or AI-enabled apps       14.0
# 2                         AI CodeGen tools or AI-enabled apps       10.0
# 3           AI CodeGen tools or AI-enabled apps;Technical ...       12.0
# 4           AI CodeGen tools or AI-enabled apps;Videos (no...        5.0
# 5           Technical documentation (is generated for/by t...       22.0
# ...                                                       ...        ...
# 49119       AI CodeGen tools or AI-enabled apps;Technical ...       13.0
# 49120       AI CodeGen tools or AI-enabled apps;Videos (no...       15.0
# 49121                                                     NaN        NaN
# 49122       Videos (not associated with specific online co...       14.0
# 49123                                                     NaN       15.0
#
#                           DevType                   OrgSize  \
# ResponseId
# 1               Developer, mobile        20 to 99 employees
# 2             Developer, back-end      500 to 999 employees
# 3            Developer, front-end                       NaN
# 4             Developer, back-end  10,000 or more employees
# 5             Engineering manager                       NaN
# ...                           ...                       ...
# 49119       Developer, full-stack      500 to 999 employees
# 49120       Developer, full-stack  1,000 to 4,999 employees
# 49121                         NaN                       NaN
# 49122       Developer, full-stack        20 to 99 employees
# 49123       Developer, full-stack    Less than 20 employees
#
#                             ICorPM  \
# ResponseId
# 1                   People manager
# 2           Individual contributor
# 3                              NaN
# 4           Individual contributor
# 5                              NaN
# ...                            ...
# 49119       Individual contributor
# 49120       Individual contributor
# 49121                          NaN
# 49122       Individual contributor
# 49123       Individual contributor
#
#                                                    RemoteWork  \
# ResponseId
# 1                                                      Remote
# 2           Hybrid (some in-person, leans heavy to flexibi...
# 3                                                         NaN
# 4                                                      Remote
# 5                                                         NaN
# ...                                                       ...
# 49119          Hybrid (some remote, leans heavy to in-person)
# 49120          Hybrid (some remote, leans heavy to in-person)
# 49121                                                     NaN
# 49122          Hybrid (some remote, leans heavy to in-person)
# 49123       Your choice (very flexible, you can come in wh...
#
#                                             PurchaseInfluence  \
# ResponseId
# 1           Yes, I influenced the purchase of a substantia...
# 2                                                          No
# 3                                                          No
# 4                                                          No
# 5           Yes, I endorsed a tool that was open-source an...
# ...                                                       ...
# 49119                                                      No
# 49120       Yes, I endorsed a tool that was open-source an...
# 49121                                                     NaN
# 49122       Yes, I influenced the purchase of a substantia...
# 49123       Yes, I influenced the purchase of a substantia...
#
#             TechEndorseIntro  TechEndorse_1  TechEndorse_2  TechEndorse_3  \
# ResponseId
# 1                       Work           10.0            7.0            9.0
# 2           Personal Project           13.0            1.0            2.0
# 3                       Work           12.0            2.0            3.0
# 4           Personal Project            2.0           12.0            6.0
# 5                       Work            6.0            3.0            1.0
# ...                      ...            ...            ...            ...
# 49119       Personal Project            8.0            2.0            4.0
# 49120                    NaN            NaN            NaN            NaN
# 49121                    NaN            NaN            NaN            NaN
# 49122                   Work            5.0            6.0            3.0
# 49123       Personal Project            9.0            2.0            3.0
#
#             TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  \
# ResponseId
# 1                     6.0            3.0           11.0           12.0
# 2                     9.0            4.0            3.0           12.0
# 3                     7.0            5.0           10.0           13.0
# 4                     5.0           13.0            3.0            8.0
# 5                     9.0           10.0            8.0            7.0
# ...                   ...            ...            ...            ...
# 49119                 5.0            6.0            7.0            9.0
# 49120                 NaN            NaN            NaN            NaN
# 49121                 NaN            NaN            NaN            NaN
# 49122                 8.0            1.0            9.0            7.0
# 49123                 1.0            6.0            4.0            7.0
#
#             TechEndorse_8  TechEndorse_9  TechEndorse_13 TechEndorse_13_TEXT  \
# ResponseId
# 1                     1.0            8.0            14.0                 NaN
# 2                     5.0            7.0            14.0                 NaN
# 3                     1.0            4.0            14.0                 NaN
# 4                    11.0            7.0            14.0                 NaN
# 5                     4.0            2.0            14.0                 NaN
# ...                   ...            ...             ...                 ...
# 49119                 3.0            1.0            10.0                 NaN
# 49120                 NaN            NaN             NaN                 NaN
# 49121                 NaN            NaN             NaN                 NaN
# 49122                 4.0            2.0            10.0                 NaN
# 49123                 5.0            8.0            10.0                 NaN
#
#             TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# ResponseId
# 1                   15.0           7.0           8.0          12.0
# 2                   14.0           1.0          13.0          10.0
# 3                    8.0           1.0           2.0          12.0
# 4                   10.0           5.0           8.0           4.0
# 5                    7.0          13.0           3.0           9.0
# ...                  ...           ...           ...           ...
# 49119                8.0           2.0           6.0           3.0
# 49120                NaN           NaN           NaN           NaN
# 49121                NaN           NaN           NaN           NaN
# 49122                9.0           7.0           8.0           2.0
# 49123                8.0           1.0           7.0           5.0
#
#             TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  \
# ResponseId
# 1                   11.0           1.0            6.0           13.0
# 2                    9.0           3.0            4.0            2.0
# 3                   13.0           3.0            9.0            4.0
# 4                   13.0          12.0            2.0            7.0
# 5                   12.0           6.0            1.0            8.0
# ...                  ...           ...            ...            ...
# 49119                9.0           4.0            1.0            5.0
# 49120                NaN           NaN            NaN            NaN
# 49121                NaN           NaN            NaN            NaN
# 49122                4.0           6.0            3.0            5.0
# 49123                6.0           2.0            3.0            4.0
#
#             TechOppose_16  TechOppose_15 TechOppose_15_TEXT  \
# ResponseId
# 1                     3.0           16.0                NaN
# 2                     5.0           15.0                NaN
# 3                    11.0           15.0                NaN
# 4                     1.0           15.0                NaN
# 5                    14.0           15.0                NaN
# ...                   ...            ...                ...
# 49119                 7.0           10.0                NaN
# 49120                 NaN            NaN                NaN
# 49121                 NaN            NaN                NaN
# 49122                 1.0           10.0                NaN
# 49123                 9.0           10.0                NaN
#
#                                 Industry  JobSatPoints_1  JobSatPoints_4  \
# ResponseId
# 1                                Fintech             3.0             9.0
# 2           Retail and Consumer Services            10.0             9.0
# 3                   Software Development             9.0            11.0
# 4           Retail and Consumer Services             1.0             5.0
# 5                   Software Development             9.0            13.0
# ...                                  ...             ...             ...
# 49119               Software Development            11.0            13.0
# 49120                                NaN             NaN             NaN
# 49121                                NaN             NaN             NaN
# 49122                      Manufacturing             8.0            14.0
# 49123               Software Development             NaN             NaN
#
#             JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# ResponseId
# 1                      5.0            10.0            12.0            11.0
# 2                     12.0             1.0             6.0             2.0
# 3                      8.0            12.0             1.0             5.0
# 4                      6.0             7.0             8.0             9.0
# 5                     14.0             8.0             6.0             5.0
# ...                    ...             ...             ...             ...
# 49119                 12.0            10.0             6.0             1.0
# 49120                  NaN             NaN             NaN             NaN
# 49121                  NaN             NaN             NaN             NaN
# 49122                 11.0            10.0             1.0             2.0
# 49123                  NaN             NaN             NaN             NaN
#
#             JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  JobSatPoints_13  \
# ResponseId
# 1                      2.0              6.0              7.0             13.0
# 2                     11.0              4.0              7.0             13.0
# 3                      2.0              4.0              3.0             13.0
# 4                     10.0             11.0             12.0             13.0
# 5                      7.0              2.0              1.0             12.0
# ...                    ...              ...              ...              ...
# 49119                  9.0             14.0              2.0              8.0
# 49120                  NaN              NaN              NaN              NaN
# 49121                  NaN              NaN              NaN              NaN
# 49122                  5.0             13.0              7.0             12.0
# 49123                  NaN              NaN              NaN              NaN
#
#             JobSatPoints_14  JobSatPoints_15  JobSatPoints_16  \
# ResponseId
# 1                      14.0             15.0              8.0
# 2                      14.0             15.0              5.0
# 3                      14.0             15.0             10.0
# 4                      14.0             15.0              3.0
# 5                      10.0             15.0              3.0
# ...                     ...              ...              ...
# 49119                   7.0             15.0              3.0
# 49120                   NaN              NaN              NaN
# 49121                   NaN              NaN              NaN
# 49122                   6.0             15.0              4.0
# 49123                   NaN              NaN              NaN
#
#            JobSatPoints_15_TEXT      AIThreat  \
# ResponseId
# 1                           NaN  I'm not sure
# 2                           NaN  I'm not sure
# 3                           NaN            No
# 4                           NaN            No
# 5                           NaN            No
# ...                         ...           ...
# 49119                       NaN  I'm not sure
# 49120                       NaN           NaN
# 49121                       NaN           NaN
# 49122                       NaN            No
# 49123                       NaN            No
#
#                                                       NewRole  ToolCountWork  \
# ResponseId
# 1           I have neither consider or transitioned into a...            7.0
# 2           I have transitioned into a new career and/or i...            6.0
# 3           I have transitioned into a new career and/or i...            3.0
# 4           I have neither consider or transitioned into a...            NaN
# 5           I have neither consider or transitioned into a...            4.0
# ...                                                       ...            ...
# 49119       I have somewhat considered changing my career ...            NaN
# 49120                                                     NaN            NaN
# 49121                                                     NaN            NaN
# 49122       I have somewhat considered changing my career ...            8.0
# 49123       I have somewhat considered changing my career ...            NaN
#
#             ToolCountPersonal      Country                  Currency  \
# ResponseId
# 1                         3.0      Ukraine         EUR European Euro
# 2                         5.0  Netherlands         EUR European Euro
# 3                         3.0      Ukraine     UAH Ukrainian hryvnia
# 4                         NaN      Ukraine         EUR European Euro
# 5                         3.0      Ukraine  USD United States dollar
# ...                       ...          ...                       ...
# 49119                     NaN          NaN                       NaN
# 49120                     NaN          NaN                       NaN
# 49121                     NaN          NaN                       NaN
# 49122                     2.0       France         EUR European Euro
# 49123                     NaN        Italy         EUR European Euro
#
#             CompTotal LanguageChoice  \
# ResponseId
# 1             52800.0            Yes
# 2             90000.0            Yes
# 3           2214000.0            Yes
# 4             31200.0            Yes
# 5             60000.0            Yes
# ...               ...            ...
# 49119             NaN            NaN
# 49120             NaN            NaN
# 49121             NaN            NaN
# 49122         50000.0            Yes
# 49123         40000.0            NaN
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 1                            Bash/Shell (all shells);Dart;SQL
# 2                                                        Java
# 3                         Dart;HTML/CSS;JavaScript;TypeScript
# 4                                             Java;Kotlin;SQL
# 5           C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                  C#;SQL
# 49123                                                     NaN
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                        Dart
# 2                                           Java;Python;Swift
# 3                         Dart;HTML/CSS;JavaScript;TypeScript
# 4                                                 Java;Kotlin
# 5                    C#;Java;JavaScript;Python;SQL;TypeScript
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       C#;HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;...
# 49123                                                     NaN
#
#                                      LanguageAdmired LanguagesHaveEntry  \
# ResponseId
# 1                                               Dart                NaN
# 2                                               Java                NaN
# 3                Dart;HTML/CSS;JavaScript;TypeScript                NaN
# 4                                        Java;Kotlin                NaN
# 5           C#;Java;JavaScript;Python;SQL;TypeScript                NaN
# ...                                              ...                ...
# 49119                                            NaN                NaN
# 49120                                            NaN                NaN
# 49121                                            NaN                NaN
# 49122                                         C#;SQL      Visual FoxPro
# 49123                                            NaN                NaN
#
#            LanguagesWantEntry DatabaseChoice  \
# ResponseId
# 1                         NaN            Yes
# 2                         NaN            Yes
# 3                         NaN            Yes
# 4                         NaN             No
# 5                         NaN            Yes
# ...                       ...            ...
# 49119                     NaN            NaN
# 49120                     NaN            NaN
# 49121                     NaN            NaN
# 49122                     NaN            Yes
# 49123                     NaN            NaN
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 1                                  Cloud Firestore;PostgreSQL
# 2                                            Dynamodb;MongoDB
# 3                                    MongoDB;MySQL;PostgreSQL
# 4                                                         NaN
# 5           Elasticsearch;Microsoft SQL Server;MySQL;Oracl...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                              Microsoft SQL Server;MySQL
# 49123                                                     NaN
#
#                         DatabaseWantToWorkWith  \
# ResponseId
# 1                                          NaN
# 2                             Dynamodb;MongoDB
# 3           Firebase Realtime Database;MongoDB
# 4                                          NaN
# 5              Elasticsearch;Oracle;PostgreSQL
# ...                                        ...
# 49119                                      NaN
# 49120                                      NaN
# 49121                                      NaN
# 49122        MariaDB;MongoDB;PostgreSQL;SQLite
# 49123                                      NaN
#
#                             DatabaseAdmired DatabaseHaveEntry  \
# ResponseId
# 1                                       NaN               NaN
# 2                          Dynamodb;MongoDB               NaN
# 3                                   MongoDB               NaN
# 4                                       NaN               NaN
# 5           Elasticsearch;Oracle;PostgreSQL               NaN
# ...                                     ...               ...
# 49119                                   NaN               NaN
# 49120                                   NaN               NaN
# 49121                                   NaN               NaN
# 49122                                   NaN               NaN
# 49123                                   NaN               NaN
#
#            DatabaseWantEntry PlatformChoice  \
# ResponseId
# 1                        NaN            Yes
# 2                        NaN            Yes
# 3                        NaN            Yes
# 4                        NaN            Yes
# 5                        NaN            Yes
# ...                      ...            ...
# 49119                    NaN            NaN
# 49120                    NaN            NaN
# 49121                    NaN            NaN
# 49122                    NaN             No
# 49123                    NaN            NaN
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 1           Amazon Web Services (AWS);Cloudflare;Firebase;...
# 2           Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 3                                   Datadog;Firebase;npm;pnpm
# 4                      Amazon Web Services (AWS);Google Cloud
# 5           Amazon Web Services (AWS);APT;Docker;Make;Mave...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                        PlatformWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 3            Amazon Web Services (AWS);Firebase;npm;pnpm;Vite
# 4                      Amazon Web Services (AWS);Google Cloud
# 5           Amazon Web Services (AWS);APT;Docker;Maven (bu...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                               PlatformAdmired  \
# ResponseId
# 1                                                         NaN
# 2           Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 3                                           Firebase;npm;pnpm
# 4                      Amazon Web Services (AWS);Google Cloud
# 5           Amazon Web Services (AWS);APT;Docker;Maven (bu...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#            PlatformHaveEntry PlatformWantEntry WebframeChoice  \
# ResponseId
# 1                        NaN               NaN             No
# 2                        NaN               NaN            Yes
# 3                        NaN               NaN            Yes
# 4                        NaN               NaN            Yes
# 5                        NaN               NaN            Yes
# ...                      ...               ...            ...
# 49119                    NaN               NaN            NaN
# 49120                    NaN               NaN            NaN
# 49121                    NaN               NaN            NaN
# 49122                    NaN               NaN             No
# 49123                    NaN               NaN            NaN
#
#                                WebframeHaveWorkedWith  \
# ResponseId
# 1                                                 NaN
# 2                                         Spring Boot
# 3                               Next.js;Node.js;React
# 4                                         Spring Boot
# 5           Angular;ASP.NET;ASP.NET Core;Flask;jQuery
# ...                                               ...
# 49119                                             NaN
# 49120                                             NaN
# 49121                                             NaN
# 49122                                             NaN
# 49123                                             NaN
#
#                 WebframeWantToWorkWith             WebframeAdmired  \
# ResponseId
# 1                                  NaN                         NaN
# 2                          Spring Boot                 Spring Boot
# 3                Next.js;Node.js;React       Next.js;Node.js;React
# 4                          Spring Boot                 Spring Boot
# 5           Angular;ASP.NET Core;Flask  Angular;ASP.NET Core;Flask
# ...                                ...                         ...
# 49119                              NaN                         NaN
# 49120                              NaN                         NaN
# 49121                              NaN                         NaN
# 49122                              NaN                         NaN
# 49123                              NaN                         NaN
#
#            WebframeHaveEntry WebframeWantEntry DevEnvsChoice  \
# ResponseId
# 1                        NaN               NaN           Yes
# 2                        NaN               NaN           Yes
# 3                        NaN          Solid.js           Yes
# 4                        NaN               NaN            No
# 5                        NaN               NaN           Yes
# ...                      ...               ...           ...
# 49119                    NaN               NaN           NaN
# 49120                    NaN               NaN           NaN
# 49121                    NaN               NaN           NaN
# 49122                    NaN               NaN           Yes
# 49123                    NaN               NaN           NaN
#
#                                         DevEnvsHaveWorkedWith  \
# ResponseId
# 1           Android Studio;Notepad++;Visual Studio;Visual ...
# 2              IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode
# 3                                          Visual Studio Code
# 4                                                         NaN
# 5           Eclipse;IntelliJ IDEA;Jupyter Notebook/Jupyter...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                           Visual Studio
# 49123                                                     NaN
#
#                                         DevEnvsWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2              IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode
# 3                                 Visual Studio Code;Windsurf
# 4                                                         NaN
# 5           IntelliJ IDEA;Jupyter Notebook/JupyterLab;Note...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       Bolt;Claude Code;Cursor;Visual Studio;Visual S...
# 49123                                                     NaN
#
#                                                DevEnvsAdmired DevEnvHaveEntry  \
# ResponseId
# 1                                                         NaN             NaN
# 2              IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode             NaN
# 3                                          Visual Studio Code             NaN
# 4                                                         NaN             NaN
# 5           IntelliJ IDEA;Jupyter Notebook/JupyterLab;Note...             NaN
# ...                                                       ...             ...
# 49119                                                     NaN             NaN
# 49120                                                     NaN             NaN
# 49121                                                     NaN             NaN
# 49122                                           Visual Studio             NaN
# 49123                                                     NaN             NaN
#
#            DevEnvWantEntry                SOTagsHaveWorkedWith  \
# ResponseId
# 1                      NaN                                 NaN
# 2                      NaN                                 NaN
# 3                      NaN                       Google Gemini
# 4                      NaN                      Amazon Bedrock
# 5                      NaN  Large Language Model;Google Gemini
# ...                    ...                                 ...
# 49119                  NaN                                 NaN
# 49120                  NaN                                 NaN
# 49121                  NaN                                 NaN
# 49122                  NaN                    .NET 8 or higher
# 49123                  NaN                                 NaN
#
#                SOTagsWantToWorkWith         SOTagsAdmired SOTagsHaveEntry  \
# ResponseId
# 1                               NaN                   NaN             NaN
# 2                               NaN                   NaN             NaN
# 3           Google Gemini;Shadcn/ui         Google Gemini             NaN
# 4                               NaN                   NaN             NaN
# 5              Large Language Model  Large Language Model             NaN
# ...                             ...                   ...             ...
# 49119                           NaN                   NaN             NaN
# 49120                           NaN                   NaN             NaN
# 49121                           NaN                   NaN             NaN
# 49122              .NET 8 or higher      .NET 8 or higher             NaN
# 49123                           NaN                   NaN             NaN
#
#            SOTagsWant Entry         OpSysPersonal use  \
# ResponseId
# 1                       NaN     Windows;MacOS;Android
# 2                       NaN  Windows;MacOS;iOS;iPadOS
# 3                       NaN             MacOS;Android
# 4                       NaN                   Windows
# 5                       NaN               Windows;iOS
# ...                     ...                       ...
# 49119                   NaN                       NaN
# 49120                   NaN                       NaN
# 49121                   NaN                       NaN
# 49122                   NaN           Windows;Android
# 49123                   NaN                       NaN
#
#                        OpSysProfessional use  \
# ResponseId
# 1           Windows;MacOS;Android;iOS;iPadOS
# 2                                      MacOS
# 3                                      MacOS
# 4                             Windows;Ubuntu
# 5                      Windows;Ubuntu;Debian
# ...                                      ...
# 49119                                    NaN
# 49120                                    NaN
# 49121                                    NaN
# 49122                                Windows
# 49123                                    NaN
#
#                          OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 1           Confluence;GitHub;GitLab;Jira;Markdown File
# 2                                Confluence;GitHub;Jira
# 3                                    GitHub;GitLab;Jira
# 4                                      GitLab;Jira;Miro
# 5                              Azure Devops;GitHub;Jira
# ...                                                 ...
# 49119                                               NaN
# 49120                                               NaN
# 49121                                               NaN
# 49122                Asana;Azure Devops;GitHub;Obsidian
# 49123                                               NaN
#
#            OfficeStackAsyncWantToWorkWith   OfficeStackAsyncAdmired  \
# ResponseId
# 1                           Markdown File             Markdown File
# 2                  Confluence;GitHub;Jira    Confluence;GitHub;Jira
# 3                      GitHub;GitLab;Jira        GitHub;GitLab;Jira
# 4                             GitLab;Jira               GitLab;Jira
# 5                Azure Devops;GitHub;Jira  Azure Devops;GitHub;Jira
# ...                                   ...                       ...
# 49119                                 NaN                       NaN
# 49120                                 NaN                       NaN
# 49121                                 NaN                       NaN
# 49122               Asana;GitHub;Obsidian     Asana;GitHub;Obsidian
# 49123                                 NaN                       NaN
#
#            OfficeStackHaveEntry OfficeStackWantEntry  \
# ResponseId
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# 4                           NaN                  NaN
# 5                           NaN                  NaN
# ...                         ...                  ...
# 49119                       NaN                  NaN
# 49120                       NaN                  NaN
# 49121                       NaN                  NaN
# 49122                       NaN                  NaN
# 49123                       NaN                  NaN
#
#                                    CommPlatformHaveWorkedWith  \
# ResponseId
# 1           Stack Overflow;Reddit;GitHub (public projects,...
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4                      Stack Overflow;Reddit;YouTube;LinkedIn
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                 Stack Overflow;Discord;YouTube;LinkedIn
# 49123                                                     NaN
#
#                                    CommPlatformWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4           Stack Overflow;Reddit;GitHub (public projects,...
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                 Stack Overflow;Discord;YouTube;LinkedIn
# 49123                                                     NaN
#
#                                           CommPlatformAdmired  \
# ResponseId
# 1                                                         NaN
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4                      Stack Overflow;Reddit;YouTube;LinkedIn
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                 Stack Overflow;Discord;YouTube;LinkedIn
# 49123                                                     NaN
#
#            CommPlatformHaveEntr CommPlatformWantEntr AIModelsChoice  \
# ResponseId
# 1                           NaN                  NaN            Yes
# 2                           NaN                  NaN            Yes
# 3                           NaN                  NaN            Yes
# 4                           NaN                  NaN             No
# 5                           NaN                  NaN            Yes
# ...                         ...                  ...            ...
# 49119                       NaN                  NaN            NaN
# 49120                       NaN                  NaN            NaN
# 49121                       NaN                  NaN            NaN
# 49122                       NaN                  NaN             No
# 49123                       NaN                  NaN            NaN
#
#                                        AIModelsHaveWorkedWith  \
# ResponseId
# 1           openAI GPT (chatbot models);openAI Image gener...
# 2                                 openAI GPT (chatbot models)
# 3           Gemini (Flash general purpose models);openAI G...
# 4                                                         NaN
# 5                                 openAI GPT (chatbot models)
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                        AIModelsWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                 openAI GPT (chatbot models)
# 3           Gemini (Flash general purpose models);Gemini (...
# 4                                                         NaN
# 5                                 openAI GPT (chatbot models)
# ...
# 49123                                                     NaN
#
#                                                     AIExplain  \
# ResponseId
# 1                                                          No
# 2                                                          No
# 3                                                          No
# 4                                                          NO
# 5                                                      partly
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       no, IA do not control de code part, it's essen...
# 49123                                                     NaN
#
#                                                      AIAgents  \
# ResponseId
# 1           Yes, I use AI agents at work monthly or infreq...
# 2                                     No, and I don't plan to
# 3                         Yes, I use AI agents at work weekly
# 4           Yes, I use AI agents at work monthly or infreq...
# 5                                     No, and I don't plan to
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       No, I use AI exclusively in copilot/autocomple...
# 49123                                                     NaN
#
#                       AIAgentChange          AIAgent_Uses  \
# ResponseId
# 1           Not at all or minimally  Software engineering
# 2           Not at all or minimally                   NaN
# 3                     Yes, somewhat  Software engineering
# 4           Not at all or minimally  Software engineering
# 5            Yes, to a great extent                   NaN
# ...                             ...                   ...
# 49119                           NaN                   NaN
# 49120                           NaN                   NaN
# 49121                           NaN                   NaN
# 49122       Not at all or minimally             Marketing
# 49123                           NaN                   NaN
#
#                                              AgentUsesGeneral  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                            Multi-platform search enablement
# 4                                         Language processing
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       Multi-platform search enablement;Language proc...
# 49123                                                     NaN
#
#                                   AIAgentImpactSomewhat agree  \
# ResponseId
# 1           AI agents have increased my productivity.;AI a...
# 2                                                         NaN
# 3           AI agents have increased my productivity.;AI a...
# 4           AI agents have accelerated my learning about n...
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                          AIAgentImpactNeutral  \
# ResponseId
# 1           AI agents have helped me automate repetitive t...
# 2                                                         NaN
# 3           AI agents have improved the quality of my code...
# 4           AI agents have increased my productivity.;AI a...
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                AIAgentImpactSomewhat disagree  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           AI agents have improved collaboration within m...
# 4           AI agents have helped me automate repetitive t...
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#            AIAgentImpactStrongly agree AIAgentImpactStrongly disagree  \
# ResponseId
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# 5                                  NaN                            NaN
# ...                                ...                            ...
# 49119                              NaN                            NaN
# 49120                              NaN                            NaN
# 49121                              NaN                            NaN
# 49122                              NaN                            NaN
# 49123                              NaN                            NaN
#
#                                      AIAgentChallengesNeutral  \
# ResponseId
# 1           I am concerned about the accuracy of the infor...
# 2           It takes significant time and effort to learn ...
# 3           It takes significant time and effort to learn ...
# 4           It takes significant time and effort to learn ...
# 5           Integrating AI agents with my existing tools a...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                            AIAgentChallengesSomewhat disagree  \
# ResponseId
# 1           Integrating AI agents with my existing tools a...
# 2                                                         NaN
# 3           My company's IT and/or InfoSec teams have stri...
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                               AIAgentChallengesStrongly agree  \
# ResponseId
# 1           The cost of using certain AI agent platforms i...
# 2           I am concerned about the accuracy of the infor...
# 3                                                         NaN
# 4           I am concerned about the accuracy of the infor...
# 5           I am concerned about the accuracy of the infor...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                               AIAgentChallengesSomewhat agree  \
# ResponseId
# 1                                                         NaN
# 2           Integrating AI agents with my existing tools a...
# 3           I am concerned about the accuracy of the infor...
# 4           Integrating AI agents with my existing tools a...
# 5           It takes significant time and effort to learn ...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#            AIAgentChallengesStrongly disagree AIAgentKnowledge  \
# ResponseId
# 1                                         NaN              NaN
# 2                                         NaN              NaN
# 3                                         NaN            Redis
# 4                                         NaN              NaN
# 5                                         NaN              NaN
# ...                                       ...              ...
# 49119                                     NaN              NaN
# 49120                                     NaN              NaN
# 49121                                     NaN              NaN
# 49122                                     NaN              NaN
# 49123                                     NaN              NaN
#
#            AIAgentKnowWrite AIAgentOrchestration AIAgentOrchWrite  \
# ResponseId
# 1                       NaN            Vertex AI              NaN
# 2                       NaN                  NaN              NaN
# 3                       NaN                  NaN              NaN
# 4                       NaN                  NaN              NaN
# 5                       NaN                  NaN              NaN
# ...                     ...                  ...              ...
# 49119                   NaN                  NaN              NaN
# 49120                   NaN                  NaN              NaN
# 49121                   NaN                  NaN              NaN
# 49122                   NaN                  NaN              NaN
# 49123                   NaN                  NaN              NaN
#
#            AIAgentObserveSecure AIAgentObsWrite  \
# ResponseId
# 1                           NaN             NaN
# 2                           NaN             NaN
# 3                           NaN             NaN
# 4                           NaN             NaN
# 5                           NaN             NaN
# ...                         ...             ...
# 49119                       NaN             NaN
# 49120                       NaN             NaN
# 49121                       NaN             NaN
# 49122                       NaN             NaN
# 49123                       NaN             NaN
#
#                                              AIAgentExternal AIAgentExtWrite  \
# ResponseId
# 1                                                    ChatGPT             NaN
# 2                                                        NaN             NaN
# 3           ChatGPT;Claude Code;GitHub Copilot;Google Gemini             NaN
# 4                                        ChatGPT;Claude Code             NaN
# 5                                                        NaN             NaN
# ...                                                      ...             ...
# 49119                                                    NaN             NaN
# 49120                                                    NaN             NaN
# 49121                                                    NaN             NaN
# 49122                                                    NaN             NaN
# 49123                                                    NaN             NaN
#
#                                                       AIHuman  \
# ResponseId
# 1                             When I don’t trust AI’s answers
# 2           When I don’t trust AI’s answers;When I want to...
# 3           When I don’t trust AI’s answers;When I want to...
# 4           When I don’t trust AI’s answers;When I want to...
# 5                             When I don’t trust AI’s answers
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                                        AIOpen  \
# ResponseId
# 1                       Troubleshooting, profiling, debugging
# 2                                   All skills. AI is a flop.
# 3           Understand how things actually work, problem s...
# 4                                                         NaN
# 5           critical thinking, the skill to define the tas...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 1                       61256.0    10.0
# 2                      104413.0     9.0
# 3                       53061.0     8.0
# 4                       36197.0     6.0
# 5                       60000.0     7.0
# ...                         ...     ...
# 49119                       NaN     8.0
# 49120                       NaN     NaN
# 49121                       NaN     NaN
# 49122                       NaN     7.0
# 49123                       NaN     8.0
#
# [49123 rows x 169 columns]

# %%
df.rename(columns={"Age": "CurrentAge"}, inplace=True) # Permanent change

# %%
df
# Out:
#                                 MainBranch       CurrentAge  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
# ...                                    ...              ...
# 49119       I am a developer by profession  25-34 years old
# 49120       I am a developer by profession  35-44 years old
# 49121       I am a developer by profession  25-34 years old
# 49122       I am a developer by profession  25-34 years old
# 49123       I am a developer by profession  25-34 years old
#
#                                                       EdLevel  \
# ResponseId
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                         Associate degree (A.A., A.S., etc.)
# 3                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                       ...
# 49119            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49120            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49121       Secondary school (e.g. American high school, G...
# 49122                     Associate degree (A.A., A.S., etc.)
# 49123       Some college/university study without earning ...
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# 3           Independent contractor, freelancer, or self-em...
# 4                                                    Employed
# 5           Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 49119                                                Employed
# 49120                                                Employed
# 49121                                                Employed
# 49122                                                Employed
# 49123                                                Employed
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 1             Caring for dependents (children, elderly, etc.)      8.0
# 2                                                         NaN      2.0
# 3                                           None of the above     10.0
# 4                                           None of the above      4.0
# 5             Caring for dependents (children, elderly, etc.)     21.0
# ...                                                       ...      ...
# 49119                                                     NaN      9.0
# 49120         Caring for dependents (children, elderly, etc.)     13.0
# 49121                                                     NaN      2.0
# 49122       None of the above;Engaged in paid work (20-29 ...     10.0
# 49123                                       None of the above     10.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
# 2           Yes, I am not new to coding but am learning ne...
# 3           Yes, I am not new to coding but am learning ne...
# 4           Yes, I am not new to coding but am learning ne...
# 5           No, I am not new to coding and did not learn n...
# ...                                                       ...
# 49119       Yes, I am not new to coding but am learning ne...
# 49120       No, I am not new to coding and did not learn n...
# 49121       Yes, I am not new to coding but am learning ne...
# 49122       No, I am not new to coding and did not learn n...
# 49123       No, I am not new to coding and did not learn n...
#
#                                                     LearnCode  \
# ResponseId
# 1           Online Courses or Certification (includes all ...
# 2           Online Courses or Certification (includes all ...
# 3           Online Courses or Certification (includes all ...
# 4           Other online resources (e.g. standard search, ...
# 5                                                         NaN
# ...                                                       ...
# 49119       Online Courses or Certification (includes all ...
# 49120                                                     NaN
# 49121       Other online resources (e.g. standard search, ...
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                                   LearnCodeAI  \
# ResponseId
# 1           Yes, I learned how to use AI-enabled tools for...
# 2           Yes, I learned how to use AI-enabled tools for...
# 3           Yes, I learned how to use AI-enabled tools for...
# 4           Yes, I learned how to use AI-enabled tools for...
# 5           Yes, I learned how to use AI-enabled tools for...
# ...                                                       ...
# 49119       Yes, I learned how to use AI-enabled tools req...
# 49120       Yes, I learned how to use AI-enabled tools req...
# 49121       No, I didn't spend time learning in the past year
# 49122       Yes, I learned how to use AI-enabled tools for...
# 49123       No, I learned something that was not related t...
#
#                                                    AILearnHow  YearsCode  \
# ResponseId
# 1                         AI CodeGen tools or AI-enabled apps       14.0
# 2                         AI CodeGen tools or AI-enabled apps       10.0
# 3           AI CodeGen tools or AI-enabled apps;Technical ...       12.0
# 4           AI CodeGen tools or AI-enabled apps;Videos (no...        5.0
# 5           Technical documentation (is generated for/by t...       22.0
# ...                                                       ...        ...
# 49119       AI CodeGen tools or AI-enabled apps;Technical ...       13.0
# 49120       AI CodeGen tools or AI-enabled apps;Videos (no...       15.0
# 49121                                                     NaN        NaN
# 49122       Videos (not associated with specific online co...       14.0
# 49123                                                     NaN       15.0
#
#                           DevType                   OrgSize  \
# ResponseId
# 1               Developer, mobile        20 to 99 employees
# 2             Developer, back-end      500 to 999 employees
# 3            Developer, front-end                       NaN
# 4             Developer, back-end  10,000 or more employees
# 5             Engineering manager                       NaN
# ...                           ...                       ...
# 49119       Developer, full-stack      500 to 999 employees
# 49120       Developer, full-stack  1,000 to 4,999 employees
# 49121                         NaN                       NaN
# 49122       Developer, full-stack        20 to 99 employees
# 49123       Developer, full-stack    Less than 20 employees
#
#                             ICorPM  \
# ResponseId
# 1                   People manager
# 2           Individual contributor
# 3                              NaN
# 4           Individual contributor
# 5                              NaN
# ...                            ...
# 49119       Individual contributor
# 49120       Individual contributor
# 49121                          NaN
# 49122       Individual contributor
# 49123       Individual contributor
#
#                                                    RemoteWork  \
# ResponseId
# 1                                                      Remote
# 2           Hybrid (some in-person, leans heavy to flexibi...
# 3                                                         NaN
# 4                                                      Remote
# 5                                                         NaN
# ...                                                       ...
# 49119          Hybrid (some remote, leans heavy to in-person)
# 49120          Hybrid (some remote, leans heavy to in-person)
# 49121                                                     NaN
# 49122          Hybrid (some remote, leans heavy to in-person)
# 49123       Your choice (very flexible, you can come in wh...
#
#                                             PurchaseInfluence  \
# ResponseId
# 1           Yes, I influenced the purchase of a substantia...
# 2                                                          No
# 3                                                          No
# 4                                                          No
# 5           Yes, I endorsed a tool that was open-source an...
# ...                                                       ...
# 49119                                                      No
# 49120       Yes, I endorsed a tool that was open-source an...
# 49121                                                     NaN
# 49122       Yes, I influenced the purchase of a substantia...
# 49123       Yes, I influenced the purchase of a substantia...
#
#             TechEndorseIntro  TechEndorse_1  TechEndorse_2  TechEndorse_3  \
# ResponseId
# 1                       Work           10.0            7.0            9.0
# 2           Personal Project           13.0            1.0            2.0
# 3                       Work           12.0            2.0            3.0
# 4           Personal Project            2.0           12.0            6.0
# 5                       Work            6.0            3.0            1.0
# ...                      ...            ...            ...            ...
# 49119       Personal Project            8.0            2.0            4.0
# 49120                    NaN            NaN            NaN            NaN
# 49121                    NaN            NaN            NaN            NaN
# 49122                   Work            5.0            6.0            3.0
# 49123       Personal Project            9.0            2.0            3.0
#
#             TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  \
# ResponseId
# 1                     6.0            3.0           11.0           12.0
# 2                     9.0            4.0            3.0           12.0
# 3                     7.0            5.0           10.0           13.0
# 4                     5.0           13.0            3.0            8.0
# 5                     9.0           10.0            8.0            7.0
# ...                   ...            ...            ...            ...
# 49119                 5.0            6.0            7.0            9.0
# 49120                 NaN            NaN            NaN            NaN
# 49121                 NaN            NaN            NaN            NaN
# 49122                 8.0            1.0            9.0            7.0
# 49123                 1.0            6.0            4.0            7.0
#
#             TechEndorse_8  TechEndorse_9  TechEndorse_13 TechEndorse_13_TEXT  \
# ResponseId
# 1                     1.0            8.0            14.0                 NaN
# 2                     5.0            7.0            14.0                 NaN
# 3                     1.0            4.0            14.0                 NaN
# 4                    11.0            7.0            14.0                 NaN
# 5                     4.0            2.0            14.0                 NaN
# ...                   ...            ...             ...                 ...
# 49119                 3.0            1.0            10.0                 NaN
# 49120                 NaN            NaN             NaN                 NaN
# 49121                 NaN            NaN             NaN                 NaN
# 49122                 4.0            2.0            10.0                 NaN
# 49123                 5.0            8.0            10.0                 NaN
#
#             TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# ResponseId
# 1                   15.0           7.0           8.0          12.0
# 2                   14.0           1.0          13.0          10.0
# 3                    8.0           1.0           2.0          12.0
# 4                   10.0           5.0           8.0           4.0
# 5                    7.0          13.0           3.0           9.0
# ...                  ...           ...           ...           ...
# 49119                8.0           2.0           6.0           3.0
# 49120                NaN           NaN           NaN           NaN
# 49121                NaN           NaN           NaN           NaN
# 49122                9.0           7.0           8.0           2.0
# 49123                8.0           1.0           7.0           5.0
#
#             TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  \
# ResponseId
# 1                   11.0           1.0            6.0           13.0
# 2                    9.0           3.0            4.0            2.0
# 3                   13.0           3.0            9.0            4.0
# 4                   13.0          12.0            2.0            7.0
# 5                   12.0           6.0            1.0            8.0
# ...                  ...           ...            ...            ...
# 49119                9.0           4.0            1.0            5.0
# 49120                NaN           NaN            NaN            NaN
# 49121                NaN           NaN            NaN            NaN
# 49122                4.0           6.0            3.0            5.0
# 49123                6.0           2.0            3.0            4.0
#
#             TechOppose_16  TechOppose_15 TechOppose_15_TEXT  \
# ResponseId
# 1                     3.0           16.0                NaN
# 2                     5.0           15.0                NaN
# 3                    11.0           15.0                NaN
# 4                     1.0           15.0                NaN
# 5                    14.0           15.0                NaN
# ...                   ...            ...                ...
# 49119                 7.0           10.0                NaN
# 49120                 NaN            NaN                NaN
# 49121                 NaN            NaN                NaN
# 49122                 1.0           10.0                NaN
# 49123                 9.0           10.0                NaN
#
#                                 Industry  JobSatPoints_1  JobSatPoints_4  \
# ResponseId
# 1                                Fintech             3.0             9.0
# 2           Retail and Consumer Services            10.0             9.0
# 3                   Software Development             9.0            11.0
# 4           Retail and Consumer Services             1.0             5.0
# 5                   Software Development             9.0            13.0
# ...                                  ...             ...             ...
# 49119               Software Development            11.0            13.0
# 49120                                NaN             NaN             NaN
# 49121                                NaN             NaN             NaN
# 49122                      Manufacturing             8.0            14.0
# 49123               Software Development             NaN             NaN
#
#             JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# ResponseId
# 1                      5.0            10.0            12.0            11.0
# 2                     12.0             1.0             6.0             2.0
# 3                      8.0            12.0             1.0             5.0
# 4                      6.0             7.0             8.0             9.0
# 5                     14.0             8.0             6.0             5.0
# ...                    ...             ...             ...             ...
# 49119                 12.0            10.0             6.0             1.0
# 49120                  NaN             NaN             NaN             NaN
# 49121                  NaN             NaN             NaN             NaN
# 49122                 11.0            10.0             1.0             2.0
# 49123                  NaN             NaN             NaN             NaN
#
#             JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  JobSatPoints_13  \
# ResponseId
# 1                      2.0              6.0              7.0             13.0
# 2                     11.0              4.0              7.0             13.0
# 3                      2.0              4.0              3.0             13.0
# 4                     10.0             11.0             12.0             13.0
# 5                      7.0              2.0              1.0             12.0
# ...                    ...              ...              ...              ...
# 49119                  9.0             14.0              2.0              8.0
# 49120                  NaN              NaN              NaN              NaN
# 49121                  NaN              NaN              NaN              NaN
# 49122                  5.0             13.0              7.0             12.0
# 49123                  NaN              NaN              NaN              NaN
#
#             JobSatPoints_14  JobSatPoints_15  JobSatPoints_16  \
# ResponseId
# 1                      14.0             15.0              8.0
# 2                      14.0             15.0              5.0
# 3                      14.0             15.0             10.0
# 4                      14.0             15.0              3.0
# 5                      10.0             15.0              3.0
# ...                     ...              ...              ...
# 49119                   7.0             15.0              3.0
# 49120                   NaN              NaN              NaN
# 49121                   NaN              NaN              NaN
# 49122                   6.0             15.0              4.0
# 49123                   NaN              NaN              NaN
#
#            JobSatPoints_15_TEXT      AIThreat  \
# ResponseId
# 1                           NaN  I'm not sure
# 2                           NaN  I'm not sure
# 3                           NaN            No
# 4                           NaN            No
# 5                           NaN            No
# ...                         ...           ...
# 49119                       NaN  I'm not sure
# 49120                       NaN           NaN
# 49121                       NaN           NaN
# 49122                       NaN            No
# 49123                       NaN            No
#
#                                                       NewRole  ToolCountWork  \
# ResponseId
# 1           I have neither consider or transitioned into a...            7.0
# 2           I have transitioned into a new career and/or i...            6.0
# 3           I have transitioned into a new career and/or i...            3.0
# 4           I have neither consider or transitioned into a...            NaN
# 5           I have neither consider or transitioned into a...            4.0
# ...                                                       ...            ...
# 49119       I have somewhat considered changing my career ...            NaN
# 49120                                                     NaN            NaN
# 49121                                                     NaN            NaN
# 49122       I have somewhat considered changing my career ...            8.0
# 49123       I have somewhat considered changing my career ...            NaN
#
#             ToolCountPersonal      Country                  Currency  \
# ResponseId
# 1                         3.0      Ukraine         EUR European Euro
# 2                         5.0  Netherlands         EUR European Euro
# 3                         3.0      Ukraine     UAH Ukrainian hryvnia
# 4                         NaN      Ukraine         EUR European Euro
# 5                         3.0      Ukraine  USD United States dollar
# ...                       ...          ...                       ...
# 49119                     NaN          NaN                       NaN
# 49120                     NaN          NaN                       NaN
# 49121                     NaN          NaN                       NaN
# 49122                     2.0       France         EUR European Euro
# 49123                     NaN        Italy         EUR European Euro
#
#             CompTotal LanguageChoice  \
# ResponseId
# 1             52800.0            Yes
# 2             90000.0            Yes
# 3           2214000.0            Yes
# 4             31200.0            Yes
# 5             60000.0            Yes
# ...               ...            ...
# 49119             NaN            NaN
# 49120             NaN            NaN
# 49121             NaN            NaN
# 49122         50000.0            Yes
# 49123         40000.0            NaN
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 1                            Bash/Shell (all shells);Dart;SQL
# 2                                                        Java
# 3                         Dart;HTML/CSS;JavaScript;TypeScript
# 4                                             Java;Kotlin;SQL
# 5           C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                  C#;SQL
# 49123                                                     NaN
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                        Dart
# 2                                           Java;Python;Swift
# 3                         Dart;HTML/CSS;JavaScript;TypeScript
# 4                                                 Java;Kotlin
# 5                    C#;Java;JavaScript;Python;SQL;TypeScript
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       C#;HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;...
# 49123                                                     NaN
#
#                                      LanguageAdmired LanguagesHaveEntry  \
# ResponseId
# 1                                               Dart                NaN
# 2                                               Java                NaN
# 3                Dart;HTML/CSS;JavaScript;TypeScript                NaN
# 4                                        Java;Kotlin                NaN
# 5           C#;Java;JavaScript;Python;SQL;TypeScript                NaN
# ...                                              ...                ...
# 49119                                            NaN                NaN
# 49120                                            NaN                NaN
# 49121                                            NaN                NaN
# 49122                                         C#;SQL      Visual FoxPro
# 49123                                            NaN                NaN
#
#            LanguagesWantEntry DatabaseChoice  \
# ResponseId
# 1                         NaN            Yes
# 2                         NaN            Yes
# 3                         NaN            Yes
# 4                         NaN             No
# 5                         NaN            Yes
# ...                       ...            ...
# 49119                     NaN            NaN
# 49120                     NaN            NaN
# 49121                     NaN            NaN
# 49122                     NaN            Yes
# 49123                     NaN            NaN
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 1                                  Cloud Firestore;PostgreSQL
# 2                                            Dynamodb;MongoDB
# 3                                    MongoDB;MySQL;PostgreSQL
# 4                                                         NaN
# 5           Elasticsearch;Microsoft SQL Server;MySQL;Oracl...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                              Microsoft SQL Server;MySQL
# 49123                                                     NaN
#
#                         DatabaseWantToWorkWith  \
# ResponseId
# 1                                          NaN
# 2                             Dynamodb;MongoDB
# 3           Firebase Realtime Database;MongoDB
# 4                                          NaN
# 5              Elasticsearch;Oracle;PostgreSQL
# ...                                        ...
# 49119                                      NaN
# 49120                                      NaN
# 49121                                      NaN
# 49122        MariaDB;MongoDB;PostgreSQL;SQLite
# 49123                                      NaN
#
#                             DatabaseAdmired DatabaseHaveEntry  \
# ResponseId
# 1                                       NaN               NaN
# 2                          Dynamodb;MongoDB               NaN
# 3                                   MongoDB               NaN
# 4                                       NaN               NaN
# 5           Elasticsearch;Oracle;PostgreSQL               NaN
# ...                                     ...               ...
# 49119                                   NaN               NaN
# 49120                                   NaN               NaN
# 49121                                   NaN               NaN
# 49122                                   NaN               NaN
# 49123                                   NaN               NaN
#
#            DatabaseWantEntry PlatformChoice  \
# ResponseId
# 1                        NaN            Yes
# 2                        NaN            Yes
# 3                        NaN            Yes
# 4                        NaN            Yes
# 5                        NaN            Yes
# ...                      ...            ...
# 49119                    NaN            NaN
# 49120                    NaN            NaN
# 49121                    NaN            NaN
# 49122                    NaN             No
# 49123                    NaN            NaN
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 1           Amazon Web Services (AWS);Cloudflare;Firebase;...
# 2           Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 3                                   Datadog;Firebase;npm;pnpm
# 4                      Amazon Web Services (AWS);Google Cloud
# 5           Amazon Web Services (AWS);APT;Docker;Make;Mave...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                        PlatformWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 3            Amazon Web Services (AWS);Firebase;npm;pnpm;Vite
# 4                      Amazon Web Services (AWS);Google Cloud
# 5           Amazon Web Services (AWS);APT;Docker;Maven (bu...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                               PlatformAdmired  \
# ResponseId
# 1                                                         NaN
# 2           Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 3                                           Firebase;npm;pnpm
# 4                      Amazon Web Services (AWS);Google Cloud
# 5           Amazon Web Services (AWS);APT;Docker;Maven (bu...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#            PlatformHaveEntry PlatformWantEntry WebframeChoice  \
# ResponseId
# 1                        NaN               NaN             No
# 2                        NaN               NaN            Yes
# 3                        NaN               NaN            Yes
# 4                        NaN               NaN            Yes
# 5                        NaN               NaN            Yes
# ...                      ...               ...            ...
# 49119                    NaN               NaN            NaN
# 49120                    NaN               NaN            NaN
# 49121                    NaN               NaN            NaN
# 49122                    NaN               NaN             No
# 49123                    NaN               NaN            NaN
#
#                                WebframeHaveWorkedWith  \
# ResponseId
# 1                                                 NaN
# 2                                         Spring Boot
# 3                               Next.js;Node.js;React
# 4                                         Spring Boot
# 5           Angular;ASP.NET;ASP.NET Core;Flask;jQuery
# ...                                               ...
# 49119                                             NaN
# 49120                                             NaN
# 49121                                             NaN
# 49122                                             NaN
# 49123                                             NaN
#
#                 WebframeWantToWorkWith             WebframeAdmired  \
# ResponseId
# 1                                  NaN                         NaN
# 2                          Spring Boot                 Spring Boot
# 3                Next.js;Node.js;React       Next.js;Node.js;React
# 4                          Spring Boot                 Spring Boot
# 5           Angular;ASP.NET Core;Flask  Angular;ASP.NET Core;Flask
# ...                                ...                         ...
# 49119                              NaN                         NaN
# 49120                              NaN                         NaN
# 49121                              NaN                         NaN
# 49122                              NaN                         NaN
# 49123                              NaN                         NaN
#
#            WebframeHaveEntry WebframeWantEntry DevEnvsChoice  \
# ResponseId
# 1                        NaN               NaN           Yes
# 2                        NaN               NaN           Yes
# 3                        NaN          Solid.js           Yes
# 4                        NaN               NaN            No
# 5                        NaN               NaN           Yes
# ...                      ...               ...           ...
# 49119                    NaN               NaN           NaN
# 49120                    NaN               NaN           NaN
# 49121                    NaN               NaN           NaN
# 49122                    NaN               NaN           Yes
# 49123                    NaN               NaN           NaN
#
#                                         DevEnvsHaveWorkedWith  \
# ResponseId
# 1           Android Studio;Notepad++;Visual Studio;Visual ...
# 2              IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode
# 3                                          Visual Studio Code
# 4                                                         NaN
# 5           Eclipse;IntelliJ IDEA;Jupyter Notebook/Jupyter...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                           Visual Studio
# 49123                                                     NaN
#
#                                         DevEnvsWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2              IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode
# 3                                 Visual Studio Code;Windsurf
# 4                                                         NaN
# 5           IntelliJ IDEA;Jupyter Notebook/JupyterLab;Note...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       Bolt;Claude Code;Cursor;Visual Studio;Visual S...
# 49123                                                     NaN
#
#                                                DevEnvsAdmired DevEnvHaveEntry  \
# ResponseId
# 1                                                         NaN             NaN
# 2              IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode             NaN
# 3                                          Visual Studio Code             NaN
# 4                                                         NaN             NaN
# 5           IntelliJ IDEA;Jupyter Notebook/JupyterLab;Note...             NaN
# ...                                                       ...             ...
# 49119                                                     NaN             NaN
# 49120                                                     NaN             NaN
# 49121                                                     NaN             NaN
# 49122                                           Visual Studio             NaN
# 49123                                                     NaN             NaN
#
#            DevEnvWantEntry                SOTagsHaveWorkedWith  \
# ResponseId
# 1                      NaN                                 NaN
# 2                      NaN                                 NaN
# 3                      NaN                       Google Gemini
# 4                      NaN                      Amazon Bedrock
# 5                      NaN  Large Language Model;Google Gemini
# ...                    ...                                 ...
# 49119                  NaN                                 NaN
# 49120                  NaN                                 NaN
# 49121                  NaN                                 NaN
# 49122                  NaN                    .NET 8 or higher
# 49123                  NaN                                 NaN
#
#                SOTagsWantToWorkWith         SOTagsAdmired SOTagsHaveEntry  \
# ResponseId
# 1                               NaN                   NaN             NaN
# 2                               NaN                   NaN             NaN
# 3           Google Gemini;Shadcn/ui         Google Gemini             NaN
# 4                               NaN                   NaN             NaN
# 5              Large Language Model  Large Language Model             NaN
# ...                             ...                   ...             ...
# 49119                           NaN                   NaN             NaN
# 49120                           NaN                   NaN             NaN
# 49121                           NaN                   NaN             NaN
# 49122              .NET 8 or higher      .NET 8 or higher             NaN
# 49123                           NaN                   NaN             NaN
#
#            SOTagsWant Entry         OpSysPersonal use  \
# ResponseId
# 1                       NaN     Windows;MacOS;Android
# 2                       NaN  Windows;MacOS;iOS;iPadOS
# 3                       NaN             MacOS;Android
# 4                       NaN                   Windows
# 5                       NaN               Windows;iOS
# ...                     ...                       ...
# 49119                   NaN                       NaN
# 49120                   NaN                       NaN
# 49121                   NaN                       NaN
# 49122                   NaN           Windows;Android
# 49123                   NaN                       NaN
#
#                        OpSysProfessional use  \
# ResponseId
# 1           Windows;MacOS;Android;iOS;iPadOS
# 2                                      MacOS
# 3                                      MacOS
# 4                             Windows;Ubuntu
# 5                      Windows;Ubuntu;Debian
# ...                                      ...
# 49119                                    NaN
# 49120                                    NaN
# 49121                                    NaN
# 49122                                Windows
# 49123                                    NaN
#
#                          OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 1           Confluence;GitHub;GitLab;Jira;Markdown File
# 2                                Confluence;GitHub;Jira
# 3                                    GitHub;GitLab;Jira
# 4                                      GitLab;Jira;Miro
# 5                              Azure Devops;GitHub;Jira
# ...                                                 ...
# 49119                                               NaN
# 49120                                               NaN
# 49121                                               NaN
# 49122                Asana;Azure Devops;GitHub;Obsidian
# 49123                                               NaN
#
#            OfficeStackAsyncWantToWorkWith   OfficeStackAsyncAdmired  \
# ResponseId
# 1                           Markdown File             Markdown File
# 2                  Confluence;GitHub;Jira    Confluence;GitHub;Jira
# 3                      GitHub;GitLab;Jira        GitHub;GitLab;Jira
# 4                             GitLab;Jira               GitLab;Jira
# 5                Azure Devops;GitHub;Jira  Azure Devops;GitHub;Jira
# ...                                   ...                       ...
# 49119                                 NaN                       NaN
# 49120                                 NaN                       NaN
# 49121                                 NaN                       NaN
# 49122               Asana;GitHub;Obsidian     Asana;GitHub;Obsidian
# 49123                                 NaN                       NaN
#
#            OfficeStackHaveEntry OfficeStackWantEntry  \
# ResponseId
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# 4                           NaN                  NaN
# 5                           NaN                  NaN
# ...                         ...                  ...
# 49119                       NaN                  NaN
# 49120                       NaN                  NaN
# 49121                       NaN                  NaN
# 49122                       NaN                  NaN
# 49123                       NaN                  NaN
#
#                                    CommPlatformHaveWorkedWith  \
# ResponseId
# 1           Stack Overflow;Reddit;GitHub (public projects,...
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4                      Stack Overflow;Reddit;YouTube;LinkedIn
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                 Stack Overflow;Discord;YouTube;LinkedIn
# 49123                                                     NaN
#
#                                    CommPlatformWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4           Stack Overflow;Reddit;GitHub (public projects,...
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                 Stack Overflow;Discord;YouTube;LinkedIn
# 49123                                                     NaN
#
#                                           CommPlatformAdmired  \
# ResponseId
# 1                                                         NaN
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4                      Stack Overflow;Reddit;YouTube;LinkedIn
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                 Stack Overflow;Discord;YouTube;LinkedIn
# 49123                                                     NaN
#
#            CommPlatformHaveEntr CommPlatformWantEntr AIModelsChoice  \
# ResponseId
# 1                           NaN                  NaN            Yes
# 2                           NaN                  NaN            Yes
# 3                           NaN                  NaN            Yes
# 4                           NaN                  NaN             No
# 5                           NaN                  NaN            Yes
# ...                         ...                  ...            ...
# 49119                       NaN                  NaN            NaN
# 49120                       NaN                  NaN            NaN
# 49121                       NaN                  NaN            NaN
# 49122                       NaN                  NaN             No
# 49123                       NaN                  NaN            NaN
#
#                                        AIModelsHaveWorkedWith  \
# ResponseId
# 1           openAI GPT (chatbot models);openAI Image gener...
# 2                                 openAI GPT (chatbot models)
# 3           Gemini (Flash general purpose models);openAI G...
# 4                                                         NaN
# 5                                 openAI GPT (chatbot models)
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                        AIModelsWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                 openAI GPT (chatbot models)
# 3           Gemini (Flash general purpose models);Gemini (...
# 4                                                         NaN
# 5                                 openAI GPT (chatbot models)
# ...
# 49123                                                     NaN
#
#                                                     AIExplain  \
# ResponseId
# 1                                                          No
# 2                                                          No
# 3                                                          No
# 4                                                          NO
# 5                                                      partly
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       no, IA do not control de code part, it's essen...
# 49123                                                     NaN
#
#                                                      AIAgents  \
# ResponseId
# 1           Yes, I use AI agents at work monthly or infreq...
# 2                                     No, and I don't plan to
# 3                         Yes, I use AI agents at work weekly
# 4           Yes, I use AI agents at work monthly or infreq...
# 5                                     No, and I don't plan to
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       No, I use AI exclusively in copilot/autocomple...
# 49123                                                     NaN
#
#                       AIAgentChange          AIAgent_Uses  \
# ResponseId
# 1           Not at all or minimally  Software engineering
# 2           Not at all or minimally                   NaN
# 3                     Yes, somewhat  Software engineering
# 4           Not at all or minimally  Software engineering
# 5            Yes, to a great extent                   NaN
# ...                             ...                   ...
# 49119                           NaN                   NaN
# 49120                           NaN                   NaN
# 49121                           NaN                   NaN
# 49122       Not at all or minimally             Marketing
# 49123                           NaN                   NaN
#
#                                              AgentUsesGeneral  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                            Multi-platform search enablement
# 4                                         Language processing
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122       Multi-platform search enablement;Language proc...
# 49123                                                     NaN
#
#                                   AIAgentImpactSomewhat agree  \
# ResponseId
# 1           AI agents have increased my productivity.;AI a...
# 2                                                         NaN
# 3           AI agents have increased my productivity.;AI a...
# 4           AI agents have accelerated my learning about n...
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                          AIAgentImpactNeutral  \
# ResponseId
# 1           AI agents have helped me automate repetitive t...
# 2                                                         NaN
# 3           AI agents have improved the quality of my code...
# 4           AI agents have increased my productivity.;AI a...
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                AIAgentImpactSomewhat disagree  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           AI agents have improved collaboration within m...
# 4           AI agents have helped me automate repetitive t...
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#            AIAgentImpactStrongly agree AIAgentImpactStrongly disagree  \
# ResponseId
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# 5                                  NaN                            NaN
# ...                                ...                            ...
# 49119                              NaN                            NaN
# 49120                              NaN                            NaN
# 49121                              NaN                            NaN
# 49122                              NaN                            NaN
# 49123                              NaN                            NaN
#
#                                      AIAgentChallengesNeutral  \
# ResponseId
# 1           I am concerned about the accuracy of the infor...
# 2           It takes significant time and effort to learn ...
# 3           It takes significant time and effort to learn ...
# 4           It takes significant time and effort to learn ...
# 5           Integrating AI agents with my existing tools a...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                            AIAgentChallengesSomewhat disagree  \
# ResponseId
# 1           Integrating AI agents with my existing tools a...
# 2                                                         NaN
# 3           My company's IT and/or InfoSec teams have stri...
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                               AIAgentChallengesStrongly agree  \
# ResponseId
# 1           The cost of using certain AI agent platforms i...
# 2           I am concerned about the accuracy of the infor...
# 3                                                         NaN
# 4           I am concerned about the accuracy of the infor...
# 5           I am concerned about the accuracy of the infor...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                               AIAgentChallengesSomewhat agree  \
# ResponseId
# 1                                                         NaN
# 2           Integrating AI agents with my existing tools a...
# 3           I am concerned about the accuracy of the infor...
# 4           Integrating AI agents with my existing tools a...
# 5           It takes significant time and effort to learn ...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#            AIAgentChallengesStrongly disagree AIAgentKnowledge  \
# ResponseId
# 1                                         NaN              NaN
# 2                                         NaN              NaN
# 3                                         NaN            Redis
# 4                                         NaN              NaN
# 5                                         NaN              NaN
# ...                                       ...              ...
# 49119                                     NaN              NaN
# 49120                                     NaN              NaN
# 49121                                     NaN              NaN
# 49122                                     NaN              NaN
# 49123                                     NaN              NaN
#
#            AIAgentKnowWrite AIAgentOrchestration AIAgentOrchWrite  \
# ResponseId
# 1                       NaN            Vertex AI              NaN
# 2                       NaN                  NaN              NaN
# 3                       NaN                  NaN              NaN
# 4                       NaN                  NaN              NaN
# 5                       NaN                  NaN              NaN
# ...                     ...                  ...              ...
# 49119                   NaN                  NaN              NaN
# 49120                   NaN                  NaN              NaN
# 49121                   NaN                  NaN              NaN
# 49122                   NaN                  NaN              NaN
# 49123                   NaN                  NaN              NaN
#
#            AIAgentObserveSecure AIAgentObsWrite  \
# ResponseId
# 1                           NaN             NaN
# 2                           NaN             NaN
# 3                           NaN             NaN
# 4                           NaN             NaN
# 5                           NaN             NaN
# ...                         ...             ...
# 49119                       NaN             NaN
# 49120                       NaN             NaN
# 49121                       NaN             NaN
# 49122                       NaN             NaN
# 49123                       NaN             NaN
#
#                                              AIAgentExternal AIAgentExtWrite  \
# ResponseId
# 1                                                    ChatGPT             NaN
# 2                                                        NaN             NaN
# 3           ChatGPT;Claude Code;GitHub Copilot;Google Gemini             NaN
# 4                                        ChatGPT;Claude Code             NaN
# 5                                                        NaN             NaN
# ...                                                      ...             ...
# 49119                                                    NaN             NaN
# 49120                                                    NaN             NaN
# 49121                                                    NaN             NaN
# 49122                                                    NaN             NaN
# 49123                                                    NaN             NaN
#
#                                                       AIHuman  \
# ResponseId
# 1                             When I don’t trust AI’s answers
# 2           When I don’t trust AI’s answers;When I want to...
# 3           When I don’t trust AI’s answers;When I want to...
# 4           When I don’t trust AI’s answers;When I want to...
# 5                             When I don’t trust AI’s answers
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#                                                        AIOpen  \
# ResponseId
# 1                       Troubleshooting, profiling, debugging
# 2                                   All skills. AI is a flop.
# 3           Understand how things actually work, problem s...
# 4                                                         NaN
# 5           critical thinking, the skill to define the tas...
# ...                                                       ...
# 49119                                                     NaN
# 49120                                                     NaN
# 49121                                                     NaN
# 49122                                                     NaN
# 49123                                                     NaN
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 1                       61256.0    10.0
# 2                      104413.0     9.0
# 3                       53061.0     8.0
# 4                       36197.0     6.0
# 5                       60000.0     7.0
# ...                         ...     ...
# 49119                       NaN     8.0
# 49120                       NaN     NaN
# 49121                       NaN     NaN
# 49122                       NaN     7.0
# 49123                       NaN     8.0
#
# [49123 rows x 169 columns]

# %%
df["Employment"].map({"Employed": True, "Unemployed": False})
# Out:
# ResponseId
# 1        True
# 2        True
# 3         NaN
# 4        True
# 5         NaN
#          ...
# 49119    True
# 49120    True
# 49121    True
# 49122    True
# 49123    True
# Name: Employment, Length: 49123, dtype: object

# %%
df.sort_values(by="Country", inplace=True)

# %%
df["Country"].head(50)
# Out:
# ResponseId
# 7167     Afghanistan
# 6010     Afghanistan
# 7925     Afghanistan
# 40307    Afghanistan
# 7077     Afghanistan
# 45925    Afghanistan
# 40967    Afghanistan
# 15708    Afghanistan
# 38609    Afghanistan
# 19816    Afghanistan
# 6836     Afghanistan
# 27099    Afghanistan
# 44797    Afghanistan
# 3888         Albania
# 28588        Albania
# 35184        Albania
# 33940        Albania
# 14758        Albania
# 44946        Albania
# 35934        Albania
# 16850        Albania
# 25304        Albania
# 41907        Albania
# 3185         Albania
# 36997        Albania
# 37731        Albania
# 2023         Albania
# 11874        Albania
# 22400        Albania
# 16239        Albania
# 8776         Albania
# 27802        Albania
# 45421        Albania
# 44879        Albania
# 48950        Albania
# 36568        Algeria
# 23091        Algeria
# 39760        Algeria
# 26446        Algeria
# 24875        Algeria
# 36661        Algeria
# 41296        Algeria
# 1841         Algeria
# 5708         Algeria
# 5707         Algeria
# 31352        Algeria
# 14530        Algeria
# 35298        Algeria
# 14680        Algeria
# 36710        Algeria
# Name: Country, dtype: object

# %%
df[["Country", "WorkExp"]].head(50)
# Out:
#                 Country  WorkExp
# ResponseId
# 7167        Afghanistan      4.0
# 6010        Afghanistan      5.0
# 7925        Afghanistan      2.0
# 40307       Afghanistan      8.0
# 7077        Afghanistan      7.0
# 45925       Afghanistan      9.0
# 40967       Afghanistan      8.0
# 15708       Afghanistan      NaN
# 38609       Afghanistan     75.0
# 19816       Afghanistan      NaN
# 6836        Afghanistan      2.0
# 27099       Afghanistan      NaN
# 44797       Afghanistan     30.0
# 3888            Albania      4.0
# 28588           Albania     30.0
# 35184           Albania      7.0
# 33940           Albania      2.0
# 14758           Albania      6.0
# 44946           Albania     10.0
# 35934           Albania      9.0
# 16850           Albania     10.0
# 25304           Albania      3.0
# 41907           Albania      3.0
# 3185            Albania     40.0
# 36997           Albania      1.0
# 37731           Albania      7.0
# 2023            Albania     15.0
# 11874           Albania      1.0
# 22400           Albania     47.0
# 16239           Albania      4.0
# 8776            Albania      2.0
# 27802           Albania      5.0
# 45421           Albania      2.0
# 44879           Albania     24.0
# 48950           Albania     25.0
# 36568           Algeria     20.0
# 23091           Algeria      2.0
# 39760           Algeria     20.0
# 26446           Algeria      6.0
# 24875           Algeria      NaN
# 36661           Algeria      3.0
# 41296           Algeria     30.0
# 1841            Algeria      2.0
# 5708            Algeria      NaN
# 5707            Algeria     28.0
# 31352           Algeria      3.0
# 14530           Algeria      3.0
# 35298           Algeria      2.0
# 14680           Algeria      9.0
# 36710           Algeria      NaN

# %%
df.sort_values(by=["Country", "WorkExp"], ascending=[True, False], inplace=True)

# %%
df[["Country", "WorkExp"]].head(50)
# Out:
#                 Country  WorkExp
# ResponseId
# 38609       Afghanistan     75.0
# 44797       Afghanistan     30.0
# 45925       Afghanistan      9.0
# 40307       Afghanistan      8.0
# 40967       Afghanistan      8.0
# 7077        Afghanistan      7.0
# 6010        Afghanistan      5.0
# 7167        Afghanistan      4.0
# 7925        Afghanistan      2.0
# 6836        Afghanistan      2.0
# 15708       Afghanistan      NaN
# 19816       Afghanistan      NaN
# 27099       Afghanistan      NaN
# 22400           Albania     47.0
# 3185            Albania     40.0
# 28588           Albania     30.0
# 48950           Albania     25.0
# 44879           Albania     24.0
# 2023            Albania     15.0
# 44946           Albania     10.0
# 16850           Albania     10.0
# 35934           Albania      9.0
# 35184           Albania      7.0
# 37731           Albania      7.0
# 14758           Albania      6.0
# 27802           Albania      5.0
# 3888            Albania      4.0
# 16239           Albania      4.0
# 25304           Albania      3.0
# 41907           Albania      3.0
# 33940           Albania      2.0
# 8776            Albania      2.0
# 45421           Albania      2.0
# 36997           Albania      1.0
# 11874           Albania      1.0
# 41296           Algeria     30.0
# 5707            Algeria     28.0
# 36568           Algeria     20.0
# 39760           Algeria     20.0
# 23950           Algeria     15.0
# 11322           Algeria     15.0
# 37619           Algeria     15.0
# 41847           Algeria     15.0
# 35518           Algeria     12.0
# 14680           Algeria      9.0
# 4527            Algeria      7.0
# 26446           Algeria      6.0
# 30107           Algeria      6.0
# 49028           Algeria      5.0
# 1541            Algeria      4.0

# %%
df["WorkExp"].nlargest(10)
# Out:
# ResponseId
# 23779    100.0
# 19681    100.0
# 36625    100.0
# 18574    100.0
# 12141    100.0
# 3286     100.0
# 33197    100.0
# 16716    100.0
# 38103    100.0
# 44527    100.0
# Name: WorkExp, dtype: float64

# %%
df.nlargest(10,"WorkExp")
# Out:
#                                                    MainBranch  \
# ResponseId
# 23779       I am not primarily a developer, but I write co...
# 19681       I am not primarily a developer, but I write co...
# 36625                          I am a developer by profession
# 18574                             I code primarily as a hobby
# 12141                             I code primarily as a hobby
# 3286                              I code primarily as a hobby
# 33197                                   I am learning to code
# 16716                          I am a developer by profession
# 38103                             I code primarily as a hobby
# 44527                          I am a developer by profession
#
#                    CurrentAge  \
# ResponseId
# 23779         35-44 years old
# 19681       Prefer not to say
# 36625         55-64 years old
# 18574         25-34 years old
# 12141         35-44 years old
# 3286        65 years or older
# 33197         18-24 years old
# 16716         18-24 years old
# 38103         18-24 years old
# 44527         18-24 years old
#
#                                                       EdLevel  \
# ResponseId
# 23779       Secondary school (e.g. American high school, G...
# 19681       Secondary school (e.g. American high school, G...
# 36625                                 Other (please specify):
# 18574         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 12141                               Primary/elementary school
# 3286             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33197                                 Other (please specify):
# 16716       Secondary school (e.g. American high school, G...
# 38103         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 44527                                 Other (please specify):
#
#                      Employment  \
# ResponseId
# 23779                  Employed
# 19681                   Student
# 36625                  Employed
# 18574       I prefer not to say
# 12141                   Student
# 3286                    Retired
# 33197                  Employed
# 16716                  Employed
# 38103                   Retired
# 44527       I prefer not to say
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 23779       Attending school (full-time);Attending school ...    100.0
# 19681       Attending school (part-time);Engaged in paid w...    100.0
# 36625                            Attending school (full-time)    100.0
# 18574                                                     NaN    100.0
# 12141                            Attending school (full-time)    100.0
# 3286                                        None of the above    100.0
# 33197       Engaged in paid work (20-29 hours per week);En...    100.0
# 16716                                       None of the above    100.0
# 38103                            Attending school (full-time)    100.0
# 44527                                                     NaN    100.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 23779       Yes, I am not new to coding but am learning ne...
# 19681          Yes, I am new to coding or currently a student
# 36625          Yes, I am new to coding or currently a student
# 18574          Yes, I am new to coding or currently a student
# 12141          Yes, I am new to coding or currently a student
# 3286        No, I am not new to coding and did not learn n...
# 33197       Yes, I am not new to coding but am learning ne...
# 16716          Yes, I am new to coding or currently a student
# 38103       No, I am not new to coding and did not learn n...
# 44527       No, I am not new to coding and did not learn n...
#
#                                                     LearnCode  \
# ResponseId
# 23779                        Stack Overflow or Stack Exchange
# 19681       Technical documentation (is generated for/by t...
# 36625                 School (i.e., University, College, etc)
# 18574                  Books / Physical media;Coding Bootcamp
# 12141       Online Courses or Certification (includes all ...
# 3286                                                      NaN
# 33197                                 Other (please specify):
# 16716                                  Books / Physical media
# 38103                                                     NaN
# 44527                                                     NaN
#
#                                                   LearnCodeAI  \
# ResponseId
# 23779       Yes, I learned how to use AI-enabled tools req...
# 19681       No, I didn't spend time learning in the past year
# 36625                                                     NaN
# 18574       Yes, I learned how to use AI-enabled tools for...
# 12141       Yes, I learned how to use AI-enabled tools for...
# 3286        No, I learned something that was not related t...
# 33197                                                     NaN
# 16716       No, I didn't spend time learning in the past year
# 38103       No, I learned something that was not related t...
# 44527       No, I learned something that was not related t...
#
#                                                    AILearnHow  YearsCode  \
# ResponseId
# 23779       Stack Overflow or Stack Exchange;School (i.e.,...      100.0
# 19681                                                     NaN      100.0
# 36625                                                     NaN        8.0
# 18574                                       Blogs or podcasts        1.0
# 12141                 School (i.e., University, College, etc)      100.0
# 3286                                                      NaN       49.0
# 33197                                                     NaN        NaN
# 16716                                                     NaN      100.0
# 38103                                                     NaN      100.0
# 44527                                                     NaN        1.0
#
#                                 DevType  \
# ResponseId
# 23779               Academic researcher
# 19681                 Developer, mobile
# 36625           Other (please specify):
# 18574       Support engineer or analyst
# 12141                           Student
# 3286                            Retired
# 33197               Academic researcher
# 16716              System administrator
# 38103               Academic researcher
# 44527           Other (please specify):
#
#                                                       OrgSize  \
# ResponseId
# 23779                                  Less than 20 employees
# 19681       Just me - I am a freelancer, sole proprietor, ...
# 36625                                10,000 or more employees
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                5,000 to 9,999 employees
# 16716                                10,000 or more employees
# 38103                                                     NaN
# 44527                                                     NaN
#
#                             ICorPM  \
# ResponseId
# 23779       Individual contributor
# 19681               People manager
# 36625               People manager
# 18574                          NaN
# 12141                          NaN
# 3286                           NaN
# 33197               People manager
# 16716       Individual contributor
# 38103                          NaN
# 44527                          NaN
#
#                                                    RemoteWork  \
# ResponseId
# 23779          Hybrid (some remote, leans heavy to in-person)
# 19681       Hybrid (some in-person, leans heavy to flexibi...
# 36625                                               In-person
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197       Your choice (very flexible, you can come in wh...
# 16716                                                  Remote
# 38103                                                     NaN
# 44527                                                     NaN
#
#                                             PurchaseInfluence  \
# ResponseId
# 23779       Yes, I influenced the purchase of a substantia...
# 19681       Yes, I influenced the purchase of a tool that ...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716       Yes, I endorsed a tool that was open-source an...
# 38103                                                     NaN
# 44527                                                     NaN
#
#             TechEndorseIntro  TechEndorse_1  TechEndorse_2  TechEndorse_3  \
# ResponseId
# 23779                   Work            NaN            NaN            NaN
# 19681                 School            4.0            1.0            5.0
# 36625       Personal Project            3.0            4.0            9.0
# 18574                 School            4.0            7.0            5.0
# 12141                 School            4.0            7.0            3.0
# 3286        Personal Project            3.0            1.0            2.0
# 33197                   Work            NaN            NaN            NaN
# 16716                   Work            9.0            7.0            3.0
# 38103       Personal Project            8.0            7.0            2.0
# 44527       Personal Project            2.0            6.0            8.0
#
#             TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  \
# ResponseId
# 23779                 NaN            NaN            NaN            NaN
# 19681                 6.0            2.0            7.0            9.0
# 36625                 5.0            1.0            2.0            6.0
# 18574                 9.0            8.0            2.0            6.0
# 12141                 1.0            2.0            9.0            5.0
# 3286                  8.0            9.0            6.0            7.0
# 33197                 NaN            NaN            NaN            NaN
# 16716                 1.0            6.0            5.0            4.0
# 38103                 9.0            6.0            5.0            3.0
# 44527                 9.0            1.0            7.0            5.0
#
#             TechEndorse_8  TechEndorse_9  TechEndorse_13  \
# ResponseId
# 23779                 NaN            NaN             NaN
# 19681                 3.0            8.0            10.0
# 36625                 7.0            8.0            10.0
# 18574                 3.0            1.0            10.0
# 12141                 6.0            8.0            10.0
# 3286                  4.0            5.0            10.0
# 33197                 NaN            NaN             NaN
# 16716                 2.0            8.0            10.0
# 38103                 4.0            1.0            10.0
# 44527                 3.0            4.0            10.0
#
#                         TechEndorse_13_TEXT  TechOppose_1  TechOppose_2  \
# ResponseId
# 23779                                   NaN           NaN           NaN
# 19681                                   NaN           9.0           6.0
# 36625                             1234.6789           NaN           NaN
# 18574                                   NaN           6.0           2.0
# 12141                                   NaN           3.0           5.0
# 3286                                    NaN           6.0           1.0
# 33197                                   NaN           NaN           NaN
# 16716                                   NaN           4.0           1.0
# 38103                                   NaN           4.0           9.0
# 44527       My new company in Nepal Ramjuce           1.0           2.0
#
#             TechOppose_3  TechOppose_5  TechOppose_7  TechOppose_9  \
# ResponseId
# 23779                NaN           NaN           NaN           NaN
# 19681                1.0           8.0           4.0           3.0
# 36625                NaN           NaN           NaN           NaN
# 18574                7.0           4.0           9.0           3.0
# 12141                2.0           4.0           1.0           7.0
# 3286                 5.0           3.0           8.0           4.0
# 33197                NaN           NaN           NaN           NaN
# 16716                5.0           3.0           8.0           9.0
# 38103                7.0           2.0           1.0           8.0
# 44527                4.0           3.0           8.0           6.0
#
#             TechOppose_11  TechOppose_13  TechOppose_16  TechOppose_15  \
# ResponseId
# 23779                 NaN            NaN            NaN            NaN
# 19681                 5.0            2.0            7.0           10.0
# 36625                 NaN            NaN            NaN            NaN
# 18574                 5.0            8.0            1.0           10.0
# 12141                 6.0            9.0            8.0           10.0
# 3286                  9.0            2.0            7.0           10.0
# 33197                 NaN            NaN            NaN            NaN
# 16716                 2.0            6.0            7.0           10.0
# 38103                 6.0            5.0            3.0           10.0
# 44527                 5.0            7.0            9.0           10.0
#
#                                TechOppose_15_TEXT              Industry  \
# ResponseId
# 23779                                         NaN                Energy
# 19681                                         NaN               Fintech
# 36625                                         NaN                Other:
# 18574                                         NaN                   NaN
# 12141                                         NaN                   NaN
# 3286                                          NaN                   NaN
# 33197                                         NaN  Software Development
# 16716                                         NaN  Software Development
# 38103                                         NaN                   NaN
# 44527       How to create a money the I hard work                   NaN
#
#             JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  \
# ResponseId
# 23779                  NaN             NaN             NaN             NaN
# 19681                  NaN             NaN             NaN             NaN
# 36625                 13.0             4.0             3.0             8.0
# 18574                  NaN             NaN             NaN             NaN
# 12141                  NaN             NaN             NaN             NaN
# 3286                   NaN             NaN             NaN             NaN
# 33197                  NaN             NaN             NaN             NaN
# 16716                  NaN             NaN             NaN             NaN
# 38103                  NaN             NaN             NaN             NaN
# 44527                  2.0             6.0            12.0             1.0
#
#             JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  \
# ResponseId
# 23779                  NaN             NaN             NaN              NaN
# 19681                  NaN             NaN             NaN              NaN
# 36625                  7.0             1.0            12.0             11.0
# 18574                  NaN             NaN             NaN              NaN
# 12141                  NaN             NaN             NaN              NaN
# 3286                   NaN             NaN             NaN              NaN
# 33197                  NaN             NaN             NaN              NaN
# 16716                  NaN             NaN             NaN              NaN
# 38103                  NaN             NaN             NaN              NaN
# 44527                 13.0             8.0             5.0             11.0
#
#             JobSatPoints_11  JobSatPoints_13  JobSatPoints_14  \
# ResponseId
# 23779                   NaN              NaN              NaN
# 19681                   NaN              NaN              NaN
# 36625                   2.0              5.0             10.0
# 18574                   NaN              NaN              NaN
# 12141                   NaN              NaN              NaN
# 3286                    NaN              NaN              NaN
# 33197                   NaN              NaN              NaN
# 16716                   NaN              NaN              NaN
# 38103                   NaN              NaN              NaN
# 44527                  14.0              4.0              7.0
#
#             JobSatPoints_15  JobSatPoints_16      JobSatPoints_15_TEXT  \
# ResponseId
# 23779                   NaN              NaN                       NaN
# 19681                   NaN              NaN                       NaN
# 36625                  15.0              6.0              012345678910
# 18574                   NaN              NaN                       NaN
# 12141                   NaN              NaN                       NaN
# 3286                    NaN              NaN                       NaN
# 33197                   NaN              NaN                       NaN
# 16716                   NaN              NaN                       NaN
# 38103                   NaN              NaN                       NaN
# 44527                  15.0              3.0  This my money depression
#
#            AIThreat                                            NewRole  \
# ResponseId
# 23779           Yes  I have strongly considered changing my career ...
# 19681           Yes  I have somewhat considered changing my career ...
# 36625           NaN                                                NaN
# 18574           Yes  I have strongly considered changing my career ...
# 12141           Yes  I have strongly considered changing my career ...
# 3286            NaN                                                NaN
# 33197           Yes  I have strongly considered changing my career ...
# 16716            No  I have neither consider or transitioned into a...
# 38103           NaN                                                NaN
# 44527           Yes  I have neither consider or transitioned into a...
#
#             ToolCountWork  ToolCountPersonal   Country  \
# ResponseId
# 23779               100.0              100.0    Brazil
# 19681               100.0              100.0  Cambodia
# 36625              1000.0             1000.0  Cameroon
# 18574              4000.0             1000.0    Canada
# 12141               100.0              100.0    Canada
# 3286                  NaN                0.0   Denmark
# 33197              1000.0             1000.0    France
# 16716                 6.0                3.0   Germany
# 38103                 NaN              100.0    Mexico
# 44527              1000.0             1000.0     Nepal
#
#                             Currency     CompTotal LanguageChoice  \
# ResponseId
# 23779             BRL Brazilian real  1.000000e+02            Yes
# 19681             KHR Cambodian riel           NaN            Yes
# 36625             BRL Brazilian real  1.000000e+03            Yes
# 18574            CAD Canadian dollar  4.000000e+03            NaN
# 12141       USD United States dollar  1.000000e+02            Yes
# 3286               DKK\tDanish krone  0.000000e+00             No
# 33197       USD United States dollar  1.000000e+03            Yes
# 16716              EUR European Euro  2.899000e+05            Yes
# 38103            CAD Canadian dollar  1.000000e+02            Yes
# 44527       USD United States dollar  8.000000e+23            NaN
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 23779       Ada;Assembly;Bash/Shell (all shells);C;C#;C++;...
# 19681       Ada;Assembly;Bash/Shell (all shells);C;C#;C++;...
# 36625                                                     Ada
# 18574                                                     NaN
# 12141                                                     Ada
# 3286                                                      NaN
# 33197       Ada;Assembly;Bash/Shell (all shells);C;C#;C++;...
# 16716                 Bash/Shell (all shells);C;C++;Java;Rust
# 38103                    Ada;Assembly;Bash/Shell (all shells)
# 44527       Ada;Assembly;Bash/Shell (all shells);C;C#;C++;...
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 23779                                                     NaN
# 19681       Ada;Assembly;Bash/Shell (all shells);C;C#;C++;...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141       Assembly;Bash/Shell (all shells);C;C#;C++;COBO...
# 3286                                                      NaN
# 33197       Ada;Assembly;Bash/Shell (all shells);C;C#;C++;...
# 16716                        Bash/Shell (all shells);C++;Java
# 38103                                                     NaN
# 44527                                                     NaN
#
#                                               LanguageAdmired  \
# ResponseId
# 23779                                                     NaN
# 19681       Ada;Assembly;Bash/Shell (all shells);C;C#;C++;...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197       Ada;Assembly;Bash/Shell (all shells);C;C#;C++;...
# 16716                        Bash/Shell (all shells);C++;Java
# 38103                                                     NaN
# 44527                                                     NaN
#
#                  LanguagesHaveEntry LanguagesWantEntry DatabaseChoice  \
# ResponseId
# 23779                           100                100            Yes
# 19681                           NaN                NaN            Yes
# 36625                           NaN               1000            NaN
# 18574                           NaN                NaN            NaN
# 12141                           ไทย                ไทย            Yes
# 3286                            NaN                NaN             No
# 33197                           NaN                NaN            Yes
# 16716                           NaN                NaN             No
# 38103                       Español               1000            Yes
# 44527       I am no using a coading               Fake            Yes
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 23779       BigQuery;Cassandra;Cloud Firestore;Cosmos DB;D...
# 19681                                                     NaN
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                BigQuery
# 16716                                                     NaN
# 38103                                                     NaN
# 44527       BigQuery;Cassandra;Cloud Firestore;Cosmos DB;D...
#
#            DatabaseWantToWorkWith DatabaseAdmired           DatabaseHaveEntry  \
# ResponseId
# 23779                         NaN             NaN                         100
# 19681                         NaN             NaN                         NaN
# 36625                         NaN             NaN                        1000
# 18574                         NaN             NaN                         NaN
# 12141                         NaN             NaN                         ไทย
# 3286                          NaN             NaN                         NaN
# 33197                         NaN             NaN                         NaN
# 16716                         NaN             NaN                         NaN
# 38103                         NaN             NaN                         NaN
# 44527                         NaN             NaN  I am using only PC and cpu
#
#            DatabaseWantEntry PlatformChoice  \
# ResponseId
# 23779                    100            Yes
# 19681                    NaN             No
# 36625                   1000             No
# 18574                    NaN            NaN
# 12141                     ดี            Yes
# 3286                     NaN             No
# 33197                    NaN             No
# 16716                    NaN            Yes
# 38103                    NaN            NaN
# 44527             Duckduckgo            Yes
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 23779                                                     NaN
# 19681                                                     NaN
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                               Amazon Web Services (AWS)
# 38103                                                     NaN
# 44527       Amazon Web Services (AWS);Ansible;APT;Bun;Carg...
#
#                                        PlatformWantToWorkWith  \
# ResponseId
# 23779                                                     NaN
# 19681                                                     NaN
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                                     NaN
# 38103                                                     NaN
# 44527       Amazon Web Services (AWS);Ansible;APT;Bun;Carg...
#
#                                               PlatformAdmired  \
# ResponseId
# 23779                                                     NaN
# 19681                                                     NaN
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                                     NaN
# 38103                                                     NaN
# 44527       Amazon Web Services (AWS);Ansible;APT;Bun;Carg...
#
#                       PlatformHaveEntry          PlatformWantEntry  \
# ResponseId
# 23779                               NaN                        NaN
# 19681                               NaN                        NaN
# 36625                               NaN                        NaN
# 18574                               NaN                        NaN
# 12141                               NaN                        NaN
# 3286                                NaN                        NaN
# 33197                               NaN                        NaN
# 16716                               NaN                        NaN
# 38103                               NaN                        NaN
# 44527       I am a new man in the world  I am new man in the world
#
#            WebframeChoice WebframeHaveWorkedWith WebframeWantToWorkWith  \
# ResponseId
# 23779                 NaN                    NaN                    NaN
# 19681                  No                    NaN                    NaN
# 36625                  No                    NaN                    NaN
# 18574                 NaN                    NaN                    NaN
# 12141                 NaN                    NaN                    NaN
# 3286                   No                    NaN                    NaN
# 33197                 Yes                    NaN                    NaN
# 16716                  No                    NaN                    NaN
# 38103                 NaN                    NaN                    NaN
# 44527                 NaN                    NaN                    NaN
#
#            WebframeAdmired WebframeHaveEntry WebframeWantEntry DevEnvsChoice  \
# ResponseId
# 23779                  NaN               NaN               NaN           NaN
# 19681                  NaN               NaN               NaN            No
# 36625                  NaN               NaN               NaN           Yes
# 18574                  NaN               NaN               NaN           NaN
# 12141                  NaN               NaN               NaN           NaN
# 3286                   NaN               NaN               NaN            No
# 33197                  NaN             10000             10000           Yes
# 16716                  NaN               NaN               NaN           Yes
# 38103                  NaN               NaN               NaN           NaN
# 44527                  NaN               NaN               NaN           NaN
#
#                                         DevEnvsHaveWorkedWith  \
# ResponseId
# 23779                                                     NaN
# 19681                                                     NaN
# 36625                                                    Bolt
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                          Android Studio
# 16716       Android Studio;IntelliJ IDEA;Neovim;Sublime Te...
# 38103                                                     NaN
# 44527                                                     NaN
#
#                                         DevEnvsWantToWorkWith  \
# ResponseId
# 23779                                                     NaN
# 19681                                                     NaN
# 36625       Aider;Android Studio;Claude Code;Cline and/or ...
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                          Android Studio
# 16716                                       IntelliJ IDEA;Vim
# 38103                                                     NaN
# 44527                                                     NaN
#
#                DevEnvsAdmired DevEnvHaveEntry DevEnvWantEntry  \
# ResponseId
# 23779                     NaN             NaN             NaN
# 19681                     NaN             NaN             NaN
# 36625                     NaN    012345678910            1000
# 18574                     NaN             NaN             NaN
# 12141                     NaN             NaN             NaN
# 3286                      NaN             NaN             NaN
# 33197          Android Studio             NaN             NaN
# 16716       IntelliJ IDEA;Vim             NaN             NaN
# 38103                     NaN             NaN             NaN
# 44527                     NaN             NaN             NaN
#
#                                          SOTagsHaveWorkedWith  \
# ResponseId
# 23779                                                     NaN
# 19681       .NET 8 or higher;c++23;Tailwind CSS 4;Polars;h...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                                     NaN
# 38103                                                     NaN
# 44527                                                     NaN
#
#                                          SOTagsWantToWorkWith  \
# ResponseId
# 23779                                                     NaN
# 19681       .NET 8 or higher;c++23;Tailwind CSS 4;Polars;h...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                                     NaN
# 38103                                                     NaN
# 44527                                                     NaN
#
#                                                 SOTagsAdmired SOTagsHaveEntry  \
# ResponseId
# 23779                                                     NaN             NaN
# 19681       .NET 8 or higher;c++23;Tailwind CSS 4;Polars;h...             NaN
# 36625                                                     NaN             2-3
# 18574                                                     NaN             NaN
# 12141                                                     NaN             NaN
# 3286                                                      NaN             NaN
# 33197                                                     NaN               2
# 16716                                                     NaN             NaN
# 38103                                                     NaN             NaN
# 44527                                                     NaN             NaN
#
#            SOTagsWant Entry  \
# ResponseId
# 23779                   NaN
# 19681                   NaN
# 36625                   2-3
# 18574                   NaN
# 12141                   NaN
# 3286                    NaN
# 33197                     2
# 16716                   NaN
# 38103                   NaN
# 44527                   NaN
#
#                                             OpSysPersonal use  \
# ResponseId
# 23779                                                     NaN
# 19681       Windows;MacOS;Ubuntu;Android;Windows Subsystem...
# 36625                                                 Windows
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                          Windows;Android
# 33197                                                   NixOS
# 16716                                                    Arch
# 38103                                                     NaN
# 44527                                                     NaN
#
#            OpSysProfessional use  \
# ResponseId
# 23779                        NaN
# 19681                        NaN
# 36625                        NaN
# 18574                        NaN
# 12141                        NaN
# 3286                         NaN
# 33197                        NaN
# 16716                       Arch
# 38103                        NaN
# 44527                        NaN
#
#                                OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 23779                                                     NaN
# 19681       Airtable;Asana;Azure Devops;Clickup;Coda;Confl...
# 36625                                                  Trello
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                   GitHub
# 33197                                                     NaN
# 16716                                           Markdown File
# 38103                                                     NaN
# 44527                                                     NaN
#
#                                OfficeStackAsyncWantToWorkWith  \
# ResponseId
# 23779                                                     NaN
# 19681       Airtable;Asana;Azure Devops;Clickup;Coda;Confl...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                           Markdown File
# 38103                                                     NaN
# 44527                                                     NaN
#
#                                       OfficeStackAsyncAdmired  \
# ResponseId
# 23779                                                     NaN
# 19681       Airtable;Asana;Azure Devops;Clickup;Coda;Confl...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                           Markdown File
# 38103                                                     NaN
# 44527                                                     NaN
#
#            OfficeStackHaveEntry OfficeStackWantEntry  \
# ResponseId
# 23779                       NaN                  NaN
# 19681                       NaN                  NaN
# 36625                       NaN                  NaN
# 18574                       NaN                  NaN
# 12141                       NaN                  NaN
# 3286                        NaN                  NaN
# 33197                       NaN                  NaN
# 16716                       NaN                  NaN
# 38103                       NaN                  NaN
# 44527                       NaN                  NaN
#
#                                    CommPlatformHaveWorkedWith  \
# ResponseId
# 23779                                                     NaN
# 19681       Stack Overflow;Stack Exchange;Discord;Reddit;D...
# 36625             GitHub (public projects, not private repos)
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                           Stack Overflow
# 33197                                                     NaN
# 16716                                                     NaN
# 38103                                                     NaN
# 44527                                                     NaN
#
#                                    CommPlatformWantToWorkWith  \
# ResponseId
# 23779                                                     NaN
# 19681       Stack Overflow;Stack Exchange;Discord;Reddit;D...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                                     NaN
# 38103                                                     NaN
# 44527                                                     NaN
#
#                                           CommPlatformAdmired  \
# ResponseId
# 23779                                                     NaN
# 19681       Stack Overflow;Stack Exchange;Discord;Reddit;D...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                                     NaN
# 38103                                                     NaN
# 44527                                                     NaN
#
#            CommPlatformHaveEntr CommPlatformWantEntr AIModelsChoice  \
# ResponseId
# 23779                       NaN                  NaN            NaN
# 19681                       NaN                  NaN            Yes
# 36625                       2-3                  2-3            Yes
# 18574                       NaN                  NaN            NaN
# 12141                       NaN                  NaN            NaN
# 3286                        NaN                  NaN             No
# 33197               03069838249          03069838249            Yes
# 16716                       NaN                  NaN            Yes
# 38103                       NaN                  NaN            NaN
# 44527                       NaN                  NaN            NaN
#
#                                        AIModelsHaveWorkedWith  \
# ResponseId
# 23779                                                     NaN
# 19681       Alibaba Cloud Qwen models;Amazon Titan models;...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                               Alibaba Cloud Qwen models
# 16716       Alibaba Cloud Qwen models;Amazon Titan models;...
# 38103                                                     NaN
# 44527                                                     NaN
#
#                                        AIModelsWantToWorkWith  \
# ResponseId
# 23779                                                     NaN
# 19681       Alibaba Cloud Qwen models;Amazon Titan models;...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716       Alibaba Cloud Qwen models;Amazon Titan models;...
# 38103                                                     NaN
# 44527                                                     NaN
#
#                                               AIModelsAdmired  \
# ResponseId
# 23779                                                     NaN
# 19681       Alibaba Cloud Qwen models;Amazon Titan models;...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716       Alibaba Cloud Qwen models;Amazon Titan models;...
# 38103                                                     NaN
# 44527                                                     NaN
#
#            AIModelsHaveEntry AIModelsWantEntry SOAccount  \
# ResponseId
# 23779                    NaN               NaN       NaN
# 19681                    NaN               NaN       Yes
# 36625                     -4               2-3       NaN
# 18574                    NaN               NaN       NaN
# 12141                    NaN               NaN       Yes
# 3286                     NaN               NaN       Yes
# ...
# 38103                             NaN
# 44527       I am note using Wikipedia
#
#                                                      AIAgents  \
# ResponseId
# 23779                                                     NaN
# 19681                      Yes, I use AI agents at work daily
# 36625       Yes, I use AI agents at work monthly or infreq...
# 18574                      Yes, I use AI agents at work daily
# 12141                      Yes, I use AI agents at work daily
# 3286                                  No, and I don't plan to
# 33197                                                     NaN
# 16716                      Yes, I use AI agents at work daily
# 38103                                                     NaN
# 44527                     Yes, I use AI agents at work weekly
#
#                                                 AIAgentChange  \
# ResponseId
# 23779                                                     NaN
# 19681       No, but my development work has changed somewh...
# 36625       No, but my development work has significantly ...
# 18574                                  Yes, to a great extent
# 12141                                  Yes, to a great extent
# 3286                                  Not at all or minimally
# 33197                                                     NaN
# 16716                                  Yes, to a great extent
# 38103                                                     NaN
# 44527       No, but my development work has significantly ...
#
#                                                  AIAgent_Uses  \
# ResponseId
# 23779                                                     NaN
# 19681       Software engineering;Business process automati...
# 36625       Customer service support;Other Industry purpos...
# 18574                    Business process automation;Robotics
# 12141                             Business process automation
# 3286                                                      NaN
# 33197                                                     NaN
# 16716       Business process automation;Customer service s...
# 38103                                                     NaN
# 44527       Business process automation;Other Industry pur...
#
#                                              AgentUsesGeneral  \
# ResponseId
# 23779                                                     NaN
# 19681       Multi-platform search enablement;Language proc...
# 36625                         Other specific task (write in):
# 18574                                                     NaN
# 12141                        Multi-platform search enablement
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                                     NaN
# 38103                                                     NaN
# 44527             MCP servers;Other specific task (write in):
#
#                                   AIAgentImpactSomewhat agree  \
# ResponseId
# 23779                                                     NaN
# 19681       AI agents have accelerated my learning about n...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                                     NaN
# 38103                                                     NaN
# 44527                                                     NaN
#
#            AIAgentImpactNeutral AIAgentImpactSomewhat disagree  \
# ResponseId
# 23779                       NaN                            NaN
# 19681                       NaN                            NaN
# 36625                       NaN                            NaN
# 18574                       NaN                            NaN
# 12141                       NaN                            NaN
# 3286                        NaN                            NaN
# 33197                       NaN                            NaN
# 16716                       NaN                            NaN
# 38103                       NaN                            NaN
# 44527                       NaN                            NaN
#
#                                   AIAgentImpactStrongly agree  \
# ResponseId
# 23779                                                     NaN
# 19681       AI agents have increased my productivity.;AI a...
# 36625       Write in the most significant benefit if not l...
# 18574       AI agents have increased my productivity.;AI a...
# 12141       AI agents have increased my productivity.;AI a...
# 3286                                                      NaN
# 33197                                                     NaN
# 16716       AI agents have increased my productivity.;AI a...
# 38103                                                     NaN
# 44527       AI agents have increased my productivity.;AI a...
#
#                                AIAgentImpactStrongly disagree  \
# ResponseId
# 23779                                                     NaN
# 19681       AI agents have improved collaboration within m...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                                     NaN
# 38103                                                     NaN
# 44527                                                     NaN
#
#                                      AIAgentChallengesNeutral  \
# ResponseId
# 23779                                                     NaN
# 19681                                                     NaN
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286        The cost of using certain AI agent platforms i...
# 33197                                                     NaN
# 16716                                                     NaN
# 38103                                                     NaN
# 44527                                                     NaN
#
#            AIAgentChallengesSomewhat disagree  \
# ResponseId
# 23779                                     NaN
# 19681                                     NaN
# 36625                                     NaN
# 18574                                     NaN
# 12141                                     NaN
# 3286                                      NaN
# 33197                                     NaN
# 16716                                     NaN
# 38103                                     NaN
# 44527                                     NaN
#
#                               AIAgentChallengesStrongly agree  \
# ResponseId
# 23779                                                     NaN
# 19681                                                     NaN
# 36625                                                     NaN
# 18574       I am concerned about the accuracy of the infor...
# 12141       I am concerned about the accuracy of the infor...
# 3286        I am concerned about the accuracy of the infor...
# 33197                                                     NaN
# 16716       I am concerned about the accuracy of the infor...
# 38103                                                     NaN
# 44527       I am concerned about the accuracy of the infor...
#
#                               AIAgentChallengesSomewhat agree  \
# ResponseId
# 23779                                                     NaN
# 19681       I am concerned about the accuracy of the infor...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                     NaN
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                                     NaN
# 38103                                                     NaN
# 44527                                                     NaN
#
#            AIAgentChallengesStrongly disagree  \
# ResponseId
# 23779                                     NaN
# 19681                                     NaN
# 36625                                     NaN
# 18574                                     NaN
# 12141                                     NaN
# 3286                                      NaN
# 33197                                     NaN
# 16716                                     NaN
# 38103                                     NaN
# 44527                                     NaN
#
#                                              AIAgentKnowledge  \
# ResponseId
# 23779                                                     NaN
# 19681       Redis;Fireproof;LanceDB;Letta;Neo4j;Qdrant;Git...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141                                                ChromaDB
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                                     Zep
# 38103                                                     NaN
# 44527                                       GitHub MCP Server
#
#                                AIAgentKnowWrite  \
# ResponseId
# 23779                                       NaN
# 19681                                       NaN
# 36625                                       NaN
# 18574                                       NaN
# 12141                                       100
# 3286                                        NaN
# 33197                                       NaN
# 16716                                       NaN
# 38103                                       NaN
# 44527       Binance,Exness,b2p,p2psystem,Reedit
#
#                                          AIAgentOrchestration  \
# ResponseId
# 23779                                                     NaN
# 19681       Vertex AI;Agno;AutoGen (Microsoft);CrewAI;IBM ...
# 36625                                                     NaN
# 18574                                                     NaN
# 12141       Vertex AI;Ollama;Smol-AGI;Amazon Bedrock Agent...
# 3286                                                      NaN
# 33197                                                     NaN
# 16716                                                    lyzr
# 38103                                                     NaN
# 44527       Vertex AI;Agno;AutoGen (Microsoft);CrewAI;IBM ...
#
#                        AIAgentOrchWrite  \
# ResponseId
# 23779                               NaN
# 19681                               NaN
# 36625                               NaN
# 18574       Work for transfert m'y info
# 12141                               100
# 3286                                NaN
# 33197                               NaN
# 16716                               NaN
# 38103                               NaN
# 44527                                 1
#
#                                          AIAgentObserveSecure AIAgentObsWrite  \
# ResponseId
# 23779                                                     NaN             NaN
# 19681       Sentry;Galileo;Honeycomb;Metero;New Relic;opik...             NaN
# 36625                                                     NaN             NaN
# 18574                                                     NaN             NaN
# 12141       Galileo;Honeycomb;Snyk;Adversarial Robustness ...             100
# 3286                                                      NaN             NaN
# 33197                                                     NaN             NaN
# 16716                                                    opik             NaN
# 38103                                                     NaN             NaN
# 44527       Sentry;Galileo;Honeycomb;Metero;New Relic;opik...               1
#
#                                               AIAgentExternal AIAgentExtWrite  \
# ResponseId
# 23779                                                     NaN             NaN
# 19681       ChatGPT;Claude Code;GitHub Copilot;Google Gemi...             NaN
# 36625                                                     NaN             NaN
# 18574                                                     NaN             NaN
# 12141       Claude Code;AgentGPT;Devin AI;Roo code (Roo-Cl...             NaN
# 3286                                                      NaN             NaN
# 33197                                                     NaN             NaN
# 16716                                                     NaN             NaN
# 38103                                                     NaN             NaN
# 44527       ChatGPT;Claude Code;GitHub Copilot;Google Gemi...               1
#
#                                                       AIHuman         AIOpen  \
# ResponseId
# 23779                                                     NaN            NaN
# 19681                     When I want to learn best practices            NaN
# 36625                                                     NaN            NaN
# 18574                                                     NaN            NaN
# 12141                                                     NaN             35
# 3286                                                      NaN            NaN
# 33197                                                     NaN            NaN
# 16716                                                     NaN        Brothel
# 38103                                                     NaN            NaN
# 44527       When I don’t trust AI’s answers;When I want to...  My vailu is 0
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 23779                      18.0     NaN
# 19681                       NaN     NaN
# 36625                     182.0    10.0
# 18574                    2918.0     NaN
# 12141                     100.0     NaN
# 3286                        NaN     NaN
# 33197                    1000.0     NaN
# 16716                  336327.0     NaN
# 38103                      73.0     NaN
# 44527                       NaN     NaN

# %%
df.nsmallest(10,"WorkExp")
# Out:
#                                                    MainBranch  \
# ResponseId
# 36997                          I am a developer by profession
# 11874                          I am a developer by profession
# 2541                              I code primarily as a hobby
# 6987                           I am a developer by profession
# 29465                          I am a developer by profession
# 35525                                   I am learning to code
# 33639                          I am a developer by profession
# 20475                          I am a developer by profession
# 43457       I am not primarily a developer, but I write co...
# 29002                          I am a developer by profession
#
#                  CurrentAge  \
# ResponseId
# 36997       18-24 years old
# 11874       18-24 years old
# 2541        18-24 years old
# 6987        18-24 years old
# 29465       18-24 years old
# 35525       18-24 years old
# 33639       25-34 years old
# 20475       25-34 years old
# 43457       25-34 years old
# 29002       18-24 years old
#
#                                                       EdLevel  \
# ResponseId
# 36997            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11874       Some college/university study without earning ...
# 2541        Some college/university study without earning ...
# 6987        Some college/university study without earning ...
# 29465         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 35525       Secondary school (e.g. American high school, G...
# 33639            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 20475       Some college/university study without earning ...
# 43457       Secondary school (e.g. American high school, G...
# 29002            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# ResponseId
# 36997                                                Employed
# 11874                                                Employed
# 2541                                             Not employed
# 6987        Independent contractor, freelancer, or self-em...
# 29465                                                Employed
# 35525                                                 Student
# 33639                                                Employed
# 20475                                                Employed
# 43457       Independent contractor, freelancer, or self-em...
# 29002       Independent contractor, freelancer, or self-em...
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 36997                            Attending school (full-time)      1.0
# 11874       Engaged in paid work (20-29 hours per week);At...      1.0
# 2541                                 Volunteering (regularly)      1.0
# 6987                             Attending school (part-time)      1.0
# 29465                                       None of the above      1.0
# 35525                            Attending school (part-time)      1.0
# 33639             Engaged in paid work (20-29 hours per week)      1.0
# 20475             Engaged in paid work (10-19 hours per week)      1.0
# 43457                                       None of the above      1.0
# 29002             Engaged in paid work (10-19 hours per week)      1.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 36997       Yes, I am not new to coding but am learning ne...
# 11874       Yes, I am not new to coding but am learning ne...
# 2541        Yes, I am not new to coding but am learning ne...
# 6987        Yes, I am not new to coding but am learning ne...
# 29465       Yes, I am not new to coding but am learning ne...
# 35525          Yes, I am new to coding or currently a student
# 33639       Yes, I am not new to coding but am learning ne...
# 20475       Yes, I am not new to coding but am learning ne...
# 43457       Yes, I am not new to coding but am learning ne...
# 29002       Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode  \
# ResponseId
# 36997       Videos (not associated with specific online co...
# 11874       Other online resources (e.g. standard search, ...
# 2541        Other online resources (e.g. standard search, ...
# 6987        Online Courses or Certification (includes all ...
# 29465       Other online resources (e.g. standard search, ...
# 35525       Technical documentation (is generated for/by t...
# 33639       Online Courses or Certification (includes all ...
# 20475                                                     NaN
# 43457       Online Courses or Certification (includes all ...
# 29002       Books / Physical media;Videos (not associated ...
#
#                                                   LearnCodeAI  \
# ResponseId
# 36997       Yes, I learned how to use AI-enabled tools for...
# 11874       Yes, I learned how to use AI-enabled tools for...
# 2541        No, I learned something that was not related t...
# 6987        Yes, I learned how to use AI-enabled tools req...
# 29465       No, I learned something that was not related t...
# 35525       No, I learned something that was not related t...
# 33639       Yes, I learned how to use AI-enabled tools for...
# 20475       No, I learned something that was not related t...
# 43457       Yes, I learned how to use AI-enabled tools for...
# 29002       Yes, I learned how to use AI-enabled tools for...
#
#                                                    AILearnHow  YearsCode  \
# ResponseId
# 36997       Videos (not associated with specific online co...        4.0
# 11874       AI CodeGen tools or AI-enabled apps;Videos (no...        4.0
# 2541                                                      NaN        5.0
# 6987        Videos (not associated with specific online co...        6.0
# 29465                                                     NaN        6.0
# 35525                                                     NaN        2.0
# 33639       Technical documentation (is generated for/by t...        5.0
# 20475                                                     NaN       11.0
# 43457       Videos (not associated with specific online co...        1.0
# 29002       Technical documentation (is generated for/by t...        6.0
#
#                                                   DevType  \
# ResponseId
# 36997                                 Developer, back-end
# 11874                                Developer, front-end
# 2541                                    Developer, mobile
# 6987                                 Developer, front-end
# 29465                                 Developer, back-end
# 35525                   Developer, AI apps or physical AI
# 33639                               Developer, full-stack
# 20475                                 Developer, back-end
# 43457                               Developer, QA or test
# 29002       Developer, desktop or enterprise applications
#
#                            OrgSize                  ICorPM  \
# ResponseId
# 36997           20 to 99 employees  Individual contributor
# 11874       Less than 20 employees  Individual contributor
# 2541                           NaN                     NaN
# 6987                           NaN                     NaN
# 29465       Less than 20 employees  Individual contributor
# 35525                          NaN                     NaN
# 33639       Less than 20 employees  Individual contributor
# 20475       Less than 20 employees  Individual contributor
# 43457                          NaN                     NaN
# 29002       Less than 20 employees  Individual contributor
#
#                                                    RemoteWork  \
# ResponseId
# 36997          Hybrid (some remote, leans heavy to in-person)
# 11874          Hybrid (some remote, leans heavy to in-person)
# 2541                                                      NaN
# 6987                                                      NaN
# 29465       Your choice (very flexible, you can come in wh...
# 35525                                                     NaN
# 33639                                                  Remote
# 20475                                                  Remote
# 43457                                                     NaN
# 29002                                                  Remote
#
#                                             PurchaseInfluence  \
# ResponseId
# 36997                                                      No
# 11874                                                      No
# 2541                                                      NaN
# 6987                                                       No
# 29465                                                      No
# 35525                                                     NaN
# 33639       Yes, I endorsed a tool that was ultimately not...
# 20475       Yes, I endorsed a tool that was open-source an...
# 43457                                                      No
# 29002                                                      No
#
#             TechEndorseIntro  TechEndorse_1  TechEndorse_2  TechEndorse_3  \
# ResponseId
# 36997                   Work            8.0            1.0            2.0
# 11874                   Work            9.0            1.0            3.0
# 2541        Personal Project            7.0            2.0            1.0
# 6987                    Work            9.0            2.0            5.0
# 29465                   Work            9.0            3.0            6.0
# 35525                 School            3.0            6.0            1.0
# 33639                   Work            9.0            4.0            5.0
# 20475                    NaN           10.0            3.0            4.0
# 43457                   Work            6.0            1.0            5.0
# 29002                   Work            4.0            7.0            2.0
#
#             TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  \
# ResponseId
# 36997                 4.0            6.0            5.0            9.0
# 11874                 7.0            4.0            6.0            5.0
# 2541                  5.0            6.0            4.0            9.0
# 6987                  8.0            1.0            7.0            6.0
# 29465                 7.0            2.0            4.0            8.0
# 35525                 5.0            7.0            2.0            4.0
# 33639                 2.0            1.0            8.0            7.0
# 20475                 8.0            5.0            6.0            9.0
# 43457                 9.0            4.0            3.0            8.0
# 29002                 3.0            6.0            9.0            5.0
#
#             TechEndorse_8  TechEndorse_9  TechEndorse_13 TechEndorse_13_TEXT  \
# ResponseId
# 36997                 3.0            7.0            10.0                 NaN
# 11874                 2.0            8.0            10.0                 NaN
# 2541                  3.0            8.0            10.0                 NaN
# 6987                  4.0            3.0            10.0                 NaN
# 29465                 5.0            1.0            10.0                 NaN
# 35525                 9.0            8.0            10.0                 NaN
# 33639                 3.0            6.0            10.0                 NaN
# 20475                 7.0            1.0             2.0     Written in rust
# 43457                 7.0            2.0            10.0                 NaN
# 29002                 8.0            1.0            10.0                 NaN
#
#             TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# ResponseId
# 36997                5.0           4.0           7.0           6.0
# 11874                8.0           9.0           2.0           1.0
# 2541                 9.0           5.0           7.0           6.0
# 6987                 9.0           6.0           7.0           5.0
# 29465                9.0           2.0           8.0           3.0
# 35525                NaN           NaN           NaN           NaN
# 33639                9.0           2.0           6.0           1.0
# 20475                9.0           5.0           7.0           4.0
# 43457                4.0           1.0           6.0           3.0
# 29002                7.0           3.0           8.0           6.0
#
#             TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  \
# ResponseId
# 36997                2.0           8.0            1.0            3.0
# 11874                7.0           3.0            5.0            4.0
# 2541                 8.0           3.0            1.0            4.0
# 6987                 2.0           3.0            1.0            4.0
# 29465                1.0           5.0            6.0            7.0
# 35525                NaN           NaN            NaN            NaN
# 33639                5.0           3.0            4.0            7.0
# 20475                1.0           3.0            2.0            6.0
# 43457                2.0           7.0            5.0            8.0
# 29002                2.0           9.0            5.0            1.0
#
#             TechOppose_16  TechOppose_15 TechOppose_15_TEXT  \
# ResponseId
# 36997                 9.0           10.0                NaN
# 11874                 6.0           10.0                NaN
# 2541                  2.0           10.0                NaN
# 6987                  8.0           10.0                NaN
# 29465                 4.0           10.0                NaN
# 35525                 NaN            NaN                NaN
# 33639                 8.0           10.0                NaN
# 20475                 8.0           10.0                NaN
# 43457                 9.0           10.0                NaN
# 29002                 4.0           10.0                NaN
#
#                         Industry  JobSatPoints_1  JobSatPoints_4  \
# ResponseId
# 36997       Software Development            13.0             5.0
# 11874       Software Development            10.0             8.0
# 2541                         NaN             NaN             NaN
# 6987        Software Development             6.0             2.0
# 29465       Software Development             NaN             NaN
# 35525                        NaN             NaN             NaN
# 33639       Software Development             9.0            10.0
# 20475       Software Development             NaN             NaN
# 43457       Software Development             NaN             NaN
# 29002       Software Development             8.0            11.0
#
#             JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# ResponseId
# 36997                  3.0             7.0             9.0             1.0
# 11874                 14.0            13.0             5.0            12.0
# 2541                   NaN             NaN             NaN             NaN
# 6987                  13.0            14.0             8.0             7.0
# 29465                  NaN             NaN             NaN             NaN
# 35525                  NaN             NaN             NaN             NaN
# 33639                 13.0            12.0             7.0             1.0
# 20475                  NaN             NaN             NaN             NaN
# 43457                  NaN             NaN             NaN             NaN
# 29002                 12.0            14.0             3.0             9.0
#
#             JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  JobSatPoints_13  \
# ResponseId
# 36997                 14.0             11.0             10.0              4.0
# 11874                  9.0              7.0             11.0              3.0
# 2541                   NaN              NaN              NaN              NaN
# 6987                  12.0              9.0              1.0              5.0
# 29465                  NaN              NaN              NaN              NaN
# 35525                  NaN              NaN              NaN              NaN
# 33639                  8.0              5.0             14.0              3.0
# 20475                  NaN              NaN              NaN              NaN
# 43457                  NaN              NaN              NaN              NaN
# 29002                  4.0              2.0              6.0             13.0
#
#             JobSatPoints_14  JobSatPoints_15  JobSatPoints_16  \
# ResponseId
# 36997                   6.0             15.0              8.0
# 11874                   4.0             15.0              2.0
# 2541                    NaN              NaN              NaN
# 6987                   11.0             15.0              4.0
# 29465                   NaN              NaN              NaN
# 35525                   NaN              NaN              NaN
# 33639                   6.0             15.0             11.0
# 20475                   NaN              NaN              NaN
# 43457                   NaN              NaN              NaN
# 29002                   1.0             15.0             10.0
#
#            JobSatPoints_15_TEXT      AIThreat  \
# ResponseId
# 36997                       NaN            No
# 11874                       NaN  I'm not sure
# 2541                        NaN            No
# 6987                        NaN            No
# 29465                       NaN            No
# 35525                       NaN  I'm not sure
# 33639                       NaN            No
# 20475                       NaN            No
# 43457                       NaN  I'm not sure
# 29002                       NaN  I'm not sure
#
#                                                       NewRole  ToolCountWork  \
# ResponseId
# 36997       I have neither consider or transitioned into a...            7.0
# 11874       I have neither consider or transitioned into a...            NaN
# 2541        I have strongly considered changing my career ...            NaN
# 6987        I have neither consider or transitioned into a...            7.0
# 29465       I have somewhat considered changing my career ...            1.0
# 35525       I have transitioned into a new career and/or i...            NaN
# 33639       I have transitioned into a new career and/or i...            3.0
# 20475       I have neither consider or transitioned into a...            NaN
# 43457       I have neither consider or transitioned into a...            5.0
# 29002       I have neither consider or transitioned into a...            8.0
#
#             ToolCountPersonal    Country                  Currency  \
# ResponseId
# 36997                     3.0    Albania         ALL\tAlbanian lek
# 11874                     NaN    Albania         ALL\tAlbanian lek
# 2541                      NaN    Algeria       DZD\tAlgerian dinar
# 6987                      5.0    Algeria       DZD\tAlgerian dinar
# 29465                     0.0    Algeria       DZD\tAlgerian dinar
# 35525                     NaN     Angola  USD United States dollar
# 33639                     5.0  Argentina       ARS\tArgentine peso
# 20475                     NaN  Argentina       ARS\tArgentine peso
# 43457                     6.0  Argentina  USD United States dollar
# 29002                    10.0  Argentina       ARS\tArgentine peso
#
#              CompTotal LanguageChoice  \
# ResponseId
# 36997              NaN            Yes
# 11874              NaN            Yes
# 2541               NaN            Yes
# 6987               NaN            Yes
# 29465        1000000.0            Yes
# 35525            200.0            NaN
# 33639       13000000.0            Yes
# 20475              NaN            Yes
# 43457           6000.0            Yes
# 29002              NaN            Yes
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 36997                          Dart;PHP;Python;SQL;TypeScript
# 11874        C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
# 2541            C;C++;HTML/CSS;Java;JavaScript;PowerShell;SQL
# 6987          Dart;HTML/CSS;Java;JavaScript;Python;TypeScript
# 29465       Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 35525                                                     NaN
# 33639       C#;HTML/CSS;JavaScript;PowerShell;SQL;TypeScri...
# 20475       Bash/Shell (all shells);C#;Go;Java;JavaScript;...
# 43457                                           HTML/CSS;Java
# 29002                                    C;C++;Delphi;Go;Java
#
#                                       LanguageWantToWorkWith  \
# ResponseId
# 36997                           Go;PHP;Python;SQL;TypeScript
# 11874                  Go;HTML/CSS;JavaScript;SQL;TypeScript
# 2541           C;C++;HTML/CSS;Java;JavaScript;PowerShell;SQL
# 6987        Go;HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript
# 29465                                    Assembly;C;C++;Rust
# 35525                                                    NaN
# 33639                                                    NaN
# 20475       Bash/Shell (all shells);C#;Lua;Python;R;Rust;SQL
# 43457                                        Java;TypeScript
# 29002                                                   Lisp
#
#                                              LanguageAdmired  \
# ResponseId
# 36997                              PHP;Python;SQL;TypeScript
# 11874                         HTML/CSS;JavaScript;TypeScript
# 2541           C;C++;HTML/CSS;Java;JavaScript;PowerShell;SQL
# 6987                   HTML/CSS;JavaScript;Python;TypeScript
# 29465                                                    NaN
# 35525                                                    NaN
# 33639                                                    NaN
# 20475       Bash/Shell (all shells);C#;Lua;Python;R;Rust;SQL
# 43457                                                   Java
# 29002                                                    NaN
#
#            LanguagesHaveEntry LanguagesWantEntry DatabaseChoice  \
# ResponseId
# 36997                     NaN                NaN            Yes
# 11874                     NaN                NaN            Yes
# 2541                      NaN                NaN            NaN
# 6987                      NaN                NaN            Yes
# 29465                     NaN                NaN            Yes
# 35525                     NaN                NaN            NaN
# 33639                     NaN                NaN            Yes
# 20475                     NaN                NaN            Yes
# 43457                     NaN                NaN            Yes
# 29002                     NaN                NaN            Yes
#
#                                       DatabaseHaveWorkedWith  \
# ResponseId
# 36997                                MySQL;PostgreSQL;SQLite
# 11874       Cloud Firestore;Firebase Realtime Database;MySQL
# 2541                                                     NaN
# 6987                                                   MySQL
# 29465                                             PostgreSQL
# 35525                                                    NaN
# 33639                Cloud Firestore;MySQL;PostgreSQL;SQLite
# 20475                         DuckDB;PostgreSQL;Redis;Valkey
# 43457                                                    NaN
# 29002                          MySQL;Neo4J;Oracle;PostgreSQL
#
#                                        DatabaseWantToWorkWith  \
# ResponseId
# 36997                                 MySQL;PostgreSQL;SQLite
# 11874       Cloud Firestore;MongoDB;MySQL;PostgreSQL;Redis...
# 2541                                                      NaN
# 6987                                MySQL;PostgreSQL;Supabase
# 29465                                                 MongoDB
# 35525                                                     NaN
# 33639            Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# 20475                                       PostgreSQL;Valkey
# 43457                                                     NaN
# 29002                                                     NaN
#
#                     DatabaseAdmired DatabaseHaveEntry DatabaseWantEntry  \
# ResponseId
# 36997       MySQL;PostgreSQL;SQLite               NaN               NaN
# 11874         Cloud Firestore;MySQL               NaN               NaN
# 2541                            NaN               NaN               NaN
# 6987                          MySQL               NaN               NaN
# 29465                           NaN               NaN               NaN
# 35525                           NaN               NaN               NaN
# 33639       MySQL;PostgreSQL;SQLite               NaN               NaN
# 20475             PostgreSQL;Valkey               NaN               NaN
# 43457                           NaN               NaN               NaN
# 29002                           NaN               NaN               NaN
#
#            PlatformChoice                             PlatformHaveWorkedWith  \
# ResponseId
# 36997                  No                                                NaN
# 11874                  No                                                NaN
# 2541                  Yes             Chocolatey;Cloudflare;Gradle;Ninja;Pip
# 6987                  Yes           Bun;Cloudflare;npm;Pip;pnpm;Vite;Webpack
# 29465                  No                                                NaN
# 35525                 NaN                                                NaN
# 33639                 Yes     Docker;Firebase;Microsoft Azure;npm;NuGet;Vite
# 20475                 Yes  Amazon Web Services (AWS);APT;Cargo;Docker;Goo...
# 43457                 Yes             Gradle;Homebrew;Maven (build tool);npm
# 29002                  No                                                NaN
#
#                                        PlatformWantToWorkWith  \
# ResponseId
# 36997                                                     NaN
# 11874                                                     NaN
# 2541                                  Chocolatey;Gradle;Ninja
# 6987                     Bun;Cloudflare;Composer;Pip;Supabase
# 29465                                                     NaN
# 35525                                                     NaN
# 33639       Amazon Web Services (AWS);Microsoft Azure;npm;...
# 20475                      Cargo;Docker;Pacman;Terraform;Vite
# 43457                                Docker;Gradle;Kubernetes
# 29002                                                     NaN
#
#                                PlatformAdmired PlatformHaveEntry  \
# ResponseId
# 36997                                      NaN               NaN
# 11874                                      NaN               NaN
# 2541                   Chocolatey;Gradle;Ninja               NaN
# 6987                        Bun;Cloudflare;Pip               NaN
# 29465                                      NaN               NaN
# 35525                                      NaN               NaN
# 33639           Microsoft Azure;npm;NuGet;Vite               NaN
# 20475       Cargo;Docker;Pacman;Terraform;Vite               NaN
# 43457                                   Gradle               NaN
# 29002                                      NaN               NaN
#
#            PlatformWantEntry WebframeChoice  \
# ResponseId
# 36997                    NaN            Yes
# 11874                    NaN            Yes
# 2541                     NaN             No
# 6987                    Deno            Yes
# 29465                    NaN            Yes
# 35525                    NaN            NaN
# 33639                    NaN            Yes
# 20475                    NaN            Yes
# 43457                    NaN             No
# 29002                    NaN            Yes
#
#                                        WebframeHaveWorkedWith  \
# ResponseId
# 36997                          Django;FastAPI;Laravel;Next.js
# 11874                    Laravel;Next.js;Nuxt.js;React;Vue.js
# 2541                                                      NaN
# 6987                                            Next.js;React
# 29465                                             Spring Boot
# 35525                                                     NaN
# 33639       ASP.NET;ASP.NET Core;Blazor;NestJS;Node.js;Vue.js
# 20475           ASP.NET Core;Express;React;Spring Boot;Svelte
# 43457                                                     NaN
# 29002       Angular;AngularJS;Next.js;Node.js;React;Spring...
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 36997                            Astro;Django;FastAPI;Laravel
# 11874       Astro;Deno;Express;FastAPI;Fastify;NestJS;Node...
# 2541                                                      NaN
# 6987         Astro;Deno;Express;Laravel;Next.js;Node.js;React
# 29465                                                     NaN
# 35525                                                     NaN
# 33639       ASP.NET;ASP.NET Core;Blazor;NestJS;Node.js;Vue.js
# 20475                               ASP.NET Core;React;Svelte
# 43457                                                     NaN
# 29002                                                     NaN
#
#                                               WebframeAdmired  \
# ResponseId
# 36997                                  Django;FastAPI;Laravel
# 11874                                                   React
# 2541                                                      NaN
# 6987                                            Next.js;React
# 29465                                                     NaN
# 35525                                                     NaN
# 33639       ASP.NET;ASP.NET Core;Blazor;NestJS;Node.js;Vue.js
# 20475                               ASP.NET Core;React;Svelte
# 43457                                                     NaN
# 29002                                                     NaN
#
#            WebframeHaveEntry  \
# ResponseId
# 36997                    NaN
# 11874                    NaN
# 2541                     NaN
# 6987                     NaN
# 29465                    JSF
# 35525                    NaN
# 33639                    NaN
# 20475                    NaN
# 43457                    NaN
# 29002                    NaN
#
#                                             WebframeWantEntry DevEnvsChoice  \
# ResponseId
# 36997                                                     NaN           Yes
# 11874       Preact, Solid, React Router, Tanstack Start/Ro...            No
# 2541                                                      NaN           Yes
# 6987                                                      NaN           Yes
# 29465                                                     NaN            No
# 35525                                                     NaN           NaN
# 33639                                                     NaN           Yes
# 20475                                                     NaN            No
# 43457                                                     NaN           Yes
# 29002                                                     NaN            No
#
#                                         DevEnvsHaveWorkedWith  \
# ResponseId
# 36997       Android Studio;IntelliJ IDEA;Jupyter Notebook/...
# 11874                                                     NaN
# 2541                          Sublime Text;Visual Studio Code
# 6987                          Eclipse;Nano;Visual Studio Code
# 29465                                                     NaN
# 35525                                                     NaN
# 33639          Rider;Sublime Text;Visual Studio Code;WebStorm
# 20475                                                     NaN
# 43457            Claude Code;IntelliJ IDEA;Visual Studio Code
# 29002                                                     NaN
#
#                                         DevEnvsWantToWorkWith  \
# ResponseId
# 36997       Android Studio;IntelliJ IDEA;Jupyter Notebook/...
# 11874                                                     NaN
# 2541                          Sublime Text;Visual Studio Code
# 6987                         Nano;Visual Studio Code;WebStorm
# 29465                                                     NaN
# 35525                                                     NaN
# 33639          Rider;Sublime Text;Visual Studio Code;WebStorm
# 20475                                                     NaN
# 43457            Claude Code;IntelliJ IDEA;Visual Studio Code
# 29002                                                     NaN
#
#                                                DevEnvsAdmired DevEnvHaveEntry  \
# ResponseId
# 36997       Android Studio;IntelliJ IDEA;Jupyter Notebook/...             NaN
# 11874                                                     NaN             NaN
# 2541                          Sublime Text;Visual Studio Code             NaN
# 6987                                  Nano;Visual Studio Code             NaN
# 29465                                                     NaN             NaN
# 35525                                                     NaN             NaN
# 33639          Rider;Sublime Text;Visual Studio Code;WebStorm             NaN
# 20475                                                     NaN             NaN
# 43457            Claude Code;IntelliJ IDEA;Visual Studio Code             NaN
# 29002                                                     NaN             NaN
#
#            DevEnvWantEntry                               SOTagsHaveWorkedWith  \
# ResponseId
# 36997                  NaN                      Pydantic;Google Gemini;Ollama
# 11874                  NaN  Tailwind CSS 4;Large Language Model;Google Gemini
# 2541                   NaN                                      Google Gemini
# 6987                   NaN                            Google Gemini;Shadcn/ui
# 29465                  NaN                                               Odoo
# 35525                  NaN                                                NaN
# 33639                  NaN              .NET 8 or higher;Large Language Model
# 20475                  NaN                                             Ollama
# 43457                  NaN                                                NaN
# 29002                  NaN                                          LangGraph
#
#                                          SOTagsWantToWorkWith  \
# ResponseId
# 36997                                                Pydantic
# 11874       Tailwind CSS 4;hostinger;Large Language Model;...
# 2541                                            Google Gemini
# 6987                   Tailwind CSS 4;Google Gemini;Shadcn/ui
# 29465                                                     NaN
# 35525                                                     NaN
# 33639                                        .NET 8 or higher
# 20475                                                  Ollama
# 43457                                                     NaN
# 29002                                                     NaN
#
#                                                 SOTagsAdmired SOTagsHaveEntry  \
# ResponseId
# 36997                                                Pydantic             NaN
# 11874       Tailwind CSS 4;Large Language Model;Google Gemini             NaN
# 2541                                            Google Gemini             NaN
# 6987                                  Google Gemini;Shadcn/ui             NaN
# 29465                                                     NaN             NaN
# 35525                                                     NaN             NaN
# 33639                                        .NET 8 or higher             NaN
# 20475                                                  Ollama             NaN
# 43457                                                     NaN             NaN
# 29002                                                     NaN             NaN
#
#            SOTagsWant Entry                   OpSysPersonal use  \
# ResponseId
# 36997                   NaN  Windows;iOS;Linux (non-WSL);Fedora
# 11874                   NaN                     Windows;Android
# 2541                    NaN                     Windows;Android
# 6987                    NaN                     Windows;Android
# 29465                   NaN                                Arch
# 35525                   NaN                                 NaN
# 33639                   NaN              Windows;Ubuntu;Android
# 20475                   NaN          Linux (non-WSL);Arch;NixOS
# 43457                   NaN          Windows;MacOS;iOS;ChromeOS
# 29002                   NaN                     Linux (non-WSL)
#
#                                         OpSysProfessional use  \
# ResponseId
# 36997       Windows Subsystem for Linux (WSL);Linux (non-W...
# 11874                                                 Windows
# 2541                                                      NaN
# 6987                                                   Fedora
# 29465                                                  Ubuntu
# 35525                                                     NaN
# 33639                                          Windows;Ubuntu
# 20475                              Linux (non-WSL);Arch;NixOS
# 43457                                  Windows;MacOS;ChromeOS
# 29002                                                     NaN
#
#                                OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 36997                               GitHub;Jira;Markdown File
# 11874       GitHub;GitLab;Google Colab;Google Workspace;Ma...
# 2541                                                      NaN
# 6987                                                   GitHub
# 29465                                           GitHub;Trello
# 35525                                                     NaN
# 33639                              Azure Devops;GitHub;GitLab
# 20475                                                     NaN
# 43457                                             GitHub;Jira
# 29002                                                  GitHub
#
#                     OfficeStackAsyncWantToWorkWith OfficeStackAsyncAdmired  \
# ResponseId
# 36997                                  GitHub;Jira             GitHub;Jira
# 11874                                GitHub;Trello           GitHub;Trello
# 2541                                           NaN                     NaN
# 6987                                        GitHub                  GitHub
# 29465                                          NaN                     NaN
# 35525                                          NaN                     NaN
# 33639                          Azure Devops;GitHub     Azure Devops;GitHub
# 20475                                          NaN                     NaN
# 43457       Azure Devops;GitHub;Jira;Notion;Trello             GitHub;Jira
# 29002                                          NaN                     NaN
#
#            OfficeStackHaveEntry OfficeStackWantEntry  \
# ResponseId
# 36997                       NaN                  NaN
# 11874                       NaN                  NaN
# 2541                        NaN                  NaN
# 6987                     Apidog                  NaN
# 29465                       SVN                  NaN
# 35525                       NaN                  NaN
# 33639                       NaN                  NaN
# 20475                     Taiga                Taiga
# 43457                       NaN                  NaN
# 29002                       NaN                  NaN
#
#                                    CommPlatformHaveWorkedWith  \
# ResponseId
# 36997       Stack Overflow;Discord;Reddit;GitHub (public p...
# 11874       Stack Overflow;Discord;Reddit;Hacker News;GitH...
# 2541                            Stack Overflow;Stack Exchange
# 6987        Stack Overflow;Reddit;GitHub (public projects,...
# 29465                                          Reddit;YouTube
# 35525                                                     NaN
# 33639                         Stack Overflow;Discord;LinkedIn
# 20475       Stack Overflow;Discord;Reddit;Hacker News;GitH...
# 43457                                Discord;YouTube;LinkedIn
# 29002       Stack Overflow;Stack Exchange;Reddit;GitHub (p...
#
#                                    CommPlatformWantToWorkWith  \
# ResponseId
# 36997       Discord;Reddit;GitHub (public projects, not pr...
# 11874       Discord;GitHub (public projects, not private r...
# 2541                            Stack Overflow;Stack Exchange
# 6987        Stack Overflow;Reddit;GitHub (public projects,...
# 29465                                                     NaN
# 35525                                                     NaN
# 33639                                                     NaN
# 20475       Hacker News;GitHub (public projects, not priva...
# 43457       Discord;GitHub (public projects, not private r...
# 29002                                                     NaN
#
#                                           CommPlatformAdmired  \
# ResponseId
# 36997       Discord;Reddit;GitHub (public projects, not pr...
# 11874       Discord;GitHub (public projects, not private r...
# 2541                            Stack Overflow;Stack Exchange
# 6987        Stack Overflow;Reddit;GitHub (public projects,...
# 29465                                                     NaN
# 35525                                                     NaN
# 33639                                                     NaN
# 20475       Hacker News;GitHub (public projects, not priva...
# 43457                                Discord;YouTube;LinkedIn
# 29002                                                     NaN
#
#            CommPlatformHaveEntr CommPlatformWantEntr AIModelsChoice  \
# ResponseId
# 36997                       NaN                  NaN            Yes
# 11874                       NaN                  NaN            NaN
# 2541                   Codeberg                  NaN            Yes
# 6987                        NaN                  NaN            Yes
# 29465                       NaN                  NaN            Yes
# 35525                       NaN                  NaN            NaN
# 33639                       NaN                  NaN            Yes
# 20475                       NaN                  NaN             No
# 43457                       NaN                  NaN            Yes
# 29002                       NaN                  NaN             No
#
#                                        AIModelsHaveWorkedWith  \
# ResponseId
# 36997       Anthropic: Claude Sonnet;Gemini (Pro Reasoning...
# 11874       Anthropic: Claude Sonnet;DeepSeek (R- Reasonin...
# 2541        Anthropic: Claude Sonnet;Gemini (Flash general...
# 6987        Anthropic: Claude Sonnet;Gemini (Pro Reasoning...
# 29465                             openAI GPT (chatbot models)
# 35525                                                     NaN
# 33639       openAI GPT (chatbot models);openAI Image gener...
# 20475                                                     NaN
# 43457                                                     NaN
# 29002                                                     NaN
#
#                                        AIModelsWantToWorkWith  \
# ResponseId
# 36997       Anthropic: Claude Sonnet;Gemini (Pro Reasoning...
# 11874       Anthropic: Claude Sonnet;Gemini (Flash general...
# 2541        Gemini (Flash general purpose models);openAI G...
# 6987        Anthropic: Claude Sonnet;Gemini (Pro Reasoning...
# 29465                                                     NaN
# 35525                                                     NaN
# 33639                                                     NaN
# 20475                                                     NaN
# 43457                                                     NaN
# 29002                                                     NaN
#
#                                               AIModelsAdmired  \
# ...
# 36997       Debugging AI-generated code is more time-consu...
# 11874       AI solutions that are almost right, but not qu...
# 2541        Debugging AI-generated code is more time-consu...
# 6987        AI solutions that are almost right, but not qu...
# 29465                                                     NaN
# 35525       Debugging AI-generated code is more time-consu...
# 33639       Debugging AI-generated code is more time-consu...
# 20475                          I don’t use AI tools regularly
# 43457       Debugging AI-generated code is more time-consu...
# 29002       I’ve become less confident in my own problem-s...
#
#                                                     AIExplain  \
# ResponseId
# 36997                                                   nahhh
# 11874       Nope, not at all, AI code needs a ton of human...
# 2541                                                  Big NO.
# 6987                                         No, It's stupid.
# 29465                                                     NaN
# 35525                                                     NaN
# 33639       Not really, I just use LLM's for suggestions r...
# 20475                                                     NaN
# 43457                                                     NaN
# 29002                                                      No
#
#                                        AIAgents  \
# ResponseId
# 36997                   No, and I don't plan to
# 11874       Yes, I use AI agents at work weekly
# 2541                    No, and I don't plan to
# 6987        Yes, I use AI agents at work weekly
# 29465                                       NaN
# 35525        Yes, I use AI agents at work daily
# 33639       Yes, I use AI agents at work weekly
# 20475                   No, and I don't plan to
# 43457                         No, but I plan to
# 29002        Yes, I use AI agents at work daily
#
#                                                 AIAgentChange  \
# ResponseId
# 36997                                           Yes, somewhat
# 11874                                           Yes, somewhat
# 2541        No, but my development work has changed somewh...
# 6987                                            Yes, somewhat
# 29465                                                     NaN
# 35525                                  Yes, to a great extent
# 33639                                           Yes, somewhat
# 20475                                 Not at all or minimally
# 43457                                 Not at all or minimally
# 29002                                           Yes, somewhat
#
#                                           AIAgent_Uses AgentUsesGeneral  \
# ResponseId
# 36997                                              NaN              NaN
# 11874                             Software engineering              NaN
# 2541                                               NaN              NaN
# 6987        Software engineering;Decision intelligence              NaN
# 29465                                              NaN              NaN
# 35525                                              NaN              NaN
# 33639               Software engineering;IT operations              NaN
# 20475                                              NaN              NaN
# 43457                                              NaN              NaN
# 29002                             Software engineering              NaN
#
#                                   AIAgentImpactSomewhat agree  \
# ResponseId
# 36997                                                     NaN
# 11874       AI agents have increased my productivity.;AI a...
# 2541                                                      NaN
# 6987        AI agents have improved the quality of my code...
# 29465                                                     NaN
# 35525                                                     NaN
# 33639       AI agents have helped me automate repetitive t...
# 20475                                                     NaN
# 43457                                                     NaN
# 29002                                                     NaN
#
#                                          AIAgentImpactNeutral  \
# ResponseId
# 36997                                                     NaN
# 11874       AI agents have helped me solve complex problem...
# 2541                                                      NaN
# 6987        AI agents have helped me automate repetitive t...
# 29465                                                     NaN
# 35525                                                     NaN
# 33639       AI agents have increased my productivity.;AI a...
# 20475                                                     NaN
# 43457                                                     NaN
# 29002                                                     NaN
#
#                                AIAgentImpactSomewhat disagree  \
# ResponseId
# 36997                                                     NaN
# 11874       AI agents have improved the quality of my code...
# 2541                                                      NaN
# 6987        AI agents have improved collaboration within m...
# 29465                                                     NaN
# 35525                                                     NaN
# 33639       AI agents have improved the quality of my code...
# 20475                                                     NaN
# 43457                                                     NaN
# 29002                                                     NaN
#
#                                   AIAgentImpactStrongly agree  \
# ResponseId
# 36997                                                     NaN
# 11874       AI agents have reduced the time spent on speci...
# 2541                                                      NaN
# 6987        AI agents have increased my productivity.;AI a...
# 29465                                                     NaN
# 35525                                                     NaN
# 33639                                                     NaN
# 20475                                                     NaN
# 43457                                                     NaN
# 29002               AI agents have increased my productivity.
#
#            AIAgentImpactStrongly disagree  \
# ResponseId
# 36997                                 NaN
# 11874                                 NaN
# 2541                                  NaN
# 6987                                  NaN
# 29465                                 NaN
# 35525                                 NaN
# 33639                                 NaN
# 20475                                 NaN
# 43457                                 NaN
# 29002                                 NaN
#
#                                      AIAgentChallengesNeutral  \
# ResponseId
# 36997       It takes significant time and effort to learn ...
# 11874       It takes significant time and effort to learn ...
# 2541        The cost of using certain AI agent platforms i...
# 6987                                                      NaN
# 29465                                                     NaN
# 35525                                                     NaN
# 33639       Integrating AI agents with my existing tools a...
# 20475                                                     NaN
# 43457       Integrating AI agents with my existing tools a...
# 29002                                                     NaN
#
#                            AIAgentChallengesSomewhat disagree  \
# ResponseId
# 36997       Integrating AI agents with my existing tools a...
# 11874       My company's IT and/or InfoSec teams have stri...
# 2541                                                      NaN
# 6987        Integrating AI agents with my existing tools a...
# 29465                                                     NaN
# 35525                                                     NaN
# 33639                                                     NaN
# 20475                                                     NaN
# 43457       The cost of using certain AI agent platforms i...
# 29002                                                     NaN
#
#                               AIAgentChallengesStrongly agree  \
# ResponseId
# 36997       I have concerns about the security and privacy...
# 11874       I am concerned about the accuracy of the infor...
# 2541        I am concerned about the accuracy of the infor...
# 6987        The cost of using certain AI agent platforms i...
# 29465                                                     NaN
# 35525                                                     NaN
# 33639       I am concerned about the accuracy of the infor...
# 20475                                                     NaN
# 43457                                                     NaN
# 29002                                                     NaN
#
#                               AIAgentChallengesSomewhat agree  \
# ResponseId
# 36997       I am concerned about the accuracy of the infor...
# 11874       Integrating AI agents with my existing tools a...
# 2541                                                      NaN
# 6987        I am concerned about the accuracy of the infor...
# 29465                                                     NaN
# 35525                                                     NaN
# 33639       I have concerns about the security and privacy...
# 20475                                                     NaN
# 43457       I am concerned about the accuracy of the infor...
# 29002                                                     NaN
#
#                            AIAgentChallengesStrongly disagree  \
# ResponseId
# 36997       My company's IT and/or InfoSec teams have stri...
# 11874                                                     NaN
# 2541                                                      NaN
# 6987        My company's IT and/or InfoSec teams have stri...
# 29465                                                     NaN
# 35525                                                     NaN
# 33639                                                     NaN
# 20475                                                     NaN
# 43457                                                     NaN
# 29002                                                     NaN
#
#            AIAgentKnowledge AIAgentKnowWrite AIAgentOrchestration  \
# ResponseId
# 36997                   NaN              NaN                  NaN
# 11874                   NaN              NaN                  NaN
# 2541                    NaN              NaN                  NaN
# 6987                    NaN              NaN                  NaN
# 29465                   NaN              NaN                  NaN
# 35525                   NaN              NaN                  NaN
# 33639                   NaN              NaN                  NaN
# 20475                   NaN              NaN                  NaN
# 43457                   NaN              NaN                  NaN
# 29002                   NaN              NaN                  NaN
#
#            AIAgentOrchWrite AIAgentObserveSecure AIAgentObsWrite  \
# ResponseId
# 36997                   NaN                  NaN             NaN
# 11874                   NaN                  NaN             NaN
# 2541                    NaN                  NaN             NaN
# 6987                    NaN                  NaN             NaN
# 29465                   NaN                  NaN             NaN
# 35525                   NaN                  NaN             NaN
# 33639                   NaN                  NaN             NaN
# 20475                   NaN                  NaN             NaN
# 43457                   NaN                  NaN             NaN
# 29002                   NaN                  NaN             NaN
#
#                                               AIAgentExternal AIAgentExtWrite  \
# ResponseId
# 36997                                                     NaN             NaN
# 11874       ChatGPT;GitHub Copilot;Google Gemini;Bolt.new;...             NaN
# 2541                                                      NaN             NaN
# 6987                     ChatGPT;GitHub Copilot;Google Gemini             NaN
# 29465                                                     NaN             NaN
# 35525                                                     NaN             NaN
# 33639                                                 ChatGPT             NaN
# 20475                                                     NaN             NaN
# 43457                                                     NaN             NaN
# 29002                                                     NaN             NaN
#
#                                                       AIHuman  \
# ResponseId
# 36997       When I don’t trust AI’s answers;When I want to...
# 11874       When I don’t trust AI’s answers;When I want to...
# 2541        When I don’t trust AI’s answers;When I want to...
# 6987        When I don’t trust AI’s answers;When I want to...
# 29465                                                     NaN
# 35525                                                     NaN
# 33639       When I don’t trust AI’s answers;When I want to...
# 20475                                                     NaN
# 43457       When I want to fully understand something;When...
# 29002                                                     NaN
#
#                                                        AIOpen  \
# ResponseId
# 36997                                         problem solving
# 11874       Architectural designs should be made by humans...
# 2541              The difference between humans and machines.
# 6987                                                      NaN
# 29465                                                     NaN
# 35525                                                     NaN
# 33639       Communication, clear and concise knowledge ove...
# 20475                                                     NaN
# 43457                                                Critical
# 29002                                                     NaN
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 36997                       NaN     9.0
# 11874                       NaN     7.0
# 2541                        NaN     NaN
# 6987                        NaN     9.0
# 29465                    7705.0     5.0
# 35525                     200.0     NaN
# 33639                   11090.0     NaN
# 20475                       NaN     9.0
# 43457                    6000.0     NaN
# 29002                       NaN     7.0
