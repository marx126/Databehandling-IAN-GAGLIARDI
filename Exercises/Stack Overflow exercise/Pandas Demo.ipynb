# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df
# Out:
#        ResponseId                      MainBranch              Age  \
# 0               1  I am a developer by profession  25-34 years old
# 1               2  I am a developer by profession  25-34 years old
# 2               3  I am a developer by profession  35-44 years old
# 3               4  I am a developer by profession  35-44 years old
# 4               5  I am a developer by profession  35-44 years old
# ...           ...                             ...              ...
# 49118       49119  I am a developer by profession  25-34 years old
# 49119       49120  I am a developer by profession  35-44 years old
# 49120       49121  I am a developer by profession  25-34 years old
# 49121       49122  I am a developer by profession  25-34 years old
# 49122       49123  I am a developer by profession  25-34 years old
#
#                                                  EdLevel  \
# 0        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
df.shape
# Out:
# (49123, 170)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49123 entries, 0 to 49122
# Columns: 170 entries, ResponseId to JobSat
# dtypes: float64(50), int64(1), object(119)
# memory usage: 63.7+ MB

# %%
pd.set_option('display.max_columns', 170)
pd.set_option('display.max_rows', 139)

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#         qid                 qname  \
# 0     QID18         TechEndorse_1
# 1     QID18         TechEndorse_2
# 2     QID18         TechEndorse_3
# 3     QID18         TechEndorse_4
# 4     QID18         TechEndorse_5
# 5     QID18         TechEndorse_6
# 6     QID18         TechEndorse_7
# 7     QID18         TechEndorse_8
# 8     QID18         TechEndorse_9
# 9     QID18        TechEndorse_13
# 10    QID18   TechEndorse_13_TEXT
# 11    QID19          TechOppose_1
# 12    QID19          TechOppose_2
# 13    QID19          TechOppose_3
# 14    QID19          TechOppose_5
# 15    QID19          TechOppose_7
# 16    QID19          TechOppose_9
# 17    QID19         TechOppose_11
# 18    QID19         TechOppose_13
# 19    QID19         TechOppose_16
# 20    QID19         TechOppose_15
# 21    QID19    TechOppose_15_TEXT
# 22    QID27        JobSatPoints_1
# 23    QID27        JobSatPoints_2
# 24    QID27       JobSatPoints_16
# 25    QID27        JobSatPoints_3
# ...

# %%
schema_df.head()
# Out:
#      qid          qname                                           question  \
# 0  QID18  TechEndorse_1  What attracts you to a technology or causes yo...
# 1  QID18  TechEndorse_2  What attracts you to a technology or causes yo...
# 2  QID18  TechEndorse_3  What attracts you to a technology or causes yo...
# 3  QID18  TechEndorse_4  What attracts you to a technology or causes yo...
# 4  QID18  TechEndorse_5  What attracts you to a technology or causes yo...
#
#   type                                      sub  sq_id
# 0   RO  AI integration or AI Agent capabilities    1.0
# 1   RO                          Easy-to-use API    2.0
# 2   RO                  Robust and complete API    3.0
# 3   RO     Customizable and manageable codebase    4.0
# 4   RO                   Reputation for quality    5.0

# %%
schema_df.tail()
# Out:
#         qid            qname  \
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  sub  sq_id
# 134  Was the tool or tools for AI agent observabili...   TE  NaN    NaN
# 135  You indicated you use or develop AI agents as ...   MC  NaN    NaN
# 136  Was the out-of-the-box agents, copilots or ass...   TE  NaN    NaN
# 137  In the future, if AI can do most coding tasks,...   MC  NaN    NaN
# 138  Looking ahead 3–5 years, what skills do you be...   TE  NaN    NaN

# %%
df.shape
# Out:
# (49123, 170)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=170)

# %%
df["Age"]
# Out:
# 0        25-34 years old
# 1        25-34 years old
# 2        35-44 years old
# 3        35-44 years old
# 4        35-44 years old
#               ...
# 49118    25-34 years old
# 49119    35-44 years old
# 49120    25-34 years old
# 49121    25-34 years old
# 49122    25-34 years old
# Name: Age, Length: 49123, dtype: object

# %%
df["Age"].value_counts()
# Out:
# Age
# 25-34 years old      16485
# 35-44 years old      13232
# 18-24 years old       9195
# 45-54 years old       6265
# 55-64 years old       2626
# 65 years or older      942
# Prefer not to say      378
# Name: count, dtype: int64

# %%
df.loc[0]
# Out:
# ResponseId                                                           1
# MainBranch                              I am a developer by profession
# Age                                                    25-34 years old
# EdLevel                Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                    Employed
#                                             ...
# AIAgentExtWrite                                                    NaN
# AIHuman                                When I don’t trust AI’s answers
# AIOpen                           Troubleshooting, profiling, debugging
# ConvertedCompYearly                                            61256.0
# JobSat                                                            10.0
# Name: 0, Length: 170, dtype: object

# %%
df.loc[0, "Age"]
# Out:
# '25-34 years old'

# %%
df.loc[[0, 1, 2], "Age"]
# Out:
# 0    25-34 years old
# 1    25-34 years old
# 2    35-44 years old
# Name: Age, dtype: object

# %%
df.loc[0:2, "Age"]
# Out:
# 0    25-34 years old
# 1    25-34 years old
# 2    35-44 years old
# Name: Age, dtype: object

# %%
df.loc[0:2, "Age":"WorkExp"]
# Out:
#                Age                                          EdLevel  \
# 0  25-34 years old  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1  25-34 years old              Associate degree (A.A., A.S., etc.)
# 2  35-44 years old     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
#
#                                     EmploymentAddl  WorkExp
# 0  Caring for dependents (children, elderly, etc.)      8.0
# 1                                              NaN      2.0
# 2                                None of the above     10.0

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col="ResponseId")

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# ...

# %%
df.loc[1]
# Out:
# MainBranch                              I am a developer by profession
# Age                                                    25-34 years old
# EdLevel                Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                    Employed
# EmploymentAddl         Caring for dependents (children, elderly, etc.)
#                                             ...
# AIAgentExtWrite                                                    NaN
# AIHuman                                When I don’t trust AI’s answers
# AIOpen                           Troubleshooting, profiling, debugging
# ConvertedCompYearly                                            61256.0
# JobSat                                                            10.0
# Name: 1, Length: 169, dtype: object

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col="qname")

# %%
schema_df
# Out:
#                          qid  \
# qname
# TechEndorse_1          QID18
# TechEndorse_2          QID18
# TechEndorse_3          QID18
# TechEndorse_4          QID18
# TechEndorse_5          QID18
# TechEndorse_6          QID18
# TechEndorse_7          QID18
# TechEndorse_8          QID18
# TechEndorse_9          QID18
# TechEndorse_13         QID18
# TechEndorse_13_TEXT    QID18
# TechOppose_1           QID19
# TechOppose_2           QID19
# TechOppose_3           QID19
# TechOppose_5           QID19
# TechOppose_7           QID19
# TechOppose_9           QID19
# TechOppose_11          QID19
# TechOppose_13          QID19
# TechOppose_16          QID19
# TechOppose_15          QID19
# TechOppose_15_TEXT     QID19
# JobSatPoints_1         QID27
# JobSatPoints_2         QID27
# JobSatPoints_16        QID27
# JobSatPoints_3         QID27
# JobSatPoints_4         QID27
# JobSatPoints_5         QID27
# JobSatPoints_6         QID27
# JobSatPoints_7         QID27
# ...

# %%
schema_df.loc["Employment"]
# Out:
# qid                                                      QID7
# question    Which of the following best describes your cur...
# type                                                       MC
# sub                                                       NaN
# sq_id                                                     NaN
# Name: Employment, dtype: object

# %%
schema_df.loc["Employment", "question"]
# Out:
# 'Which of the following best describes your current employment status?<br>'

# %%
schema_df.sort_index()
# Out:
#                          qid  \
# qname
# AIAcc                  QID80
# AIAgentChallenges      QID88
# AIAgentChange          QID83
# AIAgentExtWrite       QID104
# AIAgentExternal        QID92
# AIAgentImpact          QID87
# AIAgentKnowWrite      QID107
# AIAgentKnowledge       QID89
# AIAgentObsWrite       QID103
# AIAgentObserveSecure   QID91
# AIAgentOrchWrite      QID102
# AIAgentOrchestration   QID90
# AIAgent_Uses           QID86
# AIAgents               QID85
# AIComplex              QID81
# AIExplain              QID84
# AIFrustration          QID99
# AIHuman               QID100
# AILearnHow             QID32
# AIModels               QID43
# AIModelsChoice         QID50
# AIModelsHaveEntry      QID68
# AIModelsWantEntry      QID69
# AIOpen                 QID93
# AISelect               QID78
# AISent                 QID79
# AIThreat               QID28
# AITool                 QID82
# Age                     QID4
# AgentUsesGeneral      QID106
# ...

# %%
code_experience = df["YearsCode"] > 50

# %%
df.loc[code_experience]
# Out:
#                                                    MainBranch  \
# ResponseId
# 176         I used to be a developer by profession, but no...
# 259                               I code primarily as a hobby
# 426                            I am a developer by profession
# 937         I work with developers or my work supports dev...
# 954                               I code primarily as a hobby
# ...                                                       ...
# 47602       I am not primarily a developer, but I write co...
# 47981                             I code primarily as a hobby
# 48177       I am not primarily a developer, but I write co...
# 48209                          I am a developer by profession
# 48300                          I am a developer by profession
#
#                           Age  \
# ResponseId
# 176         65 years or older
# 259         65 years or older
# 426         65 years or older
# 937         65 years or older
# 954           55-64 years old
# ...

# %%
df.loc[code_experience, ["Age", "Employment", "RemoteWork"]]
# Out:
#                           Age  \
# ResponseId
# 176         65 years or older
# 259         65 years or older
# 426         65 years or older
# 937         65 years or older
# 954           55-64 years old
# ...                       ...
# 47602         25-34 years old
# 47981       65 years or older
# 48177       65 years or older
# 48209       65 years or older
# 48300         18-24 years old
#
#                                                    Employment  \
# ResponseId
# 176                                                   Retired
# 259                                                   Retired
# 426                                                  Employed
# 937                                                  Employed
# 954                                                   Retired
# ...                                                       ...
# 47602                                                 Student
# 47981       Independent contractor, freelancer, or self-em...
# ...

# %%
countries = ["Spain", "Italy", "Sweden"]

# %%
filt = df["Country"].isin(countries)

# %%
df.loc[filt, "Country"]
# Out:
# ResponseId
# 28       Sweden
# 37        Italy
# 61        Spain
# 68       Sweden
# 86        Italy
#           ...
# 48910     Italy
# 48938    Sweden
# 48955     Italy
# 49027     Spain
# 49123     Italy
# Name: Country, Length: 2167, dtype: object

# %%
df["LanguageHaveWorkedWith"]
# Out:
# ResponseId
# 1                         Bash/Shell (all shells);Dart;SQL
# 2                                                     Java
# 3                      Dart;HTML/CSS;JavaScript;TypeScript
# 4                                          Java;Kotlin;SQL
# 5        C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
#                                ...
# 49119                                                  NaN
# 49120                                                  NaN
# 49121                                                  NaN
# 49122                                               C#;SQL
# 49123                                                  NaN
# Name: LanguageHaveWorkedWith, Length: 49123, dtype: object

# %%
filt = df["LanguageHaveWorkedWith"].str.contains("Python", na=False)

# %%
df.loc[filt, "LanguageHaveWorkedWith"]
# Out:
# ResponseId
# 5        C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
# 8        Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 9                                        Java;Python;Scala
# 16       Ada;Assembly;C;C#;C++;COBOL;Dart;Delphi;Elixir...
# 18                          HTML/CSS;JavaScript;Python;SQL
#                                ...
# 49062    C;Go;HTML/CSS;JavaScript;MATLAB;MicroPython;Py...
# 49089                                           Python;SQL
# 49090    C;C#;C++;HTML/CSS;Java;JavaScript;PHP;PowerShe...
# 49106    C++;Dart;GDScript;HTML/CSS;JavaScript;PHP;Powe...
# 49107    Bash/Shell (all shells);Delphi;PowerShell;Pyth...
# Name: LanguageHaveWorkedWith, Length: 18444, dtype: object

# %%
df.rename(columns={"Age": "CurrentAge"}) # Temporary change
# Out:
#                                 MainBranch       CurrentAge  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
# ...                                    ...              ...
# 49119       I am a developer by profession  25-34 years old
# 49120       I am a developer by profession  35-44 years old
# 49121       I am a developer by profession  25-34 years old
# 49122       I am a developer by profession  25-34 years old
# 49123       I am a developer by profession  25-34 years old
#
#                                                       EdLevel  \
# ResponseId
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                         Associate degree (A.A., A.S., etc.)
# ...

# %%
df.rename(columns={"Age": "CurrentAge"}, inplace=True) # Permanent change

# %%
df
# Out:
#                                 MainBranch       CurrentAge  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
# ...                                    ...              ...
# 49119       I am a developer by profession  25-34 years old
# 49120       I am a developer by profession  35-44 years old
# 49121       I am a developer by profession  25-34 years old
# 49122       I am a developer by profession  25-34 years old
# 49123       I am a developer by profession  25-34 years old
#
#                                                       EdLevel  \
# ResponseId
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                         Associate degree (A.A., A.S., etc.)
# ...

# %%
df["Employment"].map({"Employed": True, "Unemployed": False})
# Out:
# ResponseId
# 1        True
# 2        True
# 3         NaN
# 4        True
# 5         NaN
#          ...
# 49119    True
# 49120    True
# 49121    True
# 49122    True
# 49123    True
# Name: Employment, Length: 49123, dtype: object

# %%
df.sort_values(by="Country")
# Out:
#                                                    MainBranch  \
# ResponseId
# 7167                           I am a developer by profession
# 6010                           I am a developer by profession
# 7925                           I am a developer by profession
# 40307                          I am a developer by profession
# 7077        I am not primarily a developer, but I write co...
# ...                                                       ...
# 49117                          I am a developer by profession
# 49118                          I am a developer by profession
# 49119                          I am a developer by profession
# 49120                          I am a developer by profession
# 49121                          I am a developer by profession
#
#                  CurrentAge  \
# ResponseId
# 7167        25-34 years old
# 6010        25-34 years old
# 7925        18-24 years old
# 40307       25-34 years old
# 7077        25-34 years old
# ...

# %%
df["Country"].head(50)
# Out:
# ResponseId
# 1                                               Ukraine
# 2                                           Netherlands
# 3                                               Ukraine
# 4                                               Ukraine
# 5                                               Ukraine
# 6                                               Ukraine
# 7                                               Ukraine
# 8                                               Ukraine
# 9                                               Ukraine
# 10                                              Ukraine
# 11                                              Ukraine
# 12                                              Ukraine
# 13                                              Ukraine
# 14                                                India
# 15                                              Georgia
# 16                                                India
# 17                                            Australia
# ...

# %%
df[["Country", "WorkExp"]].head(50)
# Out:
#                                                       Country  WorkExp
# ResponseId
# 1                                                     Ukraine      8.0
# 2                                                 Netherlands      2.0
# 3                                                     Ukraine     10.0
# 4                                                     Ukraine      4.0
# 5                                                     Ukraine     21.0
# 6                                                     Ukraine     15.0
# 7                                                     Ukraine      9.0
# 8                                                     Ukraine     22.0
# 9                                                     Ukraine      9.0
# 10                                                    Ukraine      7.0
# 11                                                    Ukraine      7.0
# 12                                                    Ukraine      3.0
# ...

# %%
df.sort_values(by=["Country", "WorkExp"], ascending=[True, False])
# Out:
#                                                    MainBranch  \
# ResponseId
# 38609       I used to be a developer by profession, but no...
# 44797       I am not primarily a developer, but I write co...
# 45925                          I am a developer by profession
# 40307                          I am a developer by profession
# 40967                          I am a developer by profession
# ...                                                       ...
# 49098                          I am a developer by profession
# 49100                          I am a developer by profession
# 49108       I am not primarily a developer, but I write co...
# 49114                                   I am learning to code
# 49118                          I am a developer by profession
#
#                    CurrentAge  \
# ResponseId
# 38609         18-24 years old
# 44797       Prefer not to say
# 45925         25-34 years old
# 40307         25-34 years old
# 40967         18-24 years old
# ...

# %%
df[["Country", "WorkExp"]].head(50)
# Out:
#                                                       Country  WorkExp
# ResponseId
# 1                                                     Ukraine      8.0
# 2                                                 Netherlands      2.0
# 3                                                     Ukraine     10.0
# 4                                                     Ukraine      4.0
# 5                                                     Ukraine     21.0
# 6                                                     Ukraine     15.0
# 7                                                     Ukraine      9.0
# 8                                                     Ukraine     22.0
# 9                                                     Ukraine      9.0
# 10                                                    Ukraine      7.0
# 11                                                    Ukraine      7.0
# 12                                                    Ukraine      3.0
# ...

# %%
df["WorkExp"].nlargest(10)
# Out:
# ResponseId
# 3286     100.0
# 4934     100.0
# 7882     100.0
# 11065    100.0
# 12141    100.0
# 15656    100.0
# 16716    100.0
# 18574    100.0
# 19681    100.0
# 21456    100.0
# Name: WorkExp, dtype: float64

# %%
df.nlargest(10,"WorkExp")
# Out:
#                                                    MainBranch  \
# ResponseId
# 3286                              I code primarily as a hobby
# 4934                           I am a developer by profession
# 7882                                    I am learning to code
# 11065                          I am a developer by profession
# 12141                             I code primarily as a hobby
# 15656                                   I am learning to code
# 16716                          I am a developer by profession
# 18574                             I code primarily as a hobby
# 19681       I am not primarily a developer, but I write co...
# 21456                          I am a developer by profession
#
#                    CurrentAge  \
# ResponseId
# 3286        65 years or older
# 4934          45-54 years old
# 7882          25-34 years old
# 11065         25-34 years old
# 12141         35-44 years old
# 15656         35-44 years old
# 16716         18-24 years old
# ...

# %%
df.nsmallest(10,"WorkExp")
# Out:
#                                                    MainBranch  \
# ResponseId
# 18                             I am a developer by profession
# 65                             I am a developer by profession
# 99          I am not primarily a developer, but I write co...
# 117                                     I am learning to code
# 119                               I code primarily as a hobby
# 128                                     I am learning to code
# 139                            I am a developer by profession
# 143                            I am a developer by profession
# 167                            I am a developer by profession
# 182         I am not primarily a developer, but I write co...
#
#                  CurrentAge  \
# ResponseId
# 18          25-34 years old
# 65          18-24 years old
# 99          18-24 years old
# 117         18-24 years old
# 119         18-24 years old
# 128         18-24 years old
# 139         25-34 years old
# ...

# %%
df["ConvertedCompYearly"].head(15)
# Out:
# ResponseId
# 1      61256.0
# 2     104413.0
# 3      53061.0
# 4      36197.0
# 5      60000.0
# 6     120000.0
# 7       6240.0
# 8      72000.0
# 9      70000.0
# 10      5400.0
# 11     65691.0
# 12     14400.0
# 13      1099.0
# 14         NaN
# 15         NaN
# Name: ConvertedCompYearly, dtype: float64

# %%
df["ConvertedCompYearly"].median()
# Out:
# np.float64(75383.5)

# %%
df.median(numeric_only=True)
# Out:
# WorkExp                    10.0
# YearsCode                  14.0
# TechEndorse_1               9.0
# TechEndorse_2               4.0
# TechEndorse_3               4.0
# TechEndorse_4               6.0
# TechEndorse_5               4.0
# TechEndorse_6               5.0
# TechEndorse_7               7.0
# TechEndorse_8               4.0
# TechEndorse_9               4.0
# TechEndorse_13             10.0
# TechOppose_1                9.0
# TechOppose_2                4.0
# TechOppose_3                6.0
# TechOppose_5                5.0
# TechOppose_7                4.0
# TechOppose_9                3.0
# TechOppose_11               4.0
# TechOppose_13               5.0
# TechOppose_16               6.0
# TechOppose_15              10.0
# JobSatPoints_1              6.0
# JobSatPoints_4             10.0
# JobSatPoints_5             10.0
# JobSatPoints_6              8.0
# JobSatPoints_7              5.0
# JobSatPoints_8              7.0
# JobSatPoints_9              6.0
# ...

# %%
df.describe()
# Out:
#             WorkExp     YearsCode  TechEndorse_1  TechEndorse_2  \
# count  42844.000000  43000.000000   35943.000000   35943.000000
# mean      13.370810     16.575256       7.867763       4.104415
# std       10.801917     11.789269       2.397243       2.276154
# min        1.000000      1.000000       1.000000       1.000000
# 25%        5.000000      8.000000       7.000000       2.000000
# 50%       10.000000     14.000000       9.000000       4.000000
# 75%       20.000000     24.000000       9.000000       6.000000
# max      100.000000    100.000000      14.000000      14.000000
#
#        TechEndorse_3  TechEndorse_4  TechEndorse_5  TechEndorse_6  \
# count   35943.000000   35943.000000   35943.000000   35943.000000
# mean        4.110341       5.678574       4.119383       5.225830
# std         2.329539       2.397899       2.437938       2.801354
# min         1.000000       1.000000       1.000000       1.000000
# ...

# %%
df["ConvertedCompYearly"].count()
# Out:
# np.int64(23928)

# %%
df["RemoteWork"]
# Out:
# ResponseId
# 1                                                   Remote
# 2        Hybrid (some in-person, leans heavy to flexibi...
# 3                                                      NaN
# 4                                                   Remote
# 5                                                      NaN
#                                ...
# 49119       Hybrid (some remote, leans heavy to in-person)
# 49120       Hybrid (some remote, leans heavy to in-person)
# 49121                                                  NaN
# 49122       Hybrid (some remote, leans heavy to in-person)
# 49123    Your choice (very flexible, you can come in wh...
# Name: RemoteWork, Length: 49123, dtype: object

# %%
df["RemoteWork"].value_counts()
# Out:
# RemoteWork
# Remote                                                                          10924
# Hybrid (some remote, leans heavy to in-person)                                   6728
# In-person                                                                        6034
# Hybrid (some in-person, leans heavy to flexibility)                              5824
# Your choice (very flexible, you can come in when you want or just as needed)     4237
# Name: count, dtype: int64

# %%
df["EdLevel"].value_counts()
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          20247
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       12575
# Some college/university study without earning a degree                                 6175
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     3627
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         2620
# Associate degree (A.A., A.S., etc.)                                                    1560
# Other (please specify):                                                                 701
# Primary/elementary school                                                               582
# Name: count, dtype: int64

# %%
df["RemoteWork"].value_counts(normalize=True)
# Out:
# RemoteWork
# Remote                                                                          0.323703
# Hybrid (some remote, leans heavy to in-person)                                  0.199366
# In-person                                                                       0.178801
# Hybrid (some in-person, leans heavy to flexibility)                             0.172578
# Your choice (very flexible, you can come in when you want or just as needed)    0.125552
# Name: proportion, dtype: float64

# %%
df["Country"].value_counts()
# Out:
# Country
# United States of America                                7226
# Germany                                                 3022
# India                                                   2542
# United Kingdom of Great Britain and Northern Ireland    2038
# France                                                  1409
#                                                         ...
# Gabon                                                      1
# Mauritania                                                 1
# Timor-Leste                                                1
# Guinea-Bissau                                              1
# Guinea                                                     1
# Name: count, Length: 177, dtype: int64

# %%
country_grp = df.groupby(["Country"])

# %%
country_grp.get_group("Sweden")
# Out:
# /var/folders/p_/8vsfgly16lq5wdbqxrpds8r00000gn/T/ipykernel_72130/339335713.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group("Sweden")
#                                                    MainBranch  \
# ResponseId
# 28                             I am a developer by profession
# 68                             I am a developer by profession
# 116                            I am a developer by profession
# 180                            I am a developer by profession
# 262         I am not primarily a developer, but I write co...
# ...                                                       ...
# 47752                          I am a developer by profession
# 48112                          I am a developer by profession
# 48813                          I am a developer by profession
# ...

# %%
filt = df["Country"] == "Sweden"

# %%
df.loc[filt]["RemoteWork"].value_counts(normalize=True)
# Out:
# RemoteWork
# Hybrid (some remote, leans heavy to in-person)                                  0.324165
# Hybrid (some in-person, leans heavy to flexibility)                             0.223969
# Your choice (very flexible, you can come in when you want or just as needed)    0.165029
# In-person                                                                       0.153242
# Remote                                                                          0.133595
# Name: proportion, dtype: float64
